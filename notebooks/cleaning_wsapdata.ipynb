# %%
# Append System path for systematic imports
import sys
if (not('./' in sys.path)):
    sys.path.append('../')

# %%
pwd
# Out:
# '/home/pradyumna/project/whatsapp_chatbot/notebooks'

# %%
#lets clean and transform the chat data
import pandas as pd
import numpy as np
import os
filename="whatsapp_deepanshu.txt"
data_path = '../data'
fpath_input = os.path.join(data_path,filename)
df=pd.read_csv(fpath_input,header=None,on_bad_lines='skip', encoding='utf8')

# %%
df= df.drop(0)
df.rename(columns={0:'Date',1:'Chat'},inplace=True)
Message= df["Chat"].str.split("-", n = 1, expand = True) 
df['Date']=df['Date'].str.replace(",","") 
df['Time']=Message[0]
df['Text']=Message[1]
Message1= df["Text"].str.split(":", n = 1, expand = True) 
df['Text']=Message1[1]
df['Name']=Message1[0]
df=df.drop(columns=['Chat'])
df['Text']=df['Text'].str.lower()
df['Text'] = df['Text'].str.replace('<media omitted>','MediaShared')
df['Text'] = df['Text'].str.replace('this message was deleted','DeletedMsg')
df['Text'] = df['Text'].str.replace(',','')
# df['Text'] = df['Text'].str.replace(np.nan,'')
df['Name'] = df['Name'].astype('str')

# %%
df
# Out:
#              Date    2    3     Time                Text  \
# 1      07/04/2020  NaN  NaN   01:48                  abe
# 2      07/04/2020  NaN  NaN   01:48                  sun
# 3      07/04/2020  NaN  NaN   01:48         sun na laude
# 4      07/04/2020  NaN  NaN   01:48    missed voice call
# 5      07/04/2020  NaN  NaN   01:48    missed voice call
# ...           ...  ...  ...      ...                 ...
# 36226  11/03/2024  NaN  NaN   18:13          MediaShared
# 36227  11/03/2024  NaN  NaN   18:19          MediaShared
# 36228  11/03/2024  NaN  NaN   18:21          MediaShared
# 36229  11/03/2024  NaN  NaN   19:10     abe lene aja bro
# 36230  11/03/2024  NaN  NaN   19:10                    🌚
#
#                         Name
# 1       Deepanshu NIT Trichy
# 2       Deepanshu NIT Trichy
# 3       Deepanshu NIT Trichy
# 4       Deepanshu NIT Trichy
# 5       Deepanshu NIT Trichy
# ...                      ...
# 36226              Pradyumna
# 36227              Pradyumna
# 36228              Pradyumna
# 36229   Deepanshu NIT Trichy
# 36230   Deepanshu NIT Trichy
#
# [36230 rows x 6 columns]

# %%
from collections import defaultdict
def convert_to_chat_covs(df):
    conv_start = defaultdict(lambda :[])
    conv_end = defaultdict(lambda :[])
    count = 0
    for i,j in df[['Text','Name']].values:
        if(j==' Deepanshu NIT Trichy'):
            count+=1
            conv_start[count].append(i)
        else:
            conv_end[count].append(i)
    return conv_start,conv_end

# %%
conv_start,conv_end = convert_to_chat_covs(df)
conv_start = dict(conv_start)
conv_end = dict(conv_end)

# %%
conv_start
# Out:
# {1: [' abe'],
#  2: [' sun'],
#  3: [' sun na laude'],
#  4: [' missed voice call'],
#  5: [' missed voice call'],
#  6: [' abe'],
#  7: [' ye mt bhja kr be ese'],
#  8: [' iss grp m ldki bhi h'],
#  9: [' usko awkwrd lgta hoga'],
#  10: [' abe'],
#  11: [' rs10 de to'],
#  12: [' googlepay mei'],
#  13: [' rs 5 bhi chlega'],
#  14: [' abe sun'],
#  15: [' ek'],
#  16: [' ha to sun'],
#  17: [' mai'],
#  18: [' webpage bnaya khud ka'],
#  19: [' mtlb files wgra sab'],
#  20: [' repo mei dal dia hu'],
#  21: [' or source code master repo se'],
#  22: [' lia hi'],
#  23: [' but wo github.io wla'],
#  24: [' domain name milta hai n'],
#  25: [' usme'],
#  26: [' mtlb published bta to r hai'],
#  27: [' but wo link kholo to bs'],
#  28: [' readme.md wla file dikjaya hai'],
#  29: [' mtlb uske andr jo likha hai bs wo'],
#  30: [' to bta ab wo jo files mai bna ke dala hu usko use kyo nhi kr r hai ?'],
#  31: [' bsdike sun'],
#  32: [' 3 din hogya hai whi kr r hu smjh nhi aa r hai'],
#  33: [' pura webpage bna lia hu'],
#  34: [' but site mei aa nhi r hai'],
#  35: [' abe ese mt bol'],
#  36: [' rat rat jg ke bnaya'],
#  37: [' or end mei'],
#  38: [' dikh hi nhi r hai'],
#  39: [' sab kr lia mai'],
#  40: [' pta nhi prblm kaha hai'],
#  41: [' bs readme.md ka contents'],
#  42: [' dikh r hai'],
#  43: [' hogya'],
#  44: [' uske alwa kch nhi'],
#  45: [' ha'],
#  46: [' 😒madarchod fork kr le'],
#  47: [' ruk public kr deta hu'],
#  48: [' ab dekh'],
#  49: [' abe dekha ?'],
#  50: [' abe'],
#  51: [' private kr dia hu abhi'],
#  52: [' kam chal r hai uspe'],
#  53: [' elements overflow wala prbln'],
#  54: [' prblm*'],
#  55: [' tere ko'],
#  56: [' chiye'],
#  57: [' kya ?'],
#  58: [' fork kr le'],
#  59: [' id ???'],
#  60: [' abe wo id '],
#  61: [' mtlb wo part ko access krne ke lia'],
#  62: [' css mei'],
#  63: [' hoga be'],
#  64: [' #tribute-link'],
#  65: [' krke'],
#  66: [' rhta hai css mei'],
#  67: [' #tribute-link {'],
#  68: [' fork kia hai kya usko?'],
#  69: [' bsdike'],
#  70: [' chori mt kr'],
#  71: [' give me some respect'],
#  72: [' fork krke use kr'],
#  73: [' acha'],
#  74: [' webpage wla pe mai overflow'],
#  75: [' prbln se preshn hogya hi'],
#  76: [' hu*'],
#  77: [' usko'],
#  78: [' dekh r hu'],
#  79: [' 200 lins html mei'],
#  80: [' 300 lines css ka'],
#  81: [' framework use krne se easy rhta hai kya ?'],
#  82: [' abe kkrh ?'],
#  83: [' tu?'],
#  84: [' grp dekh'],
#  85: [' devblin.codes'],
#  86: [' open in pc for better experince'],
#  87: [' mobile mei bhi khol skta hai but bahut chota lg r hai'],
#  88: [' missed voice call'],
#  89: [' prjct'],
#  90: [' pe kch kia ?'],
#  91: [' aage?'],
#  92: [' ok'],
#  93: [' ha update kia hu'],
#  94: [' hackermode khel'],
#  95: [' ke'],
#  96: [' hackermode'],
#  97: [' ha'],
#  98: [' ha task hai kahe ki 😂'],
#  99: [' abe thik se chala ?'],
#  100: [' hackermode ?'],
#  101: [' normal mode ?'],
#  102: [' 😂jo game bnaya hu usme 20% html .....40% css.....40% js hai'],
#  103: [' bahut'],
#  104: [' sahi'],
#  105: [' language hai'],
#  106: [' ha'],
#  107: [' js dom  pdh lia ?'],
#  108: [' ohf'],
#  109: [' yhi to main hai'],
#  110: [' mere ko bhi'],
#  111: [' induction strt hone se phle'],
#  112: [' ye'],
#  113: [' js'],
#  114: [' psnd nhi tha'],
#  115: [' programming lang typ hai krke'],
#  116: [' ha'],
#  117: [' yhi sn'],
#  118: [' to hai'],
#  119: [' ha'],
#  120: [' 🤦🏻\u200d♂️'],
#  121: [' dynamic'],
#  122: [' bnane mei kam ata hai'],
#  123: [' jo tera'],
#  124: [' bina life ke'],
#  125: [' page rhta hai'],
#  126: [' usko life'],
#  127: [' dene ka kam'],
#  128: [' krta hai ye'],
#  129: [' bol'],
#  130: [' abe'],
#  131: [' 🤦🏻\u200d♂️'],
#  132: [' kisme'],
#  133: [' se pdh r hai ?'],
#  134: [' tu ?'],
#  135: [' konsa site hai yw ?'],
#  136: [' dekh mai 7 din se kam kr r hu task pe to mere ko js use krne sahi dhng se ajata hai'],
#  137: [' tu humre'],
#  138: [' prjct pe'],
#  139: [' kam krne'],
#  140: [' ki kosis kr'],
#  141: [' sikhte jyga tu'],
#  142: [' mera mentor yhi bol r tha'],
#  143: [' mtlb jb task mila tha to'],
#  144: [' mann ke tere ko'],
#  145: [' kisi'],
#  146: [' element ko'],
#  147: [' chupana hai'],
#  148: [' wo element ka class mann le *game* hai'],
#  149: [' to fir'],
#  150: [' tu chahta hai jb tk'],
#  151: [' window'],
#  152: [' load na ho'],
#  153: [' ya kisi button ko use krke'],
#  154: [' usko visible krna hai to'],
#  155: [' btn.onclick = function(){'],
#  156: [' nhi'],
#  157: [' isme kya ho r hai ki'],
#  158: [' btn ek button ka object model hai mtlb button nam ka ek elment'],
#  159: [' hai kahi pe'],
#  160: [' html mei'],
#  161: [' tu usko'],
#  162: [' click kia'],
#  163: [' to isme jo function hai wo hoga'],
#  164: [' andr function ke hissb se'],
#  165: [' "game" class ka display property "block" mei chnge krna hai'],
#  166: [' jiske wjh se tere ko wo element dikga button click krne pe'],
#  167: [' ese hota hai'],
#  168: [' code chiye to apan discussion krenge 25 ke bd'],
#  169: [' humre game ke logic pe'],
#  170: [' kahe ki easy hai uske lia code likhna'],
#  171: [' ha bol r hu game pe kam kro aram se sikhenge'],
#  172: [' js apan'],
#  173: [' mzk mei mt lena '],
#  174: [' apan locally scores save bhi kr pyenge apne game mei'],
#  175: [' js  script language hai isly easy hai bahut'],
#  176: [' thoda basic pdh le'],
#  177: [' what ?'],
#  178: [' abe ye uncle aunty hai kya ?'],
#  179: [' abe'],
#  180: [' uncle ka'],
#  181: [' shirt pant'],
#  182: [' mst lg r ha8'],
#  183: [' combination'],
#  184: [' style'],
#  185: [' ha tu hi c reh gya'],
#  186: [' abhi ?'],
#  187: [' mtlb ?'],
#  188: [' kya hua ?'],
#  189: [' abe mtlb abhi present mei admit hai kya ?'],
#  190: [' to tu ja r hai ?'],
#  191: [' apollo ?'],
#  192: [' mere ghr'],
#  193: [' ajata'],
#  194: [' raste mei pdta hai'],
#  195: [' ha thik ha to'],
#  196: [' ajata'],
#  197: [' wps'],
#  198: [' ghr'],
#  199: [' thik hai'],
#  200: [' ....'],
#  201: [' ?'],
#  202: [' kb ?'],
#  203: [' 🤦🏻\u200d♂️'],
#  204: [' kb ja r hai gaon ?'],
#  205: [' bro ?'],
#  206: [' tu thik hai ?'],
#  207: [' 😯😯😯😯'],
#  208: [' maine group mei mtlb github wla grp mei'],
#  209: [' dal dia hai code'],
#  210: [' jyda kch nhi hai'],
#  211: [' ek div elment hai yellow uske andr red wala ek element hai'],
#  212: [' jo move kr r hai'],
#  213: [' eventlistener rkha hu uss red box mei'],
#  214: [' MediaShared'],
#  215: [' hai kon ye ?'],
#  216: [' 😯'],
#  217: [' fok'],
#  218: [' bapre'],
#  219: [' kya bt hai'],
#  220: [' nhi be 😂 mere se ye sb nhi hota'],
#  221: [' but acha'],
#  222: [' bola tu'],
#  223: [' 👏🏻'],
#  224: [' or abhi'],
#  225: [' kya kr rha hai ?'],
#  226: [' abe thoda practice bhi kiye kr ipython shell mei'],
#  227: [' bhej de😂'],
#  228: [' wo jo pdhata hai uske sth experiment wgra kr liye kr to sahi rhega'],
#  229: [' bs pdhte mt ja'],
#  230: [' koi fyda nhi hai fir'],
#  231: [' krta hai ki nhi practice ?'],
#  232: [' thik hai kr lena'],
#  233: [' kya'],
#  234: [' kar'],
#  235: [' rha h ?'],
#  236: [' hey'],
#  237: [' brosdikw'],
#  238: [' missed voice call'],
#  239: [' abe'],
#  240: [' ek'],
#  241: [' bt puchna hai mere ko'],
#  242: [' agr tu'],
#  243: [' free hoga'],
#  244: [' to'],
#  245: [' msg kr dena'],
#  246: [' pls'],
#  247: [' oye'],
#  248: [' ye kya'],
#  249: [' hai'],
#  250: [' mobile'],
#  251: [' hath mei'],
#  252: [' rkhta hai'],
#  253: [' to bhi'],
#  254: [' call'],
#  255: [' nhi uthata hai'],
#  256: [' to mai konsa muh se bolta mai i jst want attention kr r tha'],
#  257: [' abe mere ko n'],
#  258: [' agr kisi'],
#  259: [' profs'],
#  260: [' ke under'],
#  261: [' mtlb'],
#  262: [' mere hi collg ke'],
#  263: [' uske under kam'],
#  264: [' krna hai'],
#  265: [' to'],
#  266: [' kese approach'],
#  267: [' kru'],
#  268: [' prof ko ?'],
#  269: [' tell tell'],
#  270: [' acha agr'],
#  271: [' wo'],
#  272: [' prof'],
#  273: [' mera mentor'],
#  274: [' hai to ?'],
#  275: [' koi'],
#  276: [' fyda hai ?'],
#  277: [' kya ? fyda ?'],
#  278: [' ok'],
#  279: [' or sun'],
#  280: [' wo jo prof hai'],
#  281: [' uska profile bahut tgda hai'],
#  282: [' machine learning'],
#  283: [' computer vision'],
#  284: [' ke field mei'],
#  285: [' or apun ko uske under kam krne ka hi hao'],
#  286: [' but dikkat ye hai n ki mere ko knowledge hi nhi hai'],
#  287: [' kya likhu ?'],
#  288: [' to uske sth phle discuss kru ?'],
#  289: [' ya fir apne'],
#  290: [' ideas du ?'],
#  291: [' or bt kru ki'],
#  292: [' ispe kam krna hai ye wo'],
#  293: [' ok'],
#  294: [' ok'],
#  295: [' ok ok '],
#  296: [' ok'],
#  297: [' got got it'],
#  298: [' ha'],
#  299: [' ok to'],
#  300: [' kya bt chal ri hai ?'],
#  301: [' fir ?'],
#  302: [' acha'],
#  303: [' acha acha smjha'],
#  304: [' ruk ek min'],
#  305: [' ha abhi tu iot pe kr r hai n projct ek ?'],
#  306: [' to wo tu prof ke under kr r hai'],
#  307: [' n ?'],
#  308: [' konsi 🧐'],
#  309: [' sahi rhega fir to internship bhi kr pyga 😯'],
#  310: [' 🥺'],
#  311: [' 😯'],
#  312: [' acha oppurtunity hai'],
#  313: [' tu akela nhi hai be'],
#  314: [' logo ke job gye'],
#  315: [' internshio'],
#  316: [' internship tk'],
#  317: [' gye'],
#  318: [' tu'],
#  319: [' hackerrank'],
#  320: [' use krta hai?'],
#  321: [' mere ko'],
#  322: [' pta chala ki'],
#  323: [' hackerank apne yha'],
#  324: [' ka'],
#  325: [' startup hai'],
#  326: [' agya hai bsp ?'],
#  327: [' bol'],
#  328: [' to tu kya chah r hai ?'],
#  329: [' abe ek bt bta'],
#  330: [' chal dpge'],
#  331: [' doge'],
#  332: [' fir aunty'],
#  333: [' akele kese'],
#  334: [' rhengi ?'],
#  335: [' tere ghr ke ps relatives hai ?'],
#  336: [' fir bhi'],
#  337: [' badi bt to hai'],
#  338: [' to wo'],
#  339: [' dur hai be'],
#  340: [' kitna'],
#  341: [' tum log'],
#  342: [' mangla side rhte ho'],
#  343: [' too tougj'],
#  344: [' mai bachpan mei'],
#  345: [' mumy mai mera bhai'],
#  346: [' bs rhte the'],
#  347: [' to'],
#  348: [' mumy ko bekar lgta tha'],
#  349: [' or tu log bhi chal doge'],
#  350: [' ana bhi pdega'],
#  351: [' tere ko'],
#  352: [' to'],
#  353: [' sunday'],
#  354: [' vibha ko'],
#  355: [' bhi'],
#  356: [' but tere ko krna pdega'],
#  357: [' n'],
#  358: [' i advice you to do this '],
#  359: [' can'],
#  360: [' or vibha kya krti hai ? ajkal ?'],
#  361: [' wo kesi hai ?'],
#  362: [' abhi ?'],
#  363: [' exam ?'],
#  364: [' google form mei ?'],
#  365: [' cheating krna possible rhta hai kya ?'],
#  366: [' ha wo to hai'],
#  367: [' or udhr bahar nikal rhe hai kya log ? tere ghr side ?'],
#  368: [' hair ka hi pta chalega'],
#  369: [' abe'],
#  370: [' bahut'],
#  371: [' banjar'],
#  372: [' jindagi'],
#  373: [' lg rhi hai'],
#  374: [' abhi'],
#  375: [' jb bsy rhta hu'],
#  376: [' to'],
#  377: [' pta nhi chlta hai'],
#  378: [' idhr udhr krta hu to yad ata hai'],
#  379: [' kch nhi kr skta abhi'],
#  380: [' ghr bethe bethe pagal ho r hi'],
#  381: [' hu'],
#  382: [' mai 2 din se 1 obstacle ke logic pe kam kr r hu'],
#  383: [' pura'],
#  384: [' circle'],
#  385: [' ka'],
#  386: [' concept use kr lia mai'],
#  387: [' but its tough'],
#  388: [' nind nhi ata hai'],
#  389: [' sote tym sochta hu sala ye krung ye krunga ye idea krta hu'],
#  390: [' esa krte krte'],
#  391: [' 4 bj jata hai'],
#  392: [' fir late uthata hu'],
#  393: [' tera'],
#  394: [' class'],
#  395: [' chal rha hai'],
#  396: [' kya ?'],
#  397: [' abe mera'],
#  398: [' eg ka'],
#  399: [' class hota hai'],
#  400: [' or madam attendance bhi'],
#  401: [' leti hai'],
#  402: [' kahe ka nice'],
#  403: [' 2 hrs'],
#  404: [' bethna pdta hai'],
#  405: [' uppr se attendance'],
#  406: [' or uppr se'],
#  407: [' wo bich bich'],
#  408: [' mei bolti hai'],
#  409: [' kcj explain krne ke bd'],
#  410: [' why only i student responding'],
#  411: [' what about others'],
#  412: [' fir sab bhed bakri type'],
#  413: [' yeah yeah'],
#  414: [' krte hai'],
#  415: [' or 2-3 log to sbse jyda bolte hai'],
#  416: [' unki awaj chubhti hai'],
#  417: [' kan mei'],
#  418: [' mere'],
#  419: [' abe'],
#  420: [' hum'],
#  421: [' uss madam ko'],
#  422: [' sbse bdi'],
#  423: [' c'],
#  424: [' smjhte th'],
#  425: [' the'],
#  426: [' kahe ko'],
#  427: [' sb bde wale'],
#  428: [' profs'],
#  429: [' jo the'],
#  430: [' har mann gye'],
#  431: [' online class ke lia'],
#  432: [' but wo hai ki'],
#  433: [' consistencely'],
#  434: [' 3 classs le chuki hai'],
#  435: [' bakayda'],
#  436: [' jo absent rhta hai'],
#  437: [' uska absent kregi'],
#  438: [' or to'],
#  439: [' dont give proxy'],
#  440: [' i heared this voice again'],
#  441: [' ka'],
#  442: [' hua'],
#  443: [' be'],
#  444: [' bhai ?'],
#  445: [' '],
#  446: [' kya hua be tere ko'],
#  447: [' rply nhi de r hai'],
#  448: [' u'],
#  449: [' should'],
#  450: [' rply'],
#  451: [' 2-3 hi logo ke'],
#  452: [' msg ate hai bs mujhe'],
#  453: [' usme'],
#  454: [' tu bhi'],
#  455: [' rply nhi'],
#  456: [' dega'],
#  457: [' to'],
#  458: [' kese chlega'],
#  459: [' be'],
#  460: [' zbro'],
#  461: [' bol'],
#  462: [' bol bol bol'],
#  463: [' bol'],
#  464: [' ae'],
#  465: [' ungli mt dikha'],
#  466: [' abe'],
#  467: [' sun'],
#  468: [' be'],
#  469: [' ka'],
#  470: [' ka r r hai'],
#  471: [' ?'],
#  472: [' kya krta hai be dinbhr ?'],
#  473: [' too much busy ?'],
#  474: [' nowadays ?'],
#  475: [' nice'],
#  476: [' uthata kb hai tu ?'],
#  477: [' subhe'],
#  478: [' thik hai'],
#  479: [' we will be coming morning not tommorow'],
#  480: [' nhi'],
#  481: [' is it okay for uh ?'],
#  482: [' abe'],
#  483: [' apan'],
#  484: [' algi ki algo'],
#  485: [' agli'],
#  486: [' subh3'],
#  487: [' ayenge'],
#  488: [' bol r hu'],
#  489: [' tere ko chlega ?'],
#  490: [' esa puch r hu'],
#  491: [' 8 bje as ps ayenge due to lockdown timmings'],
#  492: [' ok'],
#  493: [' abe'],
#  494: [' mai arish'],
#  495: [' ayenge'],
#  496: [' bol re'],
#  497: [' the'],
#  498: [' hai*'],
#  499: [' kal'],
#  500: [' to tere ko'],
#  501: [' chlega !'],
#  502: [' ?'],
#  503: [' koi prblm ho to bol'],
#  504: [' skta hai'],
#  505: [' sorry'],
#  506: [' bro'],
#  507: [' sale'],
#  508: [' sorry'],
#  509: [' likha hu'],
#  510: [' usme'],
#  511: [' kya kya'],
#  512: [' abe ane wale the n'],
#  513: [' apan'],
#  514: [' but meri wjh'],
#  515: [' se nhi aa'],
#  516: [' paye'],
#  517: [' yes'],
#  518: [' no bro'],
#  519: [' are'],
#  520: [' mai 6 bje uth gya tha'],
#  521: [' nikal hi r tha'],
#  522: [' fir scooty mei fss gya'],
#  523: [' abhi leke gye hai bnwane ke lia'],
#  524: [' ha'],
#  525: [' kaha ?'],
#  526: [' verzeo ?'],
#  527: [' ohfo'],
#  528: [' to bn gya hai'],
#  529: [' ?'],
#  530: [' tum log ka'],
#  531: [' prjct ?'],
#  532: [' oho'],
#  533: [' 🙄'],
#  534: [' kya ?'],
#  535: [' mere ko abhi tk smjh nhi aya hai ye'],
#  536: [' oho'],
#  537: [' 🤦🏻\u200d♂️'],
#  538: [' ok got iy'],
#  539: [' it'],
#  540: [' ye roller coaster ka physics hai'],
#  541: [' mtlb math wala part'],
#  542: [' haa'],
#  543: [' mai tere se math m aage rha hu bsdike'],
#  544: [' 😒😒😒'],
#  545: [' calculus ke lia apun ne 1 month chutti mari thi school mei'],
#  546: [' are ye roller coaster wala'],
#  547: [' track dekh k smjh aya ki'],
#  548: [' acha'],
#  549: [' graph'],
#  550: [' to tum log rolercoaaster'],
#  551: [' bnane'],
#  552: [' wale'],
#  553: [' ho'],
#  554: [' kya'],
#  555: [' ?'],
#  556: [' abe  sun'],
#  557: [' infinity sign'],
#  558: [' path ka'],
#  559: [' equation'],
#  560: [' hai kya ?'],
#  561: [' wtf'],
#  562: [' kaha se'],
#  563: [' itni jldi'],
#  564: [' sahi hai kya ye ?'],
#  565: [' 😳'],
#  566: [' 😳'],
#  567: [' 🙄😳😳😳😳'],
#  568: [' ye link bhj to'],
#  569: [' site ka'],
#  570: [' sb shape bna skte hai kya isse ?'],
#  571: [' bsdike'],
#  572: [' pta to ho ki function hai kya'],
#  573: [' abe sun'],
#  574: [' ubuntu ka'],
#  575: [' sapce'],
#  576: [' space'],
#  577: [' bdha skta hu kya ?'],
#  578: [' 😂'],
#  579: [' nhi'],
#  580: [' mar jaunga  ye sb krunga to'],
#  581: [' ha'],
#  582: [' abe mai'],
#  583: [' dekha tha'],
#  584: [' partition'],
#  585: [' ka'],
#  586: [' pta nhi kya kya tha'],
#  587: [' abhi recelty mrra ubuntu ajib'],
#  588: [' behave'],
#  589: [' kr r tha'],
#  590: [' terminal'],
#  591: [' gyab'],
#  592: [' desktop gyab'],
#  593: [' bs app dikh r tha'],
#  594: [' bs python uninstall kia fir'],
#  595: [' ho r tha'],
#  596: [' 🙄'],
#  597: [' mtlb?'],
#  598: [' mai bhi'],
#  599: [' kia tha'],
#  600: [' fir mai uninstall kr dia'],
#  601: [' 😂'],
#  602: [' abe mere mei terminal hi nhi tja'],
#  603: [' exist hi nhi kr r tha'],
#  604: [' tha*'],
#  605: [' abe sun to fir'],
#  606: [' restrt kia tha mai to'],
#  607: [' black screen mei'],
#  608: [' dikha r tha ki'],
#  609: [' kch delte krna hai'],
#  610: [' ye wo'],
#  611: [' to mai sb kia'],
#  612: [' to'],
#  613: [' ubuntu'],
#  614: [' firse'],
#  615: [' install kia tha mai syd'],
#  616: [' to fir thik hogya'],
#  617: [' ha abhi to thik ha8'],
#  618: [' hai*'],
#  619: [' naya version chal r hai'],
#  620: [' but files sb safe tha'],
#  621: [' jaha tha'],
#  622: [' sb whi tha'],
#  623: [' kya hua ?'],
#  624: [' audio on krke khlna'],
#  625: [' abe kya hogya ?'],
#  626: [' whts the prblm'],
#  627: [' ?'],
#  628: [' abe wo task'],
#  629: [' ka tha be'],
#  630: [' mera'],
#  631: [' task2'],
#  632: [' khel k dekh'],
#  633: [' abe to mai bhi nhi de pa r hu delta ke tasks ke wjh se'],
#  634: [' ye bt alg hai'],
#  635: [' tu bhi pdh hi r hai'],
#  636: [' kya hai ye ?'],
#  637: [' kiska?'],
#  638: [' significan kya hai iska?'],
#  639: [' ohfo'],
#  640: [' phli bar suna dekha mai to'],
#  641: [' esa grpah'],
#  642: [' ...'],
#  643: [' ha'],
#  644: [' abe mtlb isse kya pta chlega apan'],
#  645: [' ko'],
#  646: [' ese type ke'],
#  647: [' graphs se?'],
#  648: [' acha pta chal gya'],
#  649: [' box plot jesa hota hai'],
#  650: [' bs'],
#  651: [' ye probability density bhi dikhata hai'],
#  652: [' esa kch likha hai'],
#  653: [' ha to'],
#  654: [' acha '],
#  655: [' box ploy'],
#  656: [' box plot pta hai ?'],
#  657: [' or denisty  plot?'],
#  658: [' ha to ye inn dono ka combination hai'],
#  659: [' ab smjh de mere ko'],
#  660: [' ki fyda  kya'],
#  661: [' hua'],
#  662: [' ok ok to prediction hai ki 60-80 ke bich ho skte hai ? agr test data'],
#  663: [' dalega to?'],
#  664: [' ok'],
#  665: [' abe sun'],
#  666: [' verzeo'],
#  667: [' ka kesa'],
#  668: [' lg r hai'],
#  669: [' tere ko'],
#  670: [' ye ml'],
#  671: [' wala?'],
#  672: [' ha mai soch r tha ki coursera mei koi sa course kr lu'],
#  673: [' ml pe'],
#  674: [' uska fees nhi dia hu'],
#  675: [' n abhi'],
#  676: [' ml wala'],
#  677: [' using python ?'],
#  678: [' hai ?'],
#  679: [' ha isly to tere se pucha'],
#  680: [' ha'],
#  681: [' ???'],
#  682: [' abe but mai dekha tha wo octave mei'],
#  683: [' krata hai'],
#  684: [' fok'],
#  685: [' mai dekha nhi'],
#  686: [' 🥵'],
#  687: [' ok'],
#  688: [' ha octave wala h'],
#  689: [' ha'],
#  690: [' or koi course dhyn mei hai tere?'],
#  691: [' jisme python ho'],
#  692: [' abe'],
#  693: [' how to go pro'],
#  694: [' in data science'],
#  695: [' wala link'],
#  696: [' mila kya tere ko?'],
#  697: [' milga to'],
#  698: [' mujhe'],
#  699: [' bhi'],
#  700: [' bhj dena'],
#  701: [' email'],
#  702: [' abe'],
#  703: [' tu'],
#  704: [' cmmnt kia tha n'],
#  705: [' yes email id'],
#  706: [' esa krke'],
#  707: [' ek min'],
#  708: [' MediaShared'],
#  709: [' ye tere tha ki wo c ldki bhi cmnnt ki hai'],
#  710: [' oops sry mere  ko'],
#  711: [' wo'],
#  712: [' chinese ldka tu lga'],
#  713: [' ok'],
#  714: [' khrid'],
#  715: [' lia'],
#  716: [' mai'],
#  717: [' bhi'],
#  718: [' gtav'],
#  719: [' attitude'],
#  720: [' ki'],
#  721: [' dukan'],
#  722: [' kis bt ka attitude hai didi ko'],
#  723: [' 😯'],
#  724: [' tu ka kr  hai'],
#  725: [' ?'],
#  726: [' rhene de'],
#  727: [' tu bhi na btaya kr kch'],
#  728: [' ese log ko'],
#  729: [' abe'],
#  730: [' bol'],
#  731: [' 😯'],
#  732: [' abe kch krte hai be'],
#  733: [' something interesting'],
#  734: [' abe'],
#  735: [' 😂abe'],
#  736: [' ye'],
#  737: [' 150 rupiya dega wala'],
#  738: [' status'],
#  739: [' sahi hai tera'],
#  740: [' 😳'],
#  741: [' mai bhi kr leta hu'],
#  742: [' kch idea de'],
#  743: [' wo totla ka rkh lu kya ?'],
#  744: [' usko wo chote height wala'],
#  745: [' kon tha'],
#  746: [' 25 din mei pesa double wala'],
#  747: [' ha iska'],
#  748: [' 😂'],
#  749: [' dekh ab'],
#  750: [' 😂'],
#  751: [' kya ?'],
#  752: [' ab'],
#  753: [' ha whi soch r hu'],
#  754: [' la baba 5 crore ?'],
#  755: [' 😂'],
#  756: [' https://devblin.codes'],
#  757: [' abe ye dekh be'],
#  758: [' pura responsive bnaya hu iss bar page ko'],
#  759: [' to bna le'],
#  760: [' abe to page hi to bnana'],
#  761: [' hai'],
#  762: [' to mai bs html css hi use kia hu'],
#  763: [' no'],
#  764: [' no js'],
#  765: [' only html css'],
#  766: [' abe mere page ke niche pdhna credit dia hu'],
#  767: [' 😂'],
#  768: [' madw with html css'],
#  769: [' https://html5up.net/'],
#  770: [' isme dekh le ye sb html'],
#  771: [' ae'],
#  772: [' kachra seth'],
#  773: [' dekha isko?'],
#  774: [' ha to'],
#  775: [' idea dene ke lia'],
#  776: [' ludo'],
#  777: [' ha but bahut sara rhta hai'],
#  778: [' unka code'],
#  779: [' bol'],
#  780: [' bol na'],
#  781: [' bsdikhe'],
#  782: [' kya nhi mila ?'],
#  783: [' 😯dub ja'],
#  784: [' ek glass pani leke'],
#  785: [' iya'],
#  786: [' kya hogya'],
#  787: [' hai be'],
#  788: [' tere ko'],
#  789: [' kya chiz ?'],
#  790: [' acha  koi ek template choose kr or mere ko bhj'],
#  791: [' link bhjna'],
#  792: [' to tere ko code chiye uska ?'],
#  793: [' bsdike '],
#  794: [' wo to blogger'],
#  795: [' ka template lg r hai'],
#  796: [' acha sry'],
#  797: [' abe simply'],
#  798: [' download kr'],
#  799: [' download button dikh r hoga n'],
#  800: [' usse ek zip file milega usme'],
#  801: [' sab hai'],
#  802: [' bs apne hissb se content chnge krna pdega tere ko'],
#  803: [' then you r ready to go'],
#  804: [' template whi hai'],
#  805: [' wtf'],
#  806: [' MediaShared'],
#  807: [' ho kya gya hai be tere ko'],
#  808: [' dinbhr kya krta hai ?'],
#  809: [' laptop?'],
#  810: [' kaha h ?'],
#  811: [' abe 15-20 min ka  kam hai'],
#  812: [' isse page ready krna'],
#  813: [' koi acha sa dekh k bna le'],
#  814: [' ha'],
#  815: [' abe'],
#  816: [' kya'],
#  817: [' kar rha h'],
#  818: [' bhai bt kr mere se'],
#  819: [' feeling low nowdays'],
#  820: [' kch krne ka'],
#  821: [' mnn nhi krta be'],
#  822: [' agr krne ka sochta hu to'],
#  823: [' kese krunga'],
#  824: [' kch ata hai nhi'],
#  825: [' wo sb vhor'],
#  826: [' abe mai'],
#  827: [' kch'],
#  828: [' notable krna'],
#  829: [' chahta hu'],
#  830: [' idea ga9'],
#  831: [' hai*'],
#  832: [' but'],
#  833: [' pta nhi'],
#  834: [' mnn krta nhi hai kyoki'],
#  835: [' ata hai nhi'],
#  836: [' kch mere ko'],
#  837: [' uea'],
#  838: [' yes'],
#  839: [' ek chat bot bnana hai'],
#  840: [' taki uske sth mai bt kr sku'],
#  841: [' abe'],
#  842: [' mera'],
#  843: [' idea hai n'],
#  844: [' usme n'],
#  845: [' mai jo'],
#  846: [' whtsapp ke'],
#  847: [' chats hai'],
#  848: [' usme se'],
#  849: [' export krunga chat ko'],
#  850: [' as a'],
#  851: [' training data'],
#  852: [' to fir mer chatbot usse sikhega'],
#  853: [' or fir syd'],
#  854: [' natural bt kr pau'],
#  855: [' ha bol'],
#  856: [' to'],
#  857: [' bol'],
#  858: [' abe nhi be'],
#  859: [' mere ko'],
#  860: [' whi krna hai'],
#  861: [' jo mai socha hu'],
#  862: [' tu log'],
#  863: [' krega kya'],
#  864: [' yhi chatbot wala'],
#  865: [' bsdike'],
#  866: [' ek prjct'],
#  867: [' pending hai abhi tk'],
#  868: [' kya ha'],
#  869: [' team'],
#  870: [' kya pta ye prjct startup bn jaye'],
#  871: [' chatbot wala'],
#  872: [' co-founder bn jyenge tino'],
#  873: [' ha to kese krenge'],
#  874: [' arish pubg khlte'],
#  875: [' rhta hai'],
#  876: [' grp mei aa'],
#  877: [' tu soch'],
#  878: [' potential hai'],
#  879: [' isme'],
#  880: [' mere hissb se'],
#  881: [' hai ki nhi bta ?'],
#  882: [' bsdike potential'],
#  883: [' mtlb potential'],
#  884: [' hota hai'],
#  885: [' idea'],
#  886: [' idea'],
#  887: [' bol'],
#  888: [' be'],
#  889: [' bol'],
#  890: [' 😂'],
#  891: [' fok'],
#  892: [' mam'],
#  893: [' man'],
#  894: [' fok'],
#  895: [' 🥵'],
#  896: [' 🤦🏻\u200d♂️'],
#  897: [' kya'],
#  898: [' tu'],
#  899: [' jag rha hai'],
#  900: [' abe'],
#  901: [' ye verzeo ka'],
#  902: [' major prjct mila hai'],
#  903: [' usko mai'],
#  904: [' kese kru'],
#  905: [' mtlb'],
#  906: [' kch log bol re hai ki kam bat lete hai wgra wgra'],
#  907: [' 2 din phke'],
#  908: [' chutuye'],
#  909: [' tera'],
#  910: [' ml'],
#  911: [' wla h'],
#  912: [' pta hai'],
#  913: [' ka'],
#  914: [' kr r hai be'],
#  915: [' missed voice call'],
#  916: [' online bulane ki ninja technique'],
#  917: [' abe'],
#  918: [' ka kr r hai'],
#  919: [' be'],
#  920: [' bhai mere'],
#  921: [' se'],
#  922: [' to bt kiye kr'],
#  923: [' tu hi hai sahara abhu'],
#  924: [' abhi'],
#  925: [' ka kar r h tu?'],
#  926: [' missed voice call'],
#  927: [' abe'],
#  928: [' abe'],
#  929: [' prof'],
#  930: [' ko'],
#  931: [' mail'],
#  932: [' kia tha mai'],
#  933: [' to rply m wo bola ki'],
#  934: [' pde pdgo'],
#  935: [' pdho*'],
#  936: [' for oct m bt krega research prjct pe'],
#  937: [' partial differential eq.'],
#  938: [' abe sun be'],
#  939: [' wo prof ko'],
#  940: [' rply kese du ?'],
#  941: [' jldi bol be'],
#  942: [' abe ek min'],
#  943: [' tere ko bhjta hu'],
#  944: [' pura'],
#  945: [' tu pdh ke'],
#  946: [' btana'],
#  947: [' abe esa nhi ki bs oct mei bt krenge iske bare mek'],
#  948: [' wo bola ki'],
#  949: [' advance books wgra dekho'],
#  950: [' ye wo'],
#  951: [' abe'],
#  952: [' sun'],
#  953: [' be'],
#  954: [' ja'],
#  955: [' ka'],
#  956: [' kar rha h ?'],
#  957: [' bol bhai ka krya hai'],
#  958: [' kya'],
#  959: [' hua'],
#  960: [' bol'],
#  961: [' 😏tere se phle ka update kr chuka hu'],
#  962: [' online'],
#  963: [' hi'],
#  964: [' jaha'],
#  965: [' kaha'],
#  966: [' rhta hu mai'],
#  967: [' 1 bje to soke utha hu aj'],
#  968: [' baki coursera'],
#  969: [' or prjct kr r tha verzeo ka'],
#  970: [' tu'],
#  971: [' ka'],
#  972: [' krta ha'],
#  973: [' hai'],
#  974: [' be'],
#  975: [' or?'],
#  976: [' MediaShared'],
#  977: [' jldi grp mei aa'],
#  978: [' chk krke dekh'],
#  979: [' kon hai'],
#  980: [' mere  ko to nhi pta'],
#  981: [' kya msg aya hai ?'],
#  982: [' oh'],
#  983: [' ye to'],
#  984: [' wo hai'],
#  985: [' linkedin wali'],
#  986: [' mere ko bhi ki thi'],
#  987: [' kyo ?'],
#  988: [' m'],
#  989: [' a'],
#  990: [' cbsdi'],
#  991: [' bsdhike'],
#  992: [' bsdike'],
#  993: [' abe'],
#  994: [' sun'],
#  995: [' guu kha le bhosdike'],
#  996: [' zeher walo'],
#  997: [' kheet bhi'],
#  998: [' kha'],
#  999: [' le'],
#  1000: [' kha le'],
#  ...}

# %%
conv_end[45]
# Out:
# [' wo file bhj pura jo githhub pe daala hai',
#  ' usko mai daal ke dekhta hu',
#  ' fir chala ke dekhta hu']

# %%
start_dict = defaultdict(list)


def join_sep_con(input_text, response_text):
    start_index = 1
    count = 1
    for ind in response_text.keys():
        end_index = ind
        for pointer in range(start_index, end_index+1):
            start_dict[count].append(''.join(input_text[pointer]))
        count += 1
        start_index = end_index + 1

# %%
join_sep_con(conv_start, conv_end)

# %%
start_dict = dict(start_dict)

# %%
conv_start = start_dict

# %%
[i[1] for i in conv_start.items()]
# Out:
# [[' abe', ' sun', ' sun na laude', ' missed voice call', ' missed voice call'],
#  [' abe',
#   ' ye mt bhja kr be ese',
#   ' iss grp m ldki bhi h',
#   ' usko awkwrd lgta hoga'],
#  [' abe',
#   ' rs10 de to',
#   ' googlepay mei',
#   ' rs 5 bhi chlega',
#   ' abe sun',
#   ' ek'],
#  [' ha to sun',
#   ' mai',
#   ' webpage bnaya khud ka',
#   ' mtlb files wgra sab',
#   ' repo mei dal dia hu',
#   ' or source code master repo se',
#   ' lia hi',
#   ' but wo github.io wla',
#   ' domain name milta hai n',
#   ' usme',
#   ' mtlb published bta to r hai',
#   ' but wo link kholo to bs',
#   ' readme.md wla file dikjaya hai',
#   ' mtlb uske andr jo likha hai bs wo',
#   ' to bta ab wo jo files mai bna ke dala hu usko use kyo nhi kr r hai ?',
#   ' bsdike sun',
#   ' 3 din hogya hai whi kr r hu smjh nhi aa r hai',
#   ' pura webpage bna lia hu',
#   ' but site mei aa nhi r hai'],
#  [' abe ese mt bol',
#   ' rat rat jg ke bnaya',
#   ' or end mei',
#   ' dikh hi nhi r hai'],
#  [' sab kr lia mai',
#   ' pta nhi prblm kaha hai',
#   ' bs readme.md ka contents',
#   ' dikh r hai',
#   ' hogya',
#   ' uske alwa kch nhi'],
#  [' ha'],
#  [' 😒madarchod fork kr le'],
#  [' ruk public kr deta hu', ' ab dekh', ' abe dekha ?', ' abe'],
#  [' private kr dia hu abhi',
#   ' kam chal r hai uspe',
#   ' elements overflow wala prbln',
#   ' prblm*'],
#  [' tere ko', ' chiye', ' kya ?', ' fork kr le'],
#  [' id ???'],
#  [' abe wo id ', ' mtlb wo part ko access krne ke lia', ' css mei'],
#  [' hoga be',
#   ' #tribute-link',
#   ' krke',
#   ' rhta hai css mei',
#   ' #tribute-link {'],
#  [' fork kia hai kya usko?'],
#  [' bsdike', ' chori mt kr', ' give me some respect', ' fork krke use kr'],
#  [' acha',
#   ' webpage wla pe mai overflow',
#   ' prbln se preshn hogya hi',
#   ' hu*'],
#  [' usko',
#   ' dekh r hu',
#   ' 200 lins html mei',
#   ' 300 lines css ka',
#   ' framework use krne se easy rhta hai kya ?',
#   ' abe kkrh ?',
#   ' tu?'],
#  [' grp dekh',
#   ' devblin.codes',
#   ' open in pc for better experince',
#   ' mobile mei bhi khol skta hai but bahut chota lg r hai',
#   ' missed voice call',
#   ' prjct',
#   ' pe kch kia ?',
#   ' aage?'],
#  [' ok'],
#  [' ha update kia hu'],
#  [' hackermode khel', ' ke', ' hackermode'],
#  [' ha'],
#  [' ha task hai kahe ki 😂',
#   ' abe thik se chala ?',
#   ' hackermode ?',
#   ' normal mode ?'],
#  [' 😂jo game bnaya hu usme 20% html .....40% css.....40% js hai',
#   ' bahut',
#   ' sahi',
#   ' language hai'],
#  [' ha'],
#  [' js dom  pdh lia ?'],
#  [' ohf',
#   ' yhi to main hai',
#   ' mere ko bhi',
#   ' induction strt hone se phle',
#   ' ye',
#   ' js',
#   ' psnd nhi tha',
#   ' programming lang typ hai krke'],
#  [' ha', ' yhi sn', ' to hai'],
#  [' ha',
#   ' 🤦🏻\u200d♂️',
#   ' dynamic',
#   ' bnane mei kam ata hai',
#   ' jo tera',
#   ' bina life ke',
#   ' page rhta hai',
#   ' usko life',
#   ' dene ka kam',
#   ' krta hai ye'],
#  [' bol'],
#  [' abe', ' 🤦🏻\u200d♂️'],
#  [' kisme', ' se pdh r hai ?', ' tu ?', ' konsa site hai yw ?'],
#  [' dekh mai 7 din se kam kr r hu task pe to mere ko js use krne sahi dhng se ajata hai',
#   ' tu humre',
#   ' prjct pe',
#   ' kam krne',
#   ' ki kosis kr',
#   ' sikhte jyga tu',
#   ' mera mentor yhi bol r tha',
#   ' mtlb jb task mila tha to'],
#  [' mann ke tere ko', ' kisi', ' element ko', ' chupana hai'],
#  [' wo element ka class mann le *game* hai',
#   ' to fir',
#   ' tu chahta hai jb tk',
#   ' window',
#   ' load na ho',
#   ' ya kisi button ko use krke',
#   ' usko visible krna hai to'],
#  [' btn.onclick = function(){'],
#  [' nhi',
#   ' isme kya ho r hai ki',
#   ' btn ek button ka object model hai mtlb button nam ka ek elment',
#   ' hai kahi pe',
#   ' html mei',
#   ' tu usko',
#   ' click kia',
#   ' to isme jo function hai wo hoga',
#   ' andr function ke hissb se',
#   ' "game" class ka display property "block" mei chnge krna hai',
#   ' jiske wjh se tere ko wo element dikga button click krne pe',
#   ' ese hota hai',
#   ' code chiye to apan discussion krenge 25 ke bd',
#   ' humre game ke logic pe',
#   ' kahe ki easy hai uske lia code likhna'],
#  [' ha bol r hu game pe kam kro aram se sikhenge', ' js apan'],
#  [' mzk mei mt lena ',
#   ' apan locally scores save bhi kr pyenge apne game mei',
#   ' js  script language hai isly easy hai bahut'],
#  [' thoda basic pdh le'],
#  [' what ?'],
#  [' abe ye uncle aunty hai kya ?',
#   ' abe',
#   ' uncle ka',
#   ' shirt pant',
#   ' mst lg r ha8',
#   ' combination',
#   ' style'],
#  [' ha tu hi c reh gya'],
#  [' abhi ?', ' mtlb ?', ' kya hua ?'],
#  [' abe mtlb abhi present mei admit hai kya ?', ' to tu ja r hai ?'],
#  [' apollo ?', ' mere ghr'],
#  [' ajata'],
#  [' raste mei pdta hai'],
#  [' ha thik ha to', ' ajata', ' wps', ' ghr'],
#  [' thik hai'],
#  [' ....', ' ?', ' kb ?'],
#  [' 🤦🏻\u200d♂️', ' kb ja r hai gaon ?', ' bro ?'],
#  [' tu thik hai ?'],
#  [' 😯😯😯😯'],
#  [' maine group mei mtlb github wla grp mei',
#   ' dal dia hai code',
#   ' jyda kch nhi hai',
#   ' ek div elment hai yellow uske andr red wala ek element hai',
#   ' jo move kr r hai',
#   ' eventlistener rkha hu uss red box mei',
#   ' MediaShared'],
#  [' hai kon ye ?'],
#  [' 😯', ' fok', ' bapre', ' kya bt hai'],
#  [' nhi be 😂 mere se ye sb nhi hota',
#   ' but acha',
#   ' bola tu',
#   ' 👏🏻',
#   ' or abhi',
#   ' kya kr rha hai ?'],
#  [' abe thoda practice bhi kiye kr ipython shell mei',
#   ' bhej de😂',
#   ' wo jo pdhata hai uske sth experiment wgra kr liye kr to sahi rhega',
#   ' bs pdhte mt ja',
#   ' koi fyda nhi hai fir',
#   ' krta hai ki nhi practice ?'],
#  [' thik hai kr lena',
#   ' kya',
#   ' kar',
#   ' rha h ?',
#   ' hey',
#   ' brosdikw',
#   ' missed voice call',
#   ' abe',
#   ' ek',
#   ' bt puchna hai mere ko',
#   ' agr tu',
#   ' free hoga',
#   ' to',
#   ' msg kr dena',
#   ' pls'],
#  [' oye',
#   ' ye kya',
#   ' hai',
#   ' mobile',
#   ' hath mei',
#   ' rkhta hai',
#   ' to bhi',
#   ' call',
#   ' nhi uthata hai'],
#  [' to mai konsa muh se bolta mai i jst want attention kr r tha',
#   ' abe mere ko n',
#   ' agr kisi',
#   ' profs',
#   ' ke under',
#   ' mtlb',
#   ' mere hi collg ke',
#   ' uske under kam',
#   ' krna hai',
#   ' to',
#   ' kese approach',
#   ' kru',
#   ' prof ko ?'],
#  [' tell tell', ' acha agr', ' wo', ' prof', ' mera mentor', ' hai to ?'],
#  [' koi', ' fyda hai ?'],
#  [' kya ? fyda ?'],
#  [' ok', ' or sun', ' wo jo prof hai'],
#  [' uska profile bahut tgda hai', ' machine learning', ' computer vision'],
#  [' ke field mei',
#   ' or apun ko uske under kam krne ka hi hao',
#   ' but dikkat ye hai n ki mere ko knowledge hi nhi hai'],
#  [' kya likhu ?'],
#  [' to uske sth phle discuss kru ?'],
#  [' ya fir apne', ' ideas du ?', ' or bt kru ki', ' ispe kam krna hai ye wo'],
#  [' ok'],
#  [' ok', ' ok ok '],
#  [' ok', ' got got it'],
#  [' ha'],
#  [' ok to', ' kya bt chal ri hai ?', ' fir ?', ' acha'],
#  [' acha acha smjha',
#   ' ruk ek min',
#   ' ha abhi tu iot pe kr r hai n projct ek ?',
#   ' to wo tu prof ke under kr r hai',
#   ' n ?'],
#  [' konsi 🧐', ' sahi rhega fir to internship bhi kr pyga 😯'],
#  [' 🥺', ' 😯', ' acha oppurtunity hai'],
#  [' tu akela nhi hai be', ' logo ke job gye'],
#  [' internshio',
#   ' internship tk',
#   ' gye',
#   ' tu',
#   ' hackerrank',
#   ' use krta hai?'],
#  [' mere ko', ' pta chala ki', ' hackerank apne yha', ' ka', ' startup hai'],
#  [' agya hai bsp ?', ' bol'],
#  [' to tu kya chah r hai ?'],
#  [' abe ek bt bta', ' chal dpge', ' doge', ' fir aunty'],
#  [' akele kese', ' rhengi ?'],
#  [' tere ghr ke ps relatives hai ?'],
#  [' fir bhi', ' badi bt to hai'],
#  [' to wo', ' dur hai be', ' kitna', ' tum log'],
#  [' mangla side rhte ho',
#   ' too tougj',
#   ' mai bachpan mei',
#   ' mumy mai mera bhai',
#   ' bs rhte the',
#   ' to',
#   ' mumy ko bekar lgta tha'],
#  [' or tu log bhi chal doge'],
#  [' ana bhi pdega', ' tere ko', ' to', ' sunday', ' vibha ko', ' bhi'],
#  [' but tere ko krna pdega', ' n'],
#  [' i advice you to do this ', ' can'],
#  [' or vibha kya krti hai ? ajkal ?', ' wo kesi hai ?', ' abhi ?'],
#  [' exam ?', ' google form mei ?'],
#  [' cheating krna possible rhta hai kya ?'],
#  [' ha wo to hai', ' or udhr bahar nikal rhe hai kya log ? tere ghr side ?'],
#  [' hair ka hi pta chalega'],
#  [' abe',
#   ' bahut',
#   ' banjar',
#   ' jindagi',
#   ' lg rhi hai',
#   ' abhi',
#   ' jb bsy rhta hu',
#   ' to',
#   ' pta nhi chlta hai',
#   ' idhr udhr krta hu to yad ata hai',
#   ' kch nhi kr skta abhi',
#   ' ghr bethe bethe pagal ho r hi',
#   ' hu',
#   ' mai 2 din se 1 obstacle ke logic pe kam kr r hu',
#   ' pura',
#   ' circle',
#   ' ka',
#   ' concept use kr lia mai'],
#  [' but its tough',
#   ' nind nhi ata hai',
#   ' sote tym sochta hu sala ye krung ye krunga ye idea krta hu',
#   ' esa krte krte',
#   ' 4 bj jata hai',
#   ' fir late uthata hu'],
#  [' tera', ' class', ' chal rha hai', ' kya ?'],
#  [' abe mera'],
#  [' eg ka', ' class hota hai'],
#  [' or madam attendance bhi',
#   ' leti hai',
#   ' kahe ka nice',
#   ' 2 hrs',
#   ' bethna pdta hai'],
#  [' uppr se attendance',
#   ' or uppr se',
#   ' wo bich bich',
#   ' mei bolti hai',
#   ' kcj explain krne ke bd',
#   ' why only i student responding',
#   ' what about others',
#   ' fir sab bhed bakri type',
#   ' yeah yeah',
#   ' krte hai',
#   ' or 2-3 log to sbse jyda bolte hai'],
#  [' unki awaj chubhti hai', ' kan mei', ' mere'],
#  [' abe',
#   ' hum',
#   ' uss madam ko',
#   ' sbse bdi',
#   ' c',
#   ' smjhte th',
#   ' the',
#   ' kahe ko',
#   ' sb bde wale',
#   ' profs',
#   ' jo the',
#   ' har mann gye',
#   ' online class ke lia',
#   ' but wo hai ki',
#   ' consistencely',
#   ' 3 classs le chuki hai',
#   ' bakayda',
#   ' jo absent rhta hai',
#   ' uska absent kregi',
#   ' or to',
#   ' dont give proxy',
#   ' i heared this voice again',
#   ' ka',
#   ' hua',
#   ' be',
#   ' bhai ?',
#   ' ',
#   ' kya hua be tere ko',
#   ' rply nhi de r hai'],
#  [' u',
#   ' should',
#   ' rply',
#   ' 2-3 hi logo ke',
#   ' msg ate hai bs mujhe',
#   ' usme',
#   ' tu bhi',
#   ' rply nhi',
#   ' dega',
#   ' to',
#   ' kese chlega',
#   ' be'],
#  [' zbro'],
#  [' bol', ' bol bol bol', ' bol'],
#  [' ae', ' ungli mt dikha', ' abe', ' sun', ' be'],
#  [' ka', ' ka r r hai', ' ?'],
#  [' kya krta hai be dinbhr ?', ' too much busy ?', ' nowadays ?'],
#  [' nice', ' uthata kb hai tu ?', ' subhe'],
#  [' thik hai'],
#  [' we will be coming morning not tommorow', ' nhi'],
#  [' is it okay for uh ?'],
#  [' abe', ' apan', ' algi ki algo', ' agli', ' subh3', ' ayenge', ' bol r hu'],
#  [' tere ko chlega ?'],
#  [' esa puch r hu', ' 8 bje as ps ayenge due to lockdown timmings'],
#  [' ok',
#   ' abe',
#   ' mai arish',
#   ' ayenge',
#   ' bol re',
#   ' the',
#   ' hai*',
#   ' kal',
#   ' to tere ko',
#   ' chlega !',
#   ' ?',
#   ' koi prblm ho to bol',
#   ' skta hai'],
#  [' sorry', ' bro'],
#  [' sale', ' sorry', ' likha hu', ' usme', ' kya kya'],
#  [' abe ane wale the n', ' apan', ' but meri wjh', ' se nhi aa', ' paye'],
#  [' yes'],
#  [' no bro'],
#  [' are'],
#  [' mai 6 bje uth gya tha',
#   ' nikal hi r tha',
#   ' fir scooty mei fss gya',
#   ' abhi leke gye hai bnwane ke lia'],
#  [' ha'],
#  [' kaha ?', ' verzeo ?'],
#  [' ohfo', ' to bn gya hai', ' ?', ' tum log ka', ' prjct ?'],
#  [' oho', ' 🙄', ' kya ?', ' mere ko abhi tk smjh nhi aya hai ye'],
#  [' oho',
#   ' 🤦🏻\u200d♂️',
#   ' ok got iy',
#   ' it',
#   ' ye roller coaster ka physics hai',
#   ' mtlb math wala part'],
#  [' haa'],
#  [' mai tere se math m aage rha hu bsdike', ' 😒😒😒'],
#  [' calculus ke lia apun ne 1 month chutti mari thi school mei'],
#  [' are ye roller coaster wala'],
#  [' track dekh k smjh aya ki',
#   ' acha',
#   ' graph',
#   ' to tum log rolercoaaster',
#   ' bnane',
#   ' wale',
#   ' ho',
#   ' kya',
#   ' ?'],
#  [' abe  sun', ' infinity sign'],
#  [' path ka', ' equation', ' hai kya ?'],
#  [' wtf', ' kaha se', ' itni jldi', ' sahi hai kya ye ?', ' 😳'],
#  [' 😳',
#   ' 🙄😳😳😳😳',
#   ' ye link bhj to',
#   ' site ka',
#   ' sb shape bna skte hai kya isse ?'],
#  [' bsdike', ' pta to ho ki function hai kya'],
#  [' abe sun', ' ubuntu ka', ' sapce', ' space', ' bdha skta hu kya ?'],
#  [' 😂', ' nhi', ' mar jaunga  ye sb krunga to'],
#  [' ha',
#   ' abe mai',
#   ' dekha tha',
#   ' partition',
#   ' ka',
#   ' pta nhi kya kya tha',
#   ' abhi recelty mrra ubuntu ajib',
#   ' behave',
#   ' kr r tha',
#   ' terminal',
#   ' gyab',
#   ' desktop gyab',
#   ' bs app dikh r tha'],
#  [' bs python uninstall kia fir', ' ho r tha'],
#  [' 🙄', ' mtlb?'],
#  [' mai bhi', ' kia tha', ' fir mai uninstall kr dia', ' 😂'],
#  [' abe mere mei terminal hi nhi tja', ' exist hi nhi kr r tha', ' tha*'],
#  [' abe sun to fir'],
#  [' restrt kia tha mai to',
#   ' black screen mei',
#   ' dikha r tha ki',
#   ' kch delte krna hai',
#   ' ye wo',
#   ' to mai sb kia',
#   ' to',
#   ' ubuntu',
#   ' firse',
#   ' install kia tha mai syd',
#   ' to fir thik hogya'],
#  [' ha abhi to thik ha8',
#   ' hai*',
#   ' naya version chal r hai',
#   ' but files sb safe tha',
#   ' jaha tha',
#   ' sb whi tha'],
#  [' kya hua ?'],
#  [' audio on krke khlna', ' abe kya hogya ?', ' whts the prblm', ' ?'],
#  [' abe wo task', ' ka tha be', ' mera'],
#  [' task2',
#   ' khel k dekh',
#   ' abe to mai bhi nhi de pa r hu delta ke tasks ke wjh se'],
#  [' ye bt alg hai', ' tu bhi pdh hi r hai'],
#  [' kya hai ye ?'],
#  [' kiska?'],
#  [' significan kya hai iska?'],
#  [' ohfo', ' phli bar suna dekha mai to'],
#  [' esa grpah', ' ...'],
#  [' ha',
#   ' abe mtlb isse kya pta chlega apan',
#   ' ko',
#   ' ese type ke',
#   ' graphs se?'],
#  [' acha pta chal gya',
#   ' box plot jesa hota hai',
#   ' bs',
#   ' ye probability density bhi dikhata hai'],
#  [' esa kch likha hai'],
#  [' ha to'],
#  [' acha '],
#  [' box ploy', ' box plot pta hai ?', ' or denisty  plot?'],
#  [' ha to ye inn dono ka combination hai',
#   ' ab smjh de mere ko',
#   ' ki fyda  kya',
#   ' hua'],
#  [' ok ok to prediction hai ki 60-80 ke bich ho skte hai ? agr test data',
#   ' dalega to?'],
#  [' ok', ' abe sun', ' verzeo', ' ka kesa'],
#  [' lg r hai', ' tere ko', ' ye ml', ' wala?'],
#  [' ha mai soch r tha ki coursera mei koi sa course kr lu',
#   ' ml pe',
#   ' uska fees nhi dia hu',
#   ' n abhi',
#   ' ml wala'],
#  [' using python ?', ' hai ?', ' ha isly to tere se pucha'],
#  [' ha', ' ???'],
#  [' abe but mai dekha tha wo octave mei', ' krata hai'],
#  [' fok', ' mai dekha nhi'],
#  [' 🥵', ' ok'],
#  [' ha octave wala h'],
#  [' ha',
#   ' or koi course dhyn mei hai tere?',
#   ' jisme python ho',
#   ' abe',
#   ' how to go pro',
#   ' in data science',
#   ' wala link',
#   ' mila kya tere ko?'],
#  [' milga to', ' mujhe', ' bhi', ' bhj dena'],
#  [' email'],
#  [' abe', ' tu', ' cmmnt kia tha n', ' yes email id', ' esa krke'],
#  [' ek min'],
#  [' MediaShared'],
#  [' ye tere tha ki wo c ldki bhi cmnnt ki hai'],
#  [' oops sry mere  ko', ' wo', ' chinese ldka tu lga'],
#  [' ok', ' khrid', ' lia', ' mai', ' bhi', ' gtav'],
#  [' attitude', ' ki', ' dukan', ' kis bt ka attitude hai didi ko', ' 😯'],
#  [' tu ka kr  hai',
#   ' ?',
#   ' rhene de',
#   ' tu bhi na btaya kr kch',
#   ' ese log ko'],
#  [' abe', ' bol'],
#  [' 😯', ' abe kch krte hai be', ' something interesting'],
#  [' abe'],
#  [' 😂abe', ' ye', ' 150 rupiya dega wala', ' status', ' sahi hai tera'],
#  [' 😳', ' mai bhi kr leta hu', ' kch idea de', ' wo totla ka rkh lu kya ?'],
#  [' usko wo chote height wala', ' kon tha', ' 25 din mei pesa double wala'],
#  [' ha iska', ' 😂', ' dekh ab', ' 😂'],
#  [' kya ?'],
#  [' ab'],
#  [' ha whi soch r hu', ' la baba 5 crore ?'],
#  [' 😂',
#   ' https://devblin.codes',
#   ' abe ye dekh be',
#   ' pura responsive bnaya hu iss bar page ko'],
#  [' to bna le'],
#  [' abe to page hi to bnana', ' hai'],
#  [' to mai bs html css hi use kia hu'],
#  [' no',
#   ' no js',
#   ' only html css',
#   ' abe mere page ke niche pdhna credit dia hu',
#   ' 😂',
#   ' madw with html css',
#   ' https://html5up.net/',
#   ' isme dekh le ye sb html',
#   ' ae',
#   ' kachra seth'],
#  [' dekha isko?'],
#  [' ha to', ' idea dene ke lia', ' ludo'],
#  [' ha but bahut sara rhta hai', ' unka code'],
#  [' bol', ' bol na', ' bsdikhe'],
#  [' kya nhi mila ?', ' 😯dub ja', ' ek glass pani leke'],
#  [' iya'],
#  [' kya hogya'],
#  [' hai be', ' tere ko', ' kya chiz ?'],
#  [' acha  koi ek template choose kr or mere ko bhj'],
#  [' link bhjna'],
#  [' to tere ko code chiye uska ?'],
#  [' bsdike ', ' wo to blogger', ' ka template lg r hai'],
#  [' acha sry',
#   ' abe simply',
#   ' download kr',
#   ' download button dikh r hoga n',
#   ' usse ek zip file milega usme',
#   ' sab hai',
#   ' bs apne hissb se content chnge krna pdega tere ko',
#   ' then you r ready to go',
#   ' template whi hai'],
#  [' wtf',
#   ' MediaShared',
#   ' ho kya gya hai be tere ko',
#   ' dinbhr kya krta hai ?'],
#  [' laptop?'],
#  [' kaha h ?', ' abe 15-20 min ka  kam hai', ' isse page ready krna'],
#  [' koi acha sa dekh k bna le'],
#  [' ha', ' abe', ' kya', ' kar rha h', ' bhai bt kr mere se'],
#  [' feeling low nowdays'],
#  [' kch krne ka',
#   ' mnn nhi krta be',
#   ' agr krne ka sochta hu to',
#   ' kese krunga',
#   ' kch ata hai nhi'],
#  [' wo sb vhor'],
#  [' abe mai', ' kch'],
#  [' notable krna',
#   ' chahta hu',
#   ' idea ga9',
#   ' hai*',
#   ' but',
#   ' pta nhi',
#   ' mnn krta nhi hai kyoki',
#   ' ata hai nhi',
#   ' kch mere ko'],
#  [' uea', ' yes', ' ek chat bot bnana hai', ' taki uske sth mai bt kr sku'],
#  [' abe',
#   ' mera',
#   ' idea hai n',
#   ' usme n',
#   ' mai jo',
#   ' whtsapp ke',
#   ' chats hai',
#   ' usme se',
#   ' export krunga chat ko',
#   ' as a',
#   ' training data',
#   ' to fir mer chatbot usse sikhega',
#   ' or fir syd'],
#  [' natural bt kr pau', ' ha bol'],
#  [' to'],
#  [' bol'],
#  [' abe nhi be', ' mere ko'],
#  [' whi krna hai', ' jo mai socha hu'],
#  [' tu log', ' krega kya'],
#  [' yhi chatbot wala'],
#  [' bsdike', ' ek prjct', ' pending hai abhi tk'],
#  [' kya ha', ' team', ' kya pta ye prjct startup bn jaye', ' chatbot wala'],
#  [' co-founder bn jyenge tino',
#   ' ha to kese krenge',
#   ' arish pubg khlte',
#   ' rhta hai'],
#  [' grp mei aa',
#   ' tu soch',
#   ' potential hai',
#   ' isme',
#   ' mere hissb se',
#   ' hai ki nhi bta ?'],
#  [' bsdike potential', ' mtlb potential', ' hota hai'],
#  [' idea', ' idea', ' bol', ' be', ' bol'],
#  [' 😂',
#   ' fok',
#   ' mam',
#   ' man',
#   ' fok',
#   ' 🥵',
#   ' 🤦🏻\u200d♂️',
#   ' kya',
#   ' tu',
#   ' jag rha hai'],
#  [' abe',
#   ' ye verzeo ka',
#   ' major prjct mila hai',
#   ' usko mai',
#   ' kese kru',
#   ' mtlb',
#   ' kch log bol re hai ki kam bat lete hai wgra wgra'],
#  [' 2 din phke'],
#  [' chutuye', ' tera', ' ml', ' wla h'],
#  [' pta hai', ' ka', ' kr r hai be', ' missed voice call'],
#  [' online bulane ki ninja technique',
#   ' abe',
#   ' ka kr r hai',
#   ' be',
#   ' bhai mere',
#   ' se',
#   ' to bt kiye kr',
#   ' tu hi hai sahara abhu',
#   ' abhi'],
#  [' ka kar r h tu?'],
#  [' missed voice call', ' abe'],
#  [' abe',
#   ' prof',
#   ' ko',
#   ' mail',
#   ' kia tha mai',
#   ' to rply m wo bola ki',
#   ' pde pdgo',
#   ' pdho*',
#   ' for oct m bt krega research prjct pe'],
#  [' partial differential eq.'],
#  [' abe sun be', ' wo prof ko', ' rply kese du ?', ' jldi bol be'],
#  [' abe ek min',
#   ' tere ko bhjta hu',
#   ' pura',
#   ' tu pdh ke',
#   ' btana',
#   ' abe esa nhi ki bs oct mei bt krenge iske bare mek',
#   ' wo bola ki',
#   ' advance books wgra dekho',
#   ' ye wo',
#   ' abe',
#   ' sun',
#   ' be',
#   ' ja',
#   ' ka',
#   ' kar rha h ?'],
#  [' bol bhai ka krya hai'],
#  [' kya', ' hua', ' bol'],
#  [' 😏tere se phle ka update kr chuka hu'],
#  [' online', ' hi', ' jaha', ' kaha', ' rhta hu mai'],
#  [' 1 bje to soke utha hu aj',
#   ' baki coursera',
#   ' or prjct kr r tha verzeo ka'],
#  [' tu', ' ka', ' krta ha', ' hai', ' be'],
#  [' or?', ' MediaShared', ' jldi grp mei aa'],
#  [' chk krke dekh', ' kon hai', ' mere  ko to nhi pta', ' kya msg aya hai ?'],
#  [' oh', ' ye to', ' wo hai', ' linkedin wali'],
#  [' mere ko bhi ki thi'],
#  [' kyo ?'],
#  [' m', ' a', ' cbsdi', ' bsdhike', ' bsdike'],
#  [' abe', ' sun'],
#  [' guu kha le bhosdike', ' zeher walo', ' kheet bhi', ' kha', ' le'],
#  [' kha le', ' na'],
#  [' abe shriya btech'],
#  [' bs likhi hai', ' btech + mtech', ' likhna', ' chiye tha', ' usko'],
#  [' ha', ' uska acc. dekhna', ' btech 2019 - 2024'],
#  [' sirf btech likhi hai bol r hu mai'],
#  [' MediaShared', ' testing backend thing'],
#  [' bsdike *about* pdhne bola tha', ' g andhe'],
#  [' bsdike',
#   ' test kr r hu',
#   ' chi',
#   ' tu',
#   ' filter',
#   ' use krta hai',
#   ' b',
#   ' s',
#   ' d',
#   ' i',
#   ' k',
#   ' e',
#   ' l',
#   ' d',
#   ' k',
#   ' i',
#   ' y',
#   ' o',
#   ' wa',
#   ' le',
#   ' shok',
#   ' k',
#   ' bse',
#   ' pal r ha'],
#  [' mai',
#   ' bsdikw k',
#   ' ka',
#   ' kr  rha',
#   ' yai',
#   ' hai',
#   ' gurlfrand',
#   ' dhundh',
#   ' lia gai',
#   ' kya',
#   ' ajkal',
#   ' itna',
#   ' bt krta hau'],
#  [' abe', ' sun ve', ' be'],
#  [' abe bittu ke papa',
#   ' ajib',
#   ' behave',
#   ' kr rhe hai',
#   ' marne warne',
#   ' ki bt kr re hai'],
#  [' bolte hai *mera akhir tym agya hai*',
#   ' ghr mei sbkoo preshan krne se acha to yhi hai ki chal du'],
#  [' 😰'],
#  [' nhi ',
#   ' koi reason nhi hai ese pine ka',
#   ' bittu bolti hai ki koi baba bola tha ki uske papa pe koi kala jadu kr diye hai syd uss wjh se'],
#  [' bhai wo kch month phle car lene wale the but bittu mna kr di thi',
#   ' pese',
#   ' ka koi',
#   ' prblm',
#   ' nhi lgta mujhe'],
#  [' to kya krna chahiye ? psychatrist ke pss bhja jaye ?',
#   ' abe ',
#   ' khana bhi',
#   ' nhi kha re hai',
#   ' kch month  phle maze mei the'],
#  [' ka hogya?',
#   ' abe',
#   ' sun',
#   ' bsdike',
#   ' kal',
#   ' badmintom',
#   ' khelenhe',
#   ' subhe',
#   ' mai jldi so jaunga',
#   ' aj pakka',
#   ' tu bhi jag jana',
#   ' nehru chowk ke pss ke park mei',
#   ' badmintom',
#   ' kaha bsy hai',
#   ' ?',
#   ' seen to kr be',
#   ' tu bahut badal',
#   ' gyi hai',
#   ' re chinmi',
#   ' chinki',
#   ' chintu',
#   ' hadd hai',
#   ' wtf',
#   ' u r cordssing'],
#  [' bsdike msg pdh le', ' pura'],
#  [' le ana'],
#  [' mere pss hai but colg mei to mai nhi la r', ' arish ke pss', ' ha9'],
#  [' khelne lyk hai?'],
#  [' le ana'],
#  [' are arish ka', ' bhai', ' bhi to hai'],
#  [' nhi',
#   ' ayega',
#   ' be',
#   ' arish ka bhai',
#   ' wo bola ki',
#   ' round mei khelnge',
#   ' 2 log',
#   ' fir 2 log',
#   ' or net nhi hai'],
#  [' ha be'],
#  [' 🤣',
#   ' ek min',
#   ' puchne de',
#   ' hona to chiye',
#   ' hoga be',
#   ' ;@',
#   ' ha hai',
#   ' wo bola',
#   ' tere pas',
#   ' cock',
#   ' hoga',
#   ' to le ana',
#   ' 🤣'],
#  [' missed group voice call',
#   ' bsdike abhi yad aa r hai tere ko bdy',
#   ' uncle ka'],
#  [' oh'],
#  [' 👍🏽'],
#  [' happy bdy mere trf se bhi uncle ko', ' apna site host kr r hu'],
#  [' taki tum log use krke dekho', ' kya fock?'],
#  [' usme kya bada kam', ' db bnao', ' or hosting se hos tkr do'],
#  [' jldi aa',
#   ' MediaShared',
#   ' bs grewal ka laplace transformation wlaa chapter ka solution hai',
#   ' ki nhi tere psss',
#   ' ?',
#   ' aj submit krna hai assignment dhundh de be',
#   ' solution dila de'],
#  [' ata hai tere ko', ' laplace?'],
#  [' kr de bhai tu bhi post', ' father day la', ' ka'],
#  [' 👍🏽', ' u shit mot rply', ' rplying', ' egoist'],
#  [' to ?', ' mai kya', ' kr skta hu', ' isme'],
#  [' kidhr?'],
#  [' oh', ' nhi', ' chlata mai', ' bhai', ' instagram'],
#  [' abe', ' acc.', ' nhi hai', ' mere pss'],
#  [' ha to pichle sal hi kr dia tha'],
#  [' sst hi bhj de na lodu', ' 🙄', ' wtf'],
#  [' 🤨insta bhi incoginuto?'],
#  [' DeletedMsg'],
#  [' DeletedMsg', ' bsdike'],
#  [' bsdike'],
#  [' ka bol',
#   ' boli',
#   ' be',
#   ' tu',
#   ' bta',
#   ' ka kr rhai',
#   ' itni',
#   ' rat ko',
#   ' kya be',
#   ' tera',
#   ' numbr',
#   ' coverage',
#   ' chrtra se',
#   ' bahar',
#   ' bta r hai'],
#  [' kya nhi',
#   ' 2 bar call kia mai',
#   ' tu kia rha tp',
#   ' to*',
#   ' kidhr gya tha?'],
#  [' kiska ghr hai ?', ' bilha m?'],
#  [' ok or call', ' kahe kia tha ?'],
#  [' thik hai',
#   ' or tera car predicition wala model use kese krte hai ?',
#   ' or tu log function use krte ho ? sicktlearn ? pandas mese ? or code likhte ho ?',
#   ' mere ko bhi sikha de thoda'],
#  [' ha but nhi krta hu mai usko',
#   ' nhi hai',
#   ' pdhne ka',
#   ' isly puch r ju',
#   ' hu',
#   ' mere ko insect classify krne wala model bnana hai',
#   ' mtlb mai photo lu insect ka or mere ko pta chal jaye ki ye hai konsa insect',
#   ' ya esa kch',
#   ' to kese krunga ye mai?'],
#  [' ha yhi to bta hai n bsdike',
#   ' ese hi sikte gai',
#   ' to or kch prerequisites?',
#   ' hai kya ?',
#   ' ki chalu kr du ?',
#   ' bol na bsdike',
#   ' gali',
#   ' gloch',
#   ' psnd nhi mere ko',
#   ' bolega'],
#  [' acha ye to ata hai',
#   ' plot krke ye pta chlega n ki mera model kesa kam kr r hai ?',
#   ' eda ?',
#   ' kya hota hai?'],
#  [' ok ok ...', ' kya bt', ' hui be', ' tere senior se', ' any imp info?'],
#  [' thik gai'],
#  [' startups mei intern krne ka fyda to hota hai ye mai pdha tha',
#   ' mere dhyn mei kch startups hai ai pe ... haptik lekin yha kese lete hai idea nhi hai'],
#  [' ha pdh lia', ' abe ye to', ' sde hi', ' krta hai'],
#  [' abs mtlb  tu pucha kyo nhi ki',
#   ' cloud ke bare mei',
#   ' kahe pdhna hai ?',
#   ' mtlb janna hai'],
#  [' oh ok..cloud isly bola hoga kahe ki ajkal sab data cloud pe rhta hai'],
#  [' inka nam kya hai ?'],
#  [' ae', ' lodu', ' ludo*', ' kjelga?'],
#  [' chepli',
#   ' kahi ki',
#   ' lodu kgel r gai kya',
#   ' ?',
#   ' oh ab',
#   ' smjh aya',
#   ' adha tym',
#   ' tera mobile hang ho jata hai',
#   ' isly lgta hai ki tu bsy hai😂',
#   ' ae indian guy',
#   ' wamt abusive wrds',
#   ' to get pressurizrd in your ear drums?',
#   ' bol na',
#   ' ludo',
#   ' abhi ldki msg ki hoti to...',
#   ' *ha bolo mai to free hu*',
#   ' *sun r hu bolo*'],
#  [' kha', ' kya?', ' laude', ' bol na'],
#  [' to google pe dekh ye ajib chiz kya hai'],
#  [' ha', ' mai chnge kia tha'],
#  [' kya dekhu?'],
#  [' randy orton kyo',
#   ' bn r hai',
#   ' wo',
#   ' kya',
#   ' hogya',
#   ' be',
#   ' call kahe kia th',
#   ' a?',
#   ' missed voice call'],
#  [' ha to?🙄', ' bolega ?'],
#  [' kya kch nhi ... bsdike puri bt to bol'],
#  [' ha to de d', ' de* usme  kya h'],
#  [' koi ldki hoti to bolta kch kch😂🤣😂'],
#  [' depends on girl'],
#  [' ??? kb ???', ' bhai?'],
#  [' acha....',
#   ' mai to nhi khichaya tha',
#   ' ab khinch di thi',
#   ' bina btaye to meri kya glti h'],
#  [' wtf', ' ?'],
#  [' ye kon'],
#  [' ye kon de dia', ' tere ko?'],
#  [' kb ka hai ye ???'],
#  [' bhai mai esa kam bikul nhi krta'],
#  [' apna photo',
#   ' share wala',
#   ' apni dp tak',
#   ' nhi lagata mai',
#   ' to photo post',
#   ' kaha se krunga ?'],
#  [' ave', ' abe'],
#  [' ye kb ka hai???', ' ye btayega ?'],
#  [' ???'],
#  [' acha ? 🙄🙄🙄'],
#  [' 😂', ' acha tere ko jalane ke lia'],
#  [' bhja rha hounga'],
#  [' wo bt alg hai'],
#  [' 70677', ' nitin hai kya ?'],
#  [' backdhoi', ' kr r hai'],
#  [' kya nice', ' laude tu', ' 1 din', ' bd rply', ' krta hai'],
#  [' kch nhi bs ldki bnne ki kosis kr r tha'],
#  [' abe'],
#  [' bol r hu usko mai ki', ' trichy ajana', ' tu bhi'],
#  [' wo bol r hai',
#   ' ki nit kyga',
#   ' jyga*',
#   ' btaya usko mai ki apun depression mei rha'],
#  [' 90 se uppr'],
#  [' haaa'],
#  [' ha bhai', ' trichy mil jyga usko'],
#  [' usko bs mai itna bola ki',
#   ' baki tu bhi usko bol de',
#   ' apne trf se',
#   ' bsdike',
#   ' linkedin',
#   ' mei msg mt kia',
#   ' kr',
#   ' profession jgh hai',
#   ' wo',
#   ' unprofessional kam mt kia kr bsdike',
#   ' ganda admi hai',
#   ' tu',
#   ' isly',
#   ' esa kam krta hai'],
#  [' tu bsdike', ' missed voice call', ' kya', ' be', ' call', ' kyo ki thi?'],
#  [' kisi se nhi', ' mentor se bt krr  tha'],
#  [' doubt'],
#  [' kch nhi',
#   ' mumy ko lga bhinga hu barish mei to mai bola nahi bhinga hu',
#   ' or kch nahi'],
#  [' nahi'],
#  [' •_°     assignment likhna hai'],
#  [' math'],
#  [' symbols', ' abe', ' abe', ' arish ka', ' ststus dekh', ' 🙂'],
#  [' 🖕🏻🖕🏿', ' missed group voice call'],
#  [' kya ?', ' kya hua?'],
#  [' bsdike', ' saram kr le', ' thoda'],
#  [' bho', ' s', ' dike'],
#  [' kaha ?',
#   ' ja rhi hai?',
#   ' bol na',
#   ' laudu',
#   ' laudi',
#   ' tu laudi hai laudi',
#   ' MediaShared',
#   ' bol na',
#   ' bsdike',
#   ' ignore',
#   ' bsdike ab tu msg',
#   ' krna',
#   ' fir mai rply dunga'],
#  [' missed voice call'],
#  [' nhi pta tujhe kch'],
#  [' kya ?'],
#  [' bahut prblm hai bro'],
#  [' bittu ke colony mei'],
#  [' bsdiwali auntiyo ka conspiracy chal r hai',
#   ' bsdike ye ab chor',
#   ' mera to dimag'],
#  [' abe uske papa abhi thik nhi hai thode or office ka kch bt tha',
#   ' to ek bsdiwali aunty',
#   ' pure colony',
#   ' ko jama krke',
#   ' bawal kr di ak',
#   ' aj',
#   ' bittu ki mumy ko suna ke',
#   ' bina wjh'],
#  [' jealous aunty',
#   ' asshole aunty',
#   ' got no chi',
#   ' bcoz bittus dad transfered his husband'],
#  [' to janjgir'],
#  [' to bakchodi kr rhi thi',
#   ' ki',
#   ' kahe lagaye ?',
#   ' kyo lagaye ?',
#   ' bhai kyo kahe kya hota hai',
#   ' sbka',
#   ' tranfer hota hai',
#   ' duty mei',
#   ' but wo aunty ko',
#   ' duty office',
#   ' or personal matter ke bich differnce nhi smjh aya',
#   ' to jst like an illiterate person',
#   ' she came barking',
#   ' with household media'],
#  [' ha whi be...',
#   ' but',
#   ' bitti',
#   ' uske bhai ke bare mei',
#   ' ulta sidha',
#   ' bt kr re the',
#   ' alg se wo log',
#   ' bittu ke ghr ane se phle'],
#  [' kch nhi....wo aunty log ki ye sikhayat thi ki', ' uska bhai bhondu hai'],
#  [' 💁🏻\u200d♂️', ' 12th mei hau'],
#  [' or ye log bittu ke line mei nhi rhte hai piche rhte hai',
#   ' or bittu ko koi frnd btai ki',
#   ' wo log bittu ke',
#   ' bare mei bhi',
#   ' ulta sishda',
#   ' bt kr re the',
#   ' ki koi',
#   ' ldka ata hai',
#   ' maestro mei',
#   ' blabla'],
#  [' wo hi jane', ' abe'],
#  [' ye tk', ' to*', ' arish ko', ' pta hai n?'],
#  [' nhi bolna tha', ' tere kk', ' ko'],
#  [' acha 🙄', ' sahi hai', ' or ka', ' to', ' mnn lia wo?'],
#  [' 😂 point to hai'],
#  [' 😂', ' bapre'],
#  [' abe whi hai', ' bs tu', ' paradox', ' chalne de'],
#  [' 🤨', ' abe', ' doninos', ' kb tk', ' deliver krta hai ?', ' rat ko?'],
#  [' tere kk', ' kese nhi pta', ' ye sb ke bare mei', ' 🤨'],
#  [' abe', ' tu ka krte rhta hai', ' itne rat ko?', ' der rat ko?'],
#  [' kyo?', ' 🙄', ' bsdike log', ' kachra wala', ' smjhenge mere ko'],
#  [' kya m', ' ?'],
#  [' bhag be', ' to usse kya hoga ?'],
#  [' abe krishna wala thik hai logo ko shanti milti hai wo sunk',
#   ' to tu rkh le'],
#  [' to laude ringtone', ' rkh le'],
#  [' bhga be', ' mai nhi krunga', ' change', ' ese'],
#  [' missed voice call'],
#  [' MediaShared'],
#  [' 🙂'],
#  [' devblin codechef search kr le'],
#  [' ye to apun ko nhi pta'],
#  [' chems'],
#  [' abe khlna'],
#  [' hai ki nhi', ' aj ?'],
#  [' wtf is arish', ' where*'],
#  [' 24/25 chemistry ct', ' 😎', ' abe to khelena', ' hai ki nhi', ' lodu'],
#  [' na bhai', ' open book tha', ' google ki help lia'],
#  [' call kr usko',
#   ' mere mei',
#   ' balance nhi hai',
#   ' abe',
#   ' kia ki',
#   ' nhi be ?',
#   ' bol na auntt au kya ghanti mai baju kya',
#   ' sot mai lagu kya',
#   ' 🙂'],
#  [' to', ' ky bola', ' wo?'],
#  [' ha',
#   ' whi kr re hai',
#   ' bsdike',
#   ' uske ghr mei hainwo',
#   ' wo',
#   ' 2 bje se',
#   ' ..',
#   ' missed voice call',
#   ' bsdike tu mere ko rs 100 dene wala tha n'],
#  [' grp pdh*'],
#  [' nhi arish ko de de....usko fir mere ko usko 50 dena hoga'],
#  [' chor mai bhj deta hu usko'],
#  [' paytm nji hai mere  lss',
#   ' ayega to bta dunga',
#   ' nhi aya  hai abj9',
#   ' missed group voice call',
#   ' he is',
#   ' going to meet',
#   ' his gf',
#   ' missed voice call'],
#  [' bsy hai abhi wo call',
#   ' pe',
#   ' shriya bhi',
#   ' bsy hai',
#   ' lockdown kbse hai?'],
#  [' 🤦🏻\u200d♂️',
#   ' ldki ke chkkr mei hum nhi khel pa rhe hai🤦🏻\u200d♂️',
#   ' usko puch aa pyega ki nhi 🤦🏻\u200d♂️'],
#  [' bol'],
#  [' ba', ' khol r hu'],
#  [' email adress', ' dlana pdta hai kya?'],
#  [' puch to r hai', ' or load nhi ho r hai', ' tym le r hai'],
#  [' yhi ho r hai kbse', ' MediaShared'],
#  [' ho skta hai', ' mobole', ' mei', ' kya prblm hai ?'],
#  [' ok'],
#  [' yhi dikha r hai',
#   ' kbse',
#   ' khul gya',
#   ' isme.kia hu jlin',
#   ' join',
#   ' abe aja',
#   ' bsdike'],
#  [' ok',
#   ' abe',
#   ' ae',
#   ' ruk na bhai',
#   ' mai naya hu',
#   ' ake mar dia bs',
#   ' or ko  kon hai?',
#   ' agame mei?'],
#  [' bolega', ' ?', ' or kya', ' krte hai isne ?'],
#  [' konsa ?', ' spooon?'],
#  [' ok', ' ryk', ' abhi mrna mt', ' dekhne de sb'],
#  [' mere pss kese ayegam', ' kese chinunga ?'],
#  [' okkm',
#   ' abe',
#   ' tu leke',
#   ' kese bhag r hai?',
#   ' spoon ?',
#   ' abolega',
#   ' tu pkd ke kese',
#   ' bhag r hai',
#   ' ?'],
#  [' hold kese krte hai?'],
#  [' ok'],
#  [' or bomb kese fekte hai?'],
#  [' om', ' chize kese', ' uthate hai?', ' bomb', ' pde rhta hai to?'],
#  [' ok', ' hindi mei bol skta hai'],
#  [' bsdike'],
#  [' arish',
#   ' ko bula',
#   ' grp mei',
#   ' bol',
#   ' fri',
#   ' shriya',
#   ' bhi',
#   ' ajyegi'],
#  [' ok', ' mere ko', ' acha', ' wo isi', ' game meinayeya?'],
#  [' aa r hu ruk customize kr r hu', ' chal aa', ' ab'],
#  [' abe', ' sun', ' tu mere ppt ke lia recording', ' kr dega kya ?'],
#  [' ppt',
#   ' bta dunga script',
#   ' tu kr lena record',
#   ' parts mei krna hai',
#   ' jya nhi',
#   ' juda',
#   ' missed group voice call',
#   ' abe sun'],
#  [' MediaShared'],
#  [' chal gudnight maza aya apke sth'],
#  [' maa kasam kha ke bol', ' to manunga'],
#  [' ...'],
#  [' MediaShared'],
#  [' DeletedMsg',
#   ' DeletedMsg',
#   ' DeletedMsg',
#   ' DeletedMsg',
#   ' DeletedMsg',
#   ' DeletedMsg',
#   ' DeletedMsg',
#   ' missed group voice call',
#   ' MediaShared',
#   ' MediaShared'],
#  [' abe sun', ' missed voice call'],
#  [' aj', ' mera viva hai', ' or tu help krega', ' mai pdf bhj r hu'],
#  [' lab ka', ' chemistry ka', ' madam ms teams mei legi'],
#  [' abe',
#   ' lab',
#   ' manual',
#   ' mei sb mil jyga',
#   ' bs tu',
#   ' dhyn se sunna',
#   ' madam jo',
#   ' ques. kregi'],
#  [' ha'],
#  [' abe nhi', ' tu whtsaop', ' call mei rhna', ' mai speaker pe kr deunga'],
#  [' ha'],
#  [' tu mute rkhna', ' bs tu sunna usko'],
#  [' 11 bje'],
#  [' wtf',
#   ' phle ke 5 hi se puchegi',
#   ' pdhne ki zarurt nhi hai',
#   ' tu search krke ansr bta pyega'],
#  [' pdf ka', ' abe fok', ' send hi nhi hua tha', ' mere ko lga bhj dia hu'],
#  [' aa r hau',
#   ' MediaShared',
#   ' mai tere ko whtsapp pe bolega',
#   ' jese',
#   ' e1  coloringagent',
#   ' mtlb experiment 1 mei coloring agent bta',
#   ' agr bs wrd bolu to',
#   ' ya sentence to uska ansr',
#   ' de dena',
#   ' e2 indicator',
#   ' e3 mtlb experiment 3',
#   ' itna smjh jana bs tu',
#   ' baki pdf search se try krna dhundne ka',
#   ' hojyga'],
#  [' abe', ' example', ' de r tha'],
#  [' hoga strt to msg krunga'],
#  [' ye kya ludu lussun hau'],
#  [' nhi bhai'],
#  [' 🙄', ' nhi', ' abe lockdown', ' kb khtm hoyega ?'],
#  [' abe mere yha', ' virtual sem', ' hoga', ' 80% chances hai'],
#  [' abe', ' krta hai dinbhr', ' ?', ' MediaShared'],
#  [' nhi hai',
#   ' dhundh ke thodi bhjta hu',
#   ' garib ki madad krne ja r tha',
#   ' ye',
#   ' to lga educational '],
#  [' kya ?'],
#  [' 🤦🏻\u200d♂️', ' nhi', ' abe ye kya hai sale tu bhi', ' to'],
#  [' ignote krta hai', ' 🙂'],
#  [' mai bhi kr r', ' 🙂', ' lauda ka'],
#  [' endsem hogya mera ab mai bhi 2nd year mei hu'],
#  [' ye sb nhi pta'],
#  [' noics', ' bahut jyda hai'],
#  [' mai 18'],
#  [' or iss bar mess ka na dena pde syd'],
#  [' total 45000-50000', ' hai syd'],
#  [' pta nhi ache se', ' 50k se kam hai', ' ha tution nhi lgta mere ko'],
#  [' 62k hai tuotion', ' ha'],
#  [' or jinka family income 1 lakh se kam hai',
#   ' unka bhi kam hota hai tuition mei'],
#  [' bwahhaha', ' MediaShared'],
#  [' nhi',
#   ' wo conneciom',
#   ' mei se',
#   ' koi',
#   ' like',
#   ' kia tha',
#   ' to dikh r hai'],
#  [' 🙂 yhi to puch r hu', ' koi mtlb hai', ' iss bat ka ?'],
#  [' ok',
#   ' or tu ka',
#   ' karte',
#   ' rhta hai',
#   ' ajka',
#   ' ajkal',
#   ' tu rakshabandhan',
#   ' manayega',
#   ' kya ?',
#   ' kal?'],
#  [' mithai', ' bhjwa', ' dena', ' fir'],
#  [' kahe ?', ' son papadi', ' khyega kya?'],
#  [' oh', ' abhi', ' ka kr r hai?'],
#  [' ka chalata hai?', ' linkedin ?', ' tinder ?', ' instagrama', ' fb?'],
#  [' kahe ?'],
#  [' oh  enlish mei bola'],
#  [' mt kiye kr ye sb achi bt nhi hai', ' or kch ?', ' nhi krta ?'],
#  [' oho', ' ye kese krta hai ?', ' ye sb dekht hai ?'],
#  [' abe mtlb whi pdh kese leta hai?', ' bore nhi lgta ?', ' ki wtf pdh r hu'],
#  [' 🙂',
#   ' mai neuroscience',
#   ' pe ek course lia hu',
#   ' or computational biology',
#   ' 🙂'],
#  [' abe ek', ' bt bta'],
#  [' kya hai', ' rakhi mei?'],
#  [' bo',
#   ' no',
#   ' abs',
#   ' bd',
#   ' abe',
#   ' lode',
#   ' nodejs',
#   ' ml enthisiast',
#   ' 🙂'],
#  [' nhi', ' 🙂', ' tu', ' abe sun', ' tera', ' card'],
#  [' dega kya'],
#  [' azure use krna hai', ' merr ko'],
#  [' abe', ' visa/mastercard', ' hai ???'],
#  [' nhi', ' dono chlta hai'],
#  [' rs 2 katega', ' bs'],
#  [' abe yr ...', ' shit', ' tere pss', ' azure', ' hai kya ?'],
#  [' abe dekh na', ' try kr ek bar', ' abe'],
#  [' chus chus mera loda jese aloo ka', ' pakoda'],
#  [' abe', ' ka kr r hai?'],
#  [' abe', ' boleha'],
#  [' abe dinbhe', ' ka krta hai'],
#  [' aj kch tufani kia ki nhi ?'],
#  [' mt hila bhai itna',
#   ' or lockdown kb khtm hoga ?',
#   ' jldi bnd kra bhai futbol',
#   ' khlna hai'],
#  [' fir adat khtm'],
#  [' kya ha ?'],
#  [' kya chiz ?'],
#  [' abe body...flexible rhta hai n',
#   ' ghr mei',
#   ' pde pde',
#   ' rust',
#   ' lg gya hai',
#   ' lgta hai'],
#  [' baki log to baki kya sale tu bhi',
#   ' rakhi',
#   ' mna r tha',
#   ' itne sare logo',
#   ' ke sth',
#   ' dar nhi lga ?'],
#  [' social distancing', ' ki', ' abcd'],
#  [' ok', ' got it'],
#  [' time joined', ' time left', ' jitne bar join left kreg', ' sb dikheyga'],
#  [' ha', ' abe'],
#  [' abe mera yha', ' r&d club ka inductiin strt hone wala hai'],
#  [' to usme webdev aur ml dono hai',
#   ' to mai konsa kru ? dono kru ki ml kru ki webdev ?'],
#  [' abw ye to chal hi r hai',
#   ' delta ka',
#   ' spider rd club hai n',
#   ' or wo log ieee mei paper wgra  publish bhi krte hai',
#   ' to mai soch r tha ki ml mei kru to ye sb jyda kr paunga',
#   ' webdev mei bs best practices sikhna reh gya hai',
#   ' mtlb 2 profile mei apply kr skta hu mai to mai dono mei apply kru ki koi ek',
#   ' smjh ni aa r hai'],
#  [' ha mujhe bhi yhi lg r hai', ' ki ye krna chiye'],
#  [' kaha ?'],
#  [' kya ke lia ?'],
#  [' kaha ?'],
#  [' acha'],
#  [' nhi sayd'],
#  [' abe to mai khelne', ' aunga', ' bol r tha'],
#  [' or tu laudamod', ' 🙂'],
#  [' tera hai muda hu', ' hua*', ' 🙂'],
#  [' nhi',
#   ' tu circular tube mei dal dia tha',
#   ' lamination hogya tera ludu ka',
#   ' 😂'],
#  [' circular tube*',
#   ' 🙂',
#   ' aj tk circular tube ko condom smjhta rha tu🙂',
#   ' you are',
#   ' MediaShared',
#   ' ae bsdike',
#   ' tu',
#   ' call kia tha ?',
#   ' 6 bje ?',
#   ' kahe ?'],
#  [' ok'],
#  [' got it', ' DeletedMsg', ' a e', ' sun', ' abe'],
#  [' so r tha kaya?'],
#  [' to fir'],
#  [' mt kr...fir',
#   ' abe wo chor merr ko ye bta bahar ka sthithi kesa hai abhi?',
#   ' bhid bhad ?',
#   ' jan ko khtra ?'],
#  [' police checking ?'],
#  [' kbse ?'],
#  [' achnk opencv!', ' ?', ' changing path ?', ' to cv ?'],
#  [' abe mera nam shortlist hogya delta ke lia ....'],
#  [' ha wo to uske andr  hai n....to cv hi krega kya ?',
#   ' ha.....task ke basis pr last task bahut kam log kiye'],
#  [' or abhi onsite hoga or hackathon'],
#  [' onsite mei daily 4 din tk ...6-7 hrs mei ek topic ke uppr bnana hoga',
#   ' last mei main product',
#   ' iss basis pe',
#   ' hoga swagat club mei'],
#  [' tu bhi bna r hai face detection ? abe pornstar ke nam pta krne wala bna le...bahut fyda hoga kbhi kbhi bahut jyda janne ki iccha hoti hai ki ye pornstar hai kon',
#   ' aba',
#   ' ha'],
#  [' ye suna suna lg r hai..achi h kya ?'],
#  [' or tere wo s&t ka',
#   ' kia tu',
#   ' apply ?',
#   ' tb jake kch months mei tu apne yha ke jo bhi student se reltes kam dekhta ho department/arra'],
#  [' to tu', ' apply', ' kr r hai ki nhi?'],
#  [' abe head nhi memebrr ?', ' ki bt kr r mai'],
#  [' induction to hota hai n ?'],
#  [' ha'],
#  [' ok....to tu ja r hai ml ke sth ?'],
#  [' bsdike uss disha mei ja r hai', ' kya', ' puch r hu'],
#  [' ok ja fir ml wale club ka dekh lena apna...nhi to tu bhi kr skta hai ye kam',
#   ' hafte ?'],
#  [' kahe ?'],
#  [' abe bsy rkhne ke lia kch hai nhi'],
#  [' tere yha'],
#  [' abhi mere yha spider',
#   ' spider ka to form bhi agya',
#   ' mai to yhi krte rhta hu',
#   ' mentor bhi mere ko'],
#  [' congo kr r tha to usse puch lia ki koi mini project de do krne ke lia',
#   ' to wo topic dega bola hai',
#   ' esi timepss bnane ke lia',
#   ' onsite se phle'],
#  [' abe bola to....daily ...4din 6-7hrs', ' project'],
#  [' webdev', ' ka hi'],
#  [' tu bhi chota mota project kiye kr', ' ha'],
#  [' devops nhi....webdev bs soch r hh devops ke loa apply kru'],
#  [' abe tutorial dekha kr....',
#   ' fir kya kiye kr ki',
#   ' wo jo bhi',
#   ' chiz bnata hai'],
#  [' tutorial mei', ' tu uskl', ' modify krna apne hissb se', ' ese krke'],
#  [' sikh lega', ' abe ml ka'],
#  [' abe live coding mt dekhe kr aage piche krne mei prblm jata hai'],
#  [' acha..', ' tere yha..coursera ka', ' mila hai n ?'],
#  [' usme rhyme', ' ka rhta hai'],
#  [' hands-on prjct', ' wo try kr ek bar'],
#  [' abe jese deeplearning.ai ka course dikhega tere ko',
#   ' vesi',
#   ' hands-on project ka ek',
#   ' section hai'],
#  [' dikhnana chiye chk kr lena'],
#  [' kya ?'],
#  [' kiska ?'],
#  [' ha'],
#  [' abe mtlb esa nhi hai ki mai nhi pdha hu...mai *for the sake of learning webdev* nhi pdha.....mai *for the sake of making the project possible*',
#   ' isly pdhta gya process mei',
#   ' or mere ko pta bho nhi',
#   ' chala ki mai kch pdh bhi r hu',
#   ' ab jese tu bolega ki mai pdh leta hu',
#   ' thoda',
#   ' js',
#   ' css wgra'],
#  [' abe mtlb tu ek ex-googler hai uska video dekhna',
#   ' wo bhi yhi',
#   ' bola ki',
#   ' mai kbhi koi language',
#   ' isly nhi sikha ki mere ko ye ana chiye',
#   ' wo bs ek prjct sochta tha',
#   ' ki ye bnaunga',
#   ' or uss prjct ke hissb se',
#   ' language dhundhta tha',
#   ' or bnate bnate sikh jata tha',
#   ' try kr prjct dekh le koi jo bna r ho  fir tu uss prjct  ko apne hissb se modify krne ki kosis krna...to tu sikh hi jyga',
#   ' at the ens',
#   ' end*'],
#  [' wtf'],
#  [' mai 4 bje aunga', ' khlne', ' location', ' send me'],
#  [' onsites', ' chal r hai'],
#  [' abe abhi nhi kr skta join',
#   ' discord',
#   ' pe',
#   ' online rhna pdta hai or',
#   ' call wgra',
#   ' krte hai',
#   ' udhr se'],
#  [' kya?',
#   ' -___________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________ ...
#  [' oh', ' okay', ' pdh lia hai tu chadarmod'],
#  [' ha to kya ?',
#   ' readmore',
#   ' to ese bhi dikhata hai',
#   ' back krke wps ane pe'],
#  [' oh you dont know me', ' kid', ' gali wali', ' chor dia', ' mai', ' dena'],
#  [' .'],
#  [' yhi aim hota hai'],
#  [' ....'],
#  [' suri', ' i am bsy', ' bzy', ' jo bolega', ' whi hoga'],
#  [' ..', ' ..'],
#  [' to bhai neutral hogya',
#   ' mai tantra mantra kr dia',
#   ' isme hi',
#   ' no reflection'],
#  [' MediaShared'],
#  [' MediaShared',
#   ' ram teri....ganga melli hogyi',
#   ' tere pap dhote dhote',
#   ' 👍'],
#  [' apne pap dho lena', ' corona hai', ' corona', ' 5  akele?'],
#  [' flight?', ' train?'],
#  [' tere laude sanskari hai?'],
#  [' i doubt'],
#  [' lkbht', ' lgbt'],
#  [' l',
#   ' a',
#   ' u',
#   ' d',
#   ' e',
#   ' k',
#   ' a',
#   ' b',
#   ' a',
#   ' l',
#   ' h',
#   ' a',
#   ' i',
#   ' t',
#   ' u',
#   ' c',
#   ' h',
#   ' a',
#   ' k',
#   ' k',
#   ' a'],
#  [' mkbhd'],
#  [' fir depression', ' mei ja r hai kya ?'],
#  [' frustration?'],
#  [' bsdike',
#   ' nhi hai abhi',
#   ' mern pdh r tha',
#   ' stack*',
#   ' hackthon bhi hogya',
#   ' mera',
#   ' delta ka'],
#  [' chances kam lg le re hai mere vese',
#   ' kyoki',
#   ' webdev mei',
#   ' bahut competition hai',
#   ' cpp kya h?'],
#  [' ane webdev ka  h', ' mongodb'],
#  [' ha'],
#  [' sahi tha cms bnana tha 8hrs mei',
#   ' mtlb or options thr',
#   ' but mai cms bnaya'],
#  [' wix jnta hai?', ' wix.com'],
#  [' ?', ' bs whi', ' bnana tha'],
#  [' jisse users',
#   ' apna webpage bna ske',
#   ' kya ?mm',
#   ' ??',
#   ' bolega',
#   ' bsdike'],
#  [' wtf', ' ye sb kya h?', ' porn  access ?'],
#  [' bsdike kam kr', ' le kch'],
#  [' to tyari kr le'],
#  [' mai april ke bd kal',
#   ' dhang se soya hu',
#   ' hackathon khtm hua fir',
#   ' abhi spider ka bhi krna hai'],
#  [' ye to 9am to 5pm',
#   ' mai pura process',
#   ' ka bt kr r hu',
#   ' induction process'],
#  [' 🙂'],
#  [' 9 se', ' 10am', ' pm*'],
#  [' lucky guy'],
#  [' kyoki mere ko sone ka tym nhi milta', ' do{search '],
#  [' kahe', ' ka lucky'],
#  [' select', ' hogya?'],
#  [' total kitne the ?'],
#  [' ho jana chiye bsdike', ' kya', ' puche m', ' ???'],
#  [' mtlb  ???'],
#  [' acha', ' ye kya direct', ' interview', ' kaha se pta chlega'],
#  [' kch ata jata hai nhi'],
#  [' task ?'],
#  [' mai hota to tere yha select nhi hota',
#   ' kabhi',
#   ' kyoki ye sb nhi hai',
#   ' mere pss',
#   ' or mere',
#   ' type log honge',
#   ' tere yha'],
#  [' jo deserve krte honge', ' but experince', ' wgra nhi hone se'],
#  [' to kya kya bola hai tu?'],
#  [' oh my gad'],
#  [' fir ?', ' kya bole', ' tere ko kya lg r hai?', ' hojyga ?'],
#  [' abe frk nhi pdta',
#   ' utna',
#   ' kaggle se',
#   ' google mei bhi ml engineers hai',
#   ' mere yha bhi hai',
#   ' wo sv kaggle nhi krte'],
#  [' backdhoi mt kr', ' sbka alg path hota hai', ' MediaShared'],
#  [' yes🙂'],
#  [' bsdike', ' aj lga gai', ' wifie'],
#  [' MediaShared'],
#  [' ye to pta nhi', ' puch ke btaunga'],
#  [' kya !'],
#  [' tu konsa plan pucha ?', ' charge wala?'],
#  [' ya total?'],
#  [' total 5000'],
#  [' lga', ' installation'],
#  [' sb mila ke', ' ye syd 1000'],
#  [' download speed max 90', ' ha', ' syd'],
#  [' unlimited', ' hai'],
#  [' ye sure nhi hu', ' 🙂 isly bola mujhe nhi pta'],
#  [' puch ke btaunga ka pitashri',
#   ' se',
#   ' wo hi lgwaye hai kyoki',
#   ' i doubt konsa plan hai',
#   ' 🙂 pitashri',
#   ' mera to hogya bhai sb fast lg r hai ab'],
#  [' idhr jiofiber nhi aa  r hai nhi to wo hi lagwata'],
#  [' ha', ' wo bola', ' nhi lg skta', ' mere area mej'],
#  [' ye bt bhi hai', ' aage se dhyn rkhna', ' iss bat ka'],
#  [' kese ?', ' kitne log hue?', ' select ?'],
#  [' oh acha', ' ui ke wjh se', ' patta kat gya mera', ' 😭'],
#  [' kya !', ' m', ' ???'],
# ...
#   ' baki tu dhundh le',
#   ' arish bhi',
#   ' software dev mei lga hai',
#   ' opensource',
#   ' contributions',
#   ' krke'],
#  [' webdev ....yes'],
#  [' kiske lia?'],
#  [' tere ko ml krna hai to tu kr skta hai....',
#   ' but ye hai dont expect',
#   ' ml jobs',
#   ' as undergrad',
#   ' highers',
#   ' krke',
#   ' expect kr',
#   ' skta hai',
#   ' bahut chances hai',
#   ' ms'],
#  [' krke'],
#  [' software developer domains',
#   ' youtube mei',
#   ' search kr',
#   ' https://youtu.be/_9zs6q4996g',
#   ' https://youtu.be/ogy_uk6frge'],
#  [' tere ko jo thik lge', ' kr bhai'],
#  [' deep learning internship -> hyperverg inc. (startuo)',
#   ' ha kon ye ?',
#   ' senior hai kya',
#   ' ?'],
#  [' ml ?', ' acha wo', ' to kr tu ml ka esa hai to'],
#  [' kch description', ' likha hai?', ' ki kya kiye ?', ' nvidia mei?'],
#  [' acha tu bta....startups ya big companies ?'],
#  [' abe mtlb likhte hai n ki kya kiye hai',
#   ' wha pe',
#   ' short desc.',
#   ' resume mei dekha ?'],
#  [' ok indirectly wo dl pe kam kiye ...mtlb framework pe',
#   ' skills wala dikha zara'],
#  [' bhai tu confuse mt ho jyda....tere ko jo sahi lg r hai kar ke ab',
#   ' le*',
#   ' ok',
#   ' tu bhi ml pe hi focus kr ab',
#   ' hojyga tera bhi chinta mt kr'],
#  [' mt kr ..... entertainment ke lia bhi',
#   ' oo bhai sab',
#   ' frontend',
#   ' thik hai',
#   ' backend',
#   ' muskil hai'],
#  [' php', ' nodejs', ' iske lia tere ko express'],
#  [' or javascript chiye', ' phle to ye', ' ye to easy hai'],
#  [' ml kr le abhi',
#   ' hai ek phle se',
#   ' referal',
#   ' ke roop mei',
#   ' kam ajyga',
#   ' ye',
#   ' isko pakad le ab tu'],
#  [' ha..project se relted doubt wgra isse hi pucha kr',
#   ' to usko fir tera',
#   ' smjh ane lgega ki',
#   ' kesa hai tu field mei',
#   ' to bd mei help ajyga'],
#  [' mai....mern kia', ' mtlb fullstack task hai', ' or java dekh r tha'],
#  [' ha'],
#  [' ha'],
#  [' stackoverflow + documentations + tutorials',
#   ' ye krna tha',
#   ' to ye krna pda'],
#  [' abe jese for example',
#   ' ek paint tool bnaya hu',
#   ' bnaya tha onsite mei',
#   ' to usme kch kch pta nhi tha to stackoverflow + kch tutorial',
#   ' kch naya functions',
#   ' pta chala',
#   ' random',
#   ' mostly traversary'],
#  [' kya ?'],
#  [' to isme nayi bt kya h ?', ' 🙂'],
#  [' ha to bna lena usme kya hai'],
#  [' nhi hota esa ajkal',
#   ' wo to',
#   ' bs',
#   ' ehsan kr dk',
#   ' do*',
#   ' ki ek project bna do',
#   ' wala condition hai',
#   ' ab tere yha',
#   ' nerds honge',
#   ' koi',
#   ' wo log to whi bnayenge jo',
#   ' branch se relted hai'],
#  [' mere yha ek hai nerd 9.7 cgpa ml ka mere se puch r tha task🙂', ' acha...'],
#  [' abe wo task dia tha jo tun kog'],
#  [' ha...or mai bta bhi r tha 😂'],
#  [' ha mai usko bola ki web kch puchta to bta deta',
#   ' ab ye kya',
#   ' ml ka',
#   ' mai khud ni kr r hu'],
#  [' ruk tujhe classs ke bd use krne ke lia dunga',
#   ' abe botfather hota hai usme new bot ka nam wgra dete hai fir backend code khud likhana pda'],
#  [' *devblin_bot* nam se hai groups mei msgs wgra bhej skta hai or groups jisme wo member hai uski lists de skta hai'],
#  [' commands ke basis pe tujhe rply bhejega wo',
#   ' /help',
#   ' se commands ke list ate hai',
#   ' /show  se group list'],
#  [' /send to group_name msg'],
#  [' kya ?'],
#  [' ha abhi private hai tu khud bhi use kr skta hai usko apne bot ke lia',
#   ' be jo commands maine de rkhe hai unme se hi use kr skta hai'],
#  [' abe tu utna bada bhi mt smjh', ' 40-50 line ka hoga'],
#  [' kyo?', ' kya hua?'],
#  [' kya h ye .', ' ?'],
#  [' nahi'],
#  [' kb ?', ' pdhai?', ' wo madam ?'],
#  [' abe speech wala bhi bnaya mai', ' https://devblin.github.io/voice/'],
#  [' isme box move krta hai speech se', ' left right', ' up'],
#  [' down', ' start'],
#  [' commands hai', ' ha mai hu'],
#  [' ready*', ' uske', ' wo seminar', ' wgra kr r hu', ' crud ka kia'],
#  [' ja'],
#  [' ha bol', ' kch nho be'],
#  [' repo bna', ' apne username ke nam se'],
#  [' ye ek project hai'],
#  [' to uska documentation dekh'],
#  [' ha to api ka documentation', ' hai gitbub mej'],
#  [' abe', ' tere psss', ' mera koi photo hai ?', ' dhang kaa?'],
#  [' ...'],
#  [' website ke lia', ' 🙂'],
#  [' nahi ....spoder', ' spider*'],
#  [' ki pradyumna kya h apki life me', " bittu's ques. 😂"],
#  [' pradyumna apke liye jaha bolte ho aa jata h but ap usko bs use krte ho',
#   " bittu's ques.",
#   ' 😂',
#   ' abe iska ansr de de bhai',
#   ' mai to bol dia jnti ho ni mere ko to jo smjhana hai smjh lo',
#   ' to ye smjh ri hai wo',
#   ' 😂'],
#  [' ansr de iska', ' jlsi'],
#  [' ok', ' bhai', ' anser de sbke'],
#  [' jo wo puchi hai', ' usko frwrd krna hau'],
#  [' pradyumna apka friend h ki ni??'],
#  [' bhai jo jo puch r hu', ' ansr de', ' sbke'],
#  [' ???'],
#  [' kya laude m', ' ?', ' abe ansr de jldi', ' sar kha ri hai mera wo', ' ab'],
#  [' ha m', ' ?'],
#  [' 🙄'],
#  [' yhi', ' tk'],
#  [' abe kch ni puch ri thi pradyumna kya hai apka',
#   ' ye wo',
#   ' to mai bola khud ko pta hona',
#   ' chiye',
#   ' ye to',
#   ' bekar sa ques. yai',
#   ' hai*',
#   ' to mai bola hi nahi',
#   ' directly'],
#  [' kya thik hai ?'],
#  [' jya be', ' kya', ' kya krta hai dinbhr ajkal ?'],
#  [' koi development wala sikh le', ' arish faced prblm'],
#  [' mujhe puch r tha apna ml model'],
#  [' deploy krna hai to kese kru?'],
#  [' mai usko bola ki django/flask sikhna pdega tujhe  agr tu webapp bnana chahta hai apne model ke lia',
#   ' to agr',
#   ' ab mai club mei hu to ek bhiya hai jo github pe top contributor the',
#   ' wo bole',
#   ' ki ml wgra sb',
#   ' overrated hogya hai'],
#  [' jyda per mt lagao',
#   ' ek chiz ache se kr lo',
#   ' but',
#   ' agr tere ko arish jesa krna hai',
#   ' ki model ke lia app wgra bnana',
#   ' to tujhe kam se kam app/web sikhna pdega'],
#  [' or codechef mt kia kr', ' kya ?'],
#  [' dsa mei kaha tk pahcuh gya ?'],
#  [' mera dsa chal r hai iss sem', ' aj to ct tha', ' google helped'],
#  [' to codechef mei kya ?', ' compete ?'],
#  [' practice ?'],
#  [' abe long challenge mt kia kr tym waste hai',
#   ' cookoff',
#   ' or lunchtime sahi hai'],
#  [' or baki codeforces', ' kia kr'],
#  [' or opensource kr r hai ?'],
#  [' MediaShared'],
#  [' MediaShared'],
#  [' maine 2 compete kiye hai abhi tk',
#   ' codeforces pe',
#   ' 2-3 hi bnta hai',
#   ' ek mei to',
#   ' bs 1 bna'],
#  [' mai to spider walo se puchunga', ' MediaShared'],
#  [' bahut sahi log hai'],
#  [' MediaShared',
#   ' agle week se project denge',
#   ' abhi bole',
#   ' sikho',
#   ' project ke hissb se',
#   ' mern to sikh hi r hu',
#   ' sath mei',
#   ' or kch extra',
#   ' phli bar sun r hu wo sb',
#   ' MediaShared'],
#  [' ha tutorial dekh r hu usme koi prjct bna r hai but mai wo prject nhi bna r hu',
#   ' mai reddit clone bna r hu'],
#  [' mtlb framework smjhne ke lia'],
#  [' tere yha to honge ?',
#   ' abe tere wo nvidia wale to honge opensource wake',
#   ' wale*',
#   ' github dekh ke smjh lia kr'],
#  [' https://goodfirstissues.com/'],
#  [' kyo nahi dal skta !', ' ?', ' 🙂'],
#  [' spider', ' ka hai'],
#  [' acha hai...dekh le tere layk', ' chiz hai'],
#  [' tali baja', ' fir', ' usme'],
#  [' MediaShared'],
#  [' ha',
#   ' but sb nhi',
#   ' kr skte hai',
#   ' restricted hai',
#   ' markdown hi use',
#   ' kr'],
#  [' ha p tag center align', ' use kr skta hai kam lrega', ' krega*'],
#  [' ha to kahe puch r bhaklandi ke', ' kia hua hai use to', ' MediaShared'],
#  [' google kia kr na laude', ' center krne ke lia', ' or kya', ' content ko'],
#  [' MediaShared',
#   ' DeletedMsg',
#   ' DeletedMsg',
#   ' DeletedMsg',
#   ' DeletedMsg',
#   ' DeletedMsg',
#   ' MediaShared'],
#  [' mera',
#   ' photu lg gua',
#   ' gya',
#   ' MediaShared',
#   ' website mei',
#   ' MediaShared'],
#  [' https://spider.nitt.edu', ' MediaShared'],
#  [' MediaShared'],
#  [' mai new bna r hu abhi parallex effect k sth',
#   ' 2-3 log bs',
#   ' seniors mei bs webdev head ka hau',
#   ' syd',
#   ' MediaShared',
#   ' nahi bhai mai ye wala phot htwa dunga jldi hi',
#   ' ajib feel ho r hai ab',
#   ' abe',
#   ' ubuntu',
#   ' ko uninstall kese kru?',
#   ' ?'],
#  [' mere ko'],
#  [' space bdhana hai', ' ubuntu ka'],
#  [' bta ?'],
#  [' 🙂 nahi smjh aya', ' last bar jo', ' tu kia tha ?', ' whi?'],
#  [' ok'],
#  [' mint kr r hu be mai install ab', ' ye uninstall ka hai ?'],
#  [' external monitor connect krne mei prblm jata hai',
#   ' ubuntu mei',
#   ' mint mei thik hai ye sb',
#   ' ye video mei hai ?'],
#  [' ek frnd krta hai use'],
#  [' dual montior'],
#  [' mera dusra monitor ka resolution jitna hai usse kam support krta hai',
#   ' ubuntu mei'],
#  [' windows mei thik chlta hai'],
#  [' kiska ?'],
#  [' 🙂 maine 10 videos', ' dekh loye', ' ye sahi krne ke loa', ' lia*'],
#  [' halka hai thoda'],
#  [' 🙂 ok', ' smjh gua'],
#  [' MediaShared'],
#  [' ok sir',
#   ' abe mint',
#   ' fast hai be',
#   ' ubuntu se',
#   ' tu bhi try kr mint',
#   ' MediaShared'],
#  [' kr  r hu'],
#  [' stats/seniors', ' ki bt'],
#  [' se bol r tha',
#   ' ki fast hai ubuntu se',
#   ' abe',
#   ' nitin ka',
#   ' kya chal r hai?',
#   ' kidhar ja r hai wo?'],
#  [' MediaShared',
#   ' 10 min lagay tu ye msg pdhne mei?',
#   ' or fur 3 min rply dene m'],
#  [' abe ye utha hai ki ni?', ' sok', ' soke', ' yad dila de usko call rkek'],
#  [' 🙂', ' iit  mei jyga lg rh', ' advanve nikal lia hoga wo'],
#  [' oh'],
#  [' abe',
#   ' ae',
#   ' bsdike maryega kya ?',
#   ' ye sb mt kr',
#   ' fel jyga sticker idhr udhr'],
#  [' ni', ' aya', ' snjh'],
#  [' nahi', ' earphone', ' nako'],
#  [' sun lia bhai', ' ye kya', ' pyaz ?', ' kya ?', ' wtf pyaz ?'],
#  [' ka krta hai ajkal?', ' class ke alwa ?'],
#  [' oh bade log'],
#  [' oh big people'],
#  [' bade log...pur ungli kyo krta h khud ko', ' 😂', ' ?'],
#  [' *kaggle* bade log krte hai', ' mere jese chote log nahi'],
#  [' abe c', ' hai bhai', ' tere club wale'],
#  [' or tu nhi c hai laude tere ko bola tha mai poroject',
#   ' kar',
#   ' induction krna nahi ata sahi se',
#   ' bhai unko'],
#  [' sbko',
#   ' equal',
#   ' sun meri bt',
#   ' sbkk',
#   ' equal chance',
#   ' milna chiye',
#   ' jese 2 month ke lia',
#   ' task wgra dena',
#   ' taki usme sikhe khud se',
#   ' ab sbko nhi pta hota'],
#  [' ml ai ke bare mei',
#   ' mere ko nhi pta tha',
#   ' webdev ke bare mei',
#   ' to ab tere yha type induction hota',
#   ' tb to mere lag jate'],
#  [' kisme ?'],
#  [' tapping wala game', ' number tapping'],
#  [' nahi',
#   ' mila hi nhi tutorial uss game ka',
#   ' dom',
#   ' manipluation krna tha'],
#  [' kya ?', ' kyo puch r hai ye sb ?'],
#  [' oh', ' wro'],
#  [' ok',
#   ' kb ?',
#   ' jyda kch  hi dominoos le jana',
#   ' ye hai konsa',
#   ' ???',
#   ' project ?'],
#  [' agr reactnative sikh lunga iss sal to',
#   ' mobileapp bna dunga',
#   ' nahi to webapp hi bna paunga'],
#  [' zarurat ke hissb se sikhta hu mai bsdike',
#   ' tere projct ke lia kahe sikhunga'],
#  [' ha',
#   ' kyoki',
#   ' react  sikh lia hu to',
#   ' native easy pdega',
#   ' frontend*',
#   ' bolte hai usko',
#   ' or tere ko phle apne model ke lia api bnana pdega',
#   ' backend*'],
#  [' django/flask', ' sikhna pdega', ' tere ko', ' iskw lua*'],
#  [' MediaShared'],
#  [' mujje kese pta hoga',
#   ' tu fb',
#   ' chalata hai',
#   ' tere ko pta hoga',
#   ' 3 yrs ?'],
#  [' usi ka',
#   ' hoga',
#   ' kya pta',
#   ' abe wo',
#   ' usme dekh le',
#   ' jo schl se',
#   ' menu card mila tha students ka',
#   ' usme sbka dob to likha hi hai'],
#  [' 🙂', ' uska nhi hai', ' to hai kiska ?'],
#  [' MediaShared'],
#  [' chutuya', ' kehna chah rhe the', ' likh nahi paye'],
#  [' a', ' cha', ' MediaShared', ' MediaShared'],
#  [' gm bro gm', ' yhi ganda dimag yhi dikhega phle'],
#  [' MediaShared', ' MediaShared'],
#  [' MediaShared'],
#  [' ha'],
#  [' chal r hai'],
#  [' haa...wo club ko', ' or ek freelance', ' wala'],
#  [' are nhi spider ko approach kiye hai',
#   ' to senior log meet krenge ki krna hai ya nahi',
#   ' cloud based hai koi'],
#  [' ye alg hai...'],
#  [' club'],
#  [' usme cuvette tech krke koi company hai',
#   ' wo',
#   ' projectw',
#   ' dilayegi',
#   ' nitt...iitkgp...',
#   ' or koi',
#   ' 2 tha',
#   ' yad nhi',
#   ' unke lia hai',
#   ' abhi',
#   ' filhal'],
#  [' abhi gya nhi hu'],
#  [' club wala to bhai club pe depend krega kyoki project chal r hai filhal',
#   ' MediaShared',
#   ' MediaShared'],
#  [' opensource contribution', ' hi maza hai', ' tere ko aya ni'],
#  [' ml ke projects dhundh r tha ?'],
#  [' ml mei mostly documentation...bug wale hi honge',
#   ' ya deployment se relted'],
#  [' sikh le',
#   ' leta',
#   ' hacktober mei',
#   ' dinbhr kya krta hai tu ?',
#   ' class ke alwa'],
#  [' or m', ' ???', ' bs ?', ' oh kaggle...'],
#  [' MediaShared'],
#  [' MediaShared'],
#  [' MediaShared',
#   ' MediaShared',
#   ' sahi hai tera tp',
#   ' statistics',
#   ' MediaShared'],
#  [' tera cgpa kitna h !', ' ?', ' MediaShared'],
#  [' mera to ab kya hi bolu course'],
#  [' dsa ', ' mera phle se gira hua hai'],
#  [' frk pdta hai...placements mei sort krte hai bina skills dekhe',
#   ' 7.5 amazon ka tha eyd',
#   ' syd*'],
#  [' mera to use bhi kam'],
#  [' microsfot ka',
#   ' bhi',
#   ' 8',
#   ' hai syd',
#   ' ha whi  krunga ct mei to 90% aa re hai',
#   ' MediaShared',
#   ' endsem online hua',
#   ' tb to',
#   ' mai hi top krunya',
#   ' MediaShared'],
#  [' kese m', ' ?'],
#  [' km kese aye ?', ' google', ' se ansr nhi mile ?'],
#  [' assignments nhi kia ?'],
#  [' itna tatti',
#   ' bhi kyo',
#   ' bnaya ?',
#   ' MediaShared',
#   ' mai to dusro ke assignments ke sth ched chad krke submit kr deta hu',
#   ' mai assignments khud se krta hi nahi ho',
#   ' hu*'],
#  [' MediaShared',
#   ' 4.5/5',
#   ' 9/10',
#   ' 8.5/10',
#   ' MediaShared',
#   ' ese aa re hai ajkal',
#   ' mai ek grp bnaya hu north walo ka mere dept. mei 2yr walo ka usme sab kr dete hai help',
#   ' MediaShared',
#   ' sbke ache ate hau',
#   ' endsem mei sbka 8+ aya',
#   ' mera chor ke',
#   ' MediaShared'],
#  [' tera to ayega hi 8 se upor', ' upor', ' kese bhi krke'],
#  [' mera to spider wale senior bol re the ki cgpa thoda bdha lo...8 ke uppr kr lo ... to dhyn dunga endsem mei thoda',
#   ' humara to relative hi hai',
#   ' endsem bhi relative tha',
#   ' absolute rkhne ka logic smjh nj aya tum log ke yha se'],
#  [' MediaShared',
#   ' mere dept. mei software dev krne wale bacho ka',
#   ' grades',
#   ' janbhuj ke gira dete hai'],
#  [' jo iss bar ki hod hai wo phle se yhi krwa ri hai...',
#   ' kyoki core pe dhyn de krke',
#   ' unko chiye ki sb core pe dhyn de'],
#  [' kin log ko?'],
#  [' bdhiya hai'],
#  [' yha to apne clubs ko funding milta hai lakh ke uppr....itna support krte hai',
#   ' abhi trichy police ke lia...app bna re hai apan',
#   ' to ye sb projects admin late hai apan ko dete hai',
#   ' logo ko jo project krna ho mtlb club wale',
#   ' wo pesa le skte hai club se',
#   ' abe',
#   ' jaldi',
#   ' group deky',
#   ' dekh*',
#   ' abe'],
#  [' mujhe', ' bhi', ' owner', ' bna', ' tdap', ' server mei', ' kch'],
#  [' krna hai',
#   ' mujhe kya pta',
#   ' bs merr ko',
#   ' server settinga',
#   ' krna hai'],
#  [' bsdike',
#   ' iske lia hi',
#   ' vhiye',
#   ' permission',
#   ' settinga dekh na',
#   ' server settings mei'],
#  [' thik hai'],
#  [' mai 3 no ko admin setting krne ka', ' kosis krunga'],
#  [' or roles wgra bta dena',
#   ' add kr dunga',
#   ' tiwari ko hilarious-boi ka',
#   ' role de dunga'],
#  [' ok',
#   ' bra',
#   ' bta',
#   ' tu bhi change kr skta hai',
#   ' ab',
#   ' tu weird-admin gai',
#   ' hai* sab powers',
#   ' hai',
#   ' bs 3 log tk rkhna hai',
#   ' tu mai arish',
#   ' honge bs weird-admin'],
#  [' abe', ' help krega kya ?'],
#  [' aj ct hai', ' to ansrs', ' dhundne', ' hai tere ko'],
#  [' circuit theory'],
#  [' kyo ?'],
#  [' MediaShared', ' chor de lab', ' 2 bje hai ct mera'],
#  [' 1'],
#  [' 2', ' bje'],
#  [' MediaShared', ' bade log'],
#  [' nahi tera hai bta r hu', ' MediaShared'],
#  [' MediaShared',
#   ' tu bhi machine learning enthusiast hai kya ?',
#   ' MediaShared'],
#  [' MediaShared', ' ha ye bt bhi hai', ' ab kya hi bol skte hai'],
#  [' MediaShared'],
#  [' MediaShared'],
#  [' kyo',
#   ' kya hua ?',
#   ' syd vit wale hai usme',
#   ' gali galoch krte hai kya ?',
#   ' MediaShared'],
#  [' abe', ' amoungus'],
#  [' khelega?', ' abhi'],
#  [' tu arish mei riwari', ' bpr'],
#  [' cancel...', ' bsdike'],
#  [' 354/2761', ' rank'],
#  [' ctf'],
#  [' web exploitation', ' ruk ja'],
#  [' haa', ' nahi'],
#  [' ha'],
#  [' hq'],
#  [' nahi'],
#  [' webdev ata hai ... webexploitation smjh ata hai'],
#  [' ki vurnabilities',
#   ' kya kya ho skti',
#   ' hai ek website mei',
#   ' cookies..session',
#   ' wgra sab'],
#  [' sql injection', ' 🙄'],
#  [' abe wo nhi',
#   ' redirects...dekhna pdta hai',
#   ' server mei',
#   ' kch',
#   ' bug hota hai',
#   ' usko dhundhte hai'],
#  [' thoda bahut'],
#  [' ha'],
#  [' ha to bhai maine basic vurnabilities smjh rkhi hai n'],
#  ...]

# %%
[i[1] for i in conv_end.items()]
# Out:
# [[' bol'],
#  [' acha thik h'],
#  [' bol'],
#  [' pata nahi', ' me kbhi github.io use nhi kia'],
#  [' google me search kia?'],
#  [' acha ruk', ' mai dekhta hu'],
#  [' wo file bhj pura jo githhub pe daala hai',
#   ' usko mai daal ke dekhta hu',
#   ' fir chala ke dekhta hu'],
#  [' acha ha', ' thik'],
#  [' nahi mil raha be tera repo', ' tribute page hi dikha ra bas repo me'],
#  [' abe public kr be'],
#  [' MediaShared'],
#  [' ha'],
#  [' abe', ' to tu css file me', ' tribute-link class kaha banaya hai'],
#  [nan, nan],
#  [' nahi'],
#  [' abe bas tera code padh ra hu alan turing wala'],
#  [' oh'],
#  [' so k utha hu abhi'],
#  [' js sikh ra hu mai bhi'],
#  [' abe', ' wo tu bnaya kya'],
#  [' kya update kiya hai'],
#  [' acha', ' ruk khelta hu'],
#  [' acha banaya hai'],
#  [' abe',
#   ' ye js to normal language jaisa hai',
#   ' isme kaha se front end me kaam aata hai',
#   ' asa lag rakoi normal programming language hi sikh ra hu',
#   ' frustrate ho gaya hu bhai'],
#  [' abe', ' to sun'],
#  [' ye isme front end me kaise kaam ata hai ye', ' kya kam krta hai'],
#  [' nahi'],
#  [' MediaShared',
#   ' MediaShared',
#   ' MediaShared',
#   ' ye dekh',
#   ' ye sab topic hi dikha ra hai'],
#  [' abe',
#   ' ye sab to cpp me bhi padhe',
#   ' to lauda kaha se desogn.me kaam ayyga ye'],
#  [' abe wo.pata hai dynamic.bnate hai', ' lekin bat sun meri'],
#  [' saala ye normal programmimg language type topic hai',
#   ' kaha se dynic bnau',
#   ' kya use krke bnau'],
#  [' wap to find simple interesr', ' sala yahi thodi bnaumga'],
#  [' abe app hai ye',
#   ' usme code krne ka rehta hai',
#   ' to jaldi samjh aa jata hai'],
#  [' abe bas ye bata dynamic kse bnate hai'],
#  [' ha'],
#  [' koi code rkha hai kya tu???'],
#  [nan, nan],
#  [' acha'],
#  [' thik', ' 🙏🏻'],
#  [' acha'],
#  [' thik'],
#  [' kya'],
#  [' mast hi pehente the bhai'],
#  [' par saala abhi appollo me hai'],
#  [' abe mera bhi nokri lgega tb dekhna', ' abe wo liver wala problem tha na'],
#  [' to small intestine me paani bhar gaya'],
#  [' abhi aya'],
#  [' 10 baje gya tha'],
#  [' abe mummy ko lene gya tha', ' raat ko waa rukti hai'],
#  [' ha dekhta hu...', ' agli bar jaunga to'],
#  [' due to sudden demise of my father', ' no network there'],
#  [' aj 11 bje'],
#  [' abhi', ' nikal gya hu'],
#  [' abe ha',
#   ' badi behen ko nhi pta hai kuch',
#   ' wo akele hai apne room me',
#   ' koi aaspas nhi hai',
#   ' islea nhi btana hai usko kuch',
#   ' MediaShared',
#   ' this is how i look these days'],
#  [' abe', ' kaise kaise banaya', ' redhand', ' explain kar'],
#  [' bol', ' kya bol ra', ' MediaShared', ' return call kiya tha mai'],
#  [' fraud'],
#  [' number du kya', ' baat krna tu bhi'],
#  [' data camp',
#   ' 80% kar liya hu python aaj hi',
#   ' or ye aarish bol ra hai isko bhi grp me bhj de'],
#  [' abe bas na wo quiz jaisa hai',
#   ' or practice ke liye jagah hai bas',
#   ' to 100% kr ke usko practice krunga'],
#  [' bol'],
#  [' abe sab so re hai', ' islea nahi uthaya', ' tu bol kya bol ra'],
#  [' direct mil jaake'],
#  [' email vgera likh le pehle'],
#  [' ha'],
#  [' recommendation milta hai'],
#  [' resume me daal skta hai'],
#  [' ha tab to or sahi hai'],
#  [' mail likh pehle'],
#  [' ha tab dikkat hai', ' kyuki kaam krne ke liye knowledge hona chiye'],
#  [' ha discuss kar le'],
#  [' dekh initially ideas de de'],
#  [' phir agar wo acha laga usko',
#   ' to sikh le ache se us skill ko',
#   ' or 2-3 month baad lag ja usk saath kaam pe'],
#  [' par pehle mail kar de..', ' inform kr dr', ' de'],
#  [' ruk..'],
#  [' MediaShared',
#   ' yha aane se pehle mail bhj kr dekha tha mai',
#   ' mai bhi cvision wale field me interested hu',
#   ' to lip reading bnane ka soch ra tha',
#   ' you deleted this message'],
#  [' usi time ye compamy ka mail aya tha',
#   ' abe abhi to ata nahi hai c vision',
#   ' par phir bhi mail bhj diya tha ki is par interested hu'],
#  [' professor bola',
#   ' ki agar acha bana',
#   ' to company ko mai dunga recommendation',
#   ' tumlog ka'],
#  [' abe apne yaha na industry-acadmia meet hota hai',
#   ' to usi me companies aati hai introduce krne ko',
#   ' to usi bahane project bhi dikha dete hai'],
#  [' ha', ' par saala lockdown bigaad dega'],
#  [' 12 may ko hona tha meet'],
#  [' use ni kiya hu 2 month se',
#   ' jab java sikh ra tha',
#   ' tab kia tha aakhri baar'],
#  [' 🤯🤯🤯', ' sahi hai', ' mai aaj hi aya hu bsp', ' abe sun'],
#  [' aaj ghar me daddy ka jitna samaan tha...',
#   ' sab daan de diye',
#   ' kapda ..shoes',
#   ' bike bhi bechenge bol rhi mummy'],
#  [' ni thik hai waise', ' kyuki mummy akele rhegi ab ghr me'],
#  [' to daddy ka sab saamaan dek ke sab yaad kregi'],
#  [' reh legi', ' konsi badi baat hai'],
#  [' bhut log rehte hai', ' mopka me hai mamaji'],
#  [' bpr k ghr ke pass wale petrol pump ke pichhe'],
#  [' ha...to kya kr skte hai ab'],
#  [' acha'],
#  [' ha...', ' roz phone krna pdega ham teeno ko', ' video call vgera'],
#  [' nhi bhai utna ni krne degi mummy'],
#  [' possible ni hai har sunday aa pana'],
#  [' ha', ' dekna pdega'],
#  [' thik hai wo bhi', ' google form me to exam hua uska ek subject ka'],
#  [' ha mtlb test jsa', ' quiz js'],
#  [' jsa', ' aaram se', ' google form k ques copy kr skta hai koi bhi'],
#  [' i have shaved my hairs... moustache and beard', ' gaon me tha barber'],
#  [' ha wo to hai'],
#  [' bdhiya hai tera', ' kuch kr ra hai'],
#  [' ha...',
#   ' mai bhi confused rhta hu',
#   ' to bas mobile khol ke datacamp krta hu'],
#  [' nhi', ' vacation lag gya'],
#  [' 1 may se'],
#  [' nice'],
#  [' ohh dard hua'],
#  [' ohhk', ' ohho'],
#  [' hmlog ko bol dete the', ' mic and video off', ' wo bhi attendance nhi'],
#  [' kuch ni be', ' nind m tha us din'],
#  [' nind me koi kse msg krega be'],
#  [' bol'],
#  [' k', ' k', ' kya bolu', ' k', ' k'],
#  [' bol'],
#  [' kuch nhi', ' bas sone jaunga abho'],
#  [' jab se aya hu', ' kuxh nhi krta', ' bas datacamp hi krta hu'],
#  [' ha subah uthta hu'],
#  [' tu nahi uthta kya subah'],
#  [' kye bel re he'],
#  [' kya okay?', ' samajh nhi aya', ' kya likha hai'],
#  [' acha'],
#  [' thik h'],
#  [' ha', ' thik'],
#  [' ni h koi prblm', ' kitne baje tak aaoge', ' tumlog'],
#  [' kya', ' ???'],
#  [' ha to sorry kyu likha hai', ' kya sorry???'],
#  [' acha'],
#  [' abe sun',
#   ' ye xavier wale grp me add hona hai kya teko',
#   ' pcm wale h sbhi usme',
#   ' mko samyak add kiya',
#   ' tko b add krne bolre hai'],
#  [' ok bro', ' aane wala tha na tu', ' kya hua'],
#  [' 7:30 baje utha mai'],
#  [' acha', ' mera meeting hai bsdka'],
#  [' 12:30 ko'],
#  [' grp project dekhega professor', ' nahi iiit'],
#  [' ha', ' calculus in roller coaster design hai'],
#  [' MediaShared', ' le'],
#  [' ha', ' kyuki uska track graph hi hota hai', ' functions and all'],
#  [' bas uska derivative nikal ke velocity accerlaertion nikal skta hai',
#   ' bas yahi hai calculus'],
#  [' tu hi bola tha ki nahi smjh aya'],
#  [' .'],
#  [' acha', ' thik'],
#  [' nhi', ' bas uska calculus explaination dena hai'],
#  [' ha'],
#  [' √2*√cos2ø'],
#  [' MediaShared'],
#  [' https://www.desmos.com/calculator', ' just write the function'],
#  [' MediaShared', ' mai bas ye search kiya'],
#  [' fir se delete krke dalna pdega', ' size bdha ke'],
#  [' acha', ' to search kr le'],
#  [' kaise', ' achnk', ' koi chhed chhad kia kya tu'],
#  [' abe bsdk', ' yahi nahi krte hai ubuntu me'],
#  [' abe ek bar mai python 3.8 khud se install kia tha', ' 3.7 delte kar ke'],
#  [' to terminal nahi khul ra tha direct icon se click krne se'],
#  [' ubuntu ke playstore me jata na'],
#  [' waha se mil jata', ' ha bol'],
#  [' in short chod dia hai tu bsdk apna ubuntu'],
#  [' abe yr'],
#  [' mko na ajeeb feel hota hai ki tu bas kaam krra hai',
#   ' mai khali pada hu',
#   ' ase hi'],
#  [' ml + datacamp ke chakkar me dhyan nhi de para hu', ' game ko'],
#  [' bahut beizzati feel hota hai'],
#  [' ha to km se km us field par to kam krra na'],
#  [' MediaShared'],
#  [' graph'],
#  [' violinplot bolte hai isko'],
#  [' abe ml ka h'],
#  [' wahi padh ra hu'],
#  [' sab statistics hai', ' 🙄'],
#  [' abe mai bhi abhi aarish se pucha hu'],
#  [' acha'],
#  [' search kia kya'],
#  [' utna to mai bhi dekha'],
#  [' par significance ni aya utna smjh'],
#  [' ha median ke around ka distribution dikhata hai'],
#  [' MediaShared',
#   ' dekh ye dikha ra hai',
#   ' ki most of math score 60-80 ke bich hai'],
#  [' test data daal ke hi tko dikha ra hai result',
#   ' predicted nhi hai',
#   ' data ko frame kia hai as a graph',
#   ' graphical analysis'],
#  [' bol'],
#  [' abe bahut jldi jldi krta hai',
#   ' usse acha khud se sikhna sahi lgta mrko',
#   ' kuch smjh nahi ata uska...'],
#  [' abe andrew ng ka hai using python', ' mt de'],
#  [' mai apna id de dunga verzeo ka', ' recorded video h'],
#  [' ha hai'],
#  [' dono hai'],
#  [' ruk link deta hu'],
#  [' https://www.coursera.org/learn/machine-learning/home/welcome',
#   ' dekh to ye octave hai kya',
#   ' ki python hai'],
#  [' acha'],
#  [' ni'],
#  [' kaha milega?'],
#  [' kislea milega?'],
#  [' kya bolra h bsdk'],
#  [' sidha sidha bol'],
#  [' isme mai kha hu'],
#  [' ???'],
#  [' ruk stuti se puchta hu', ' top wali'],
#  [' nice', ' wo to boli ki ha dekhti hu', ' uske baad kuch reply ni aya'],
#  [' MediaShared'],
#  [' mai kuch ni btata kisi ko'],
#  [' naha ke aya hu', ' baitha hu'],
#  [' kya'],
#  [' bol'],
#  [' thanks', ' MediaShared', ' naam change kr liya hu apna'],
#  [' ha rakh le', ' aarish ko bhi bol'],
#  [' rajpal yadav'],
#  [' nahi aya'],
#  [' dp'],
#  [' ha aa gya', ' abe iska koi acha wala dialogue yad krke daal'],
#  [' kya gunda banega re tu'],
#  [' bahut sahi bhai bahut sahi',
#   ' mujhe bhi banana hai yar apna webpage',
#   ' us field me dhyaan hi ni jata'],
#  [' .'],
#  [' ha yar mai bhi chahta hu',
#   ' apna bhi kuch asa type ka personal website bane',
#   ' par html css ke alwa kuch nhi ata hai',
#   ' designing me bhi utna acha nahi hu'],
#  [' javascript??'],
#  [' bol'],
#  [' template hi to hai', ' kya dekhu isko'],
#  [' acha', ' code milega kya'],
#  [' bdhiya h phir', ' ni mila kuch usme', ' abe'],
#  [' .', ' smjh ni aa ra ...', ' kaha se code ya template milega'],
#  [' nhi'],
#  [' tu dikha pehle'],
#  [' kse krna h'],
#  [' code and template kaha se milega'],
#  [' ruk'],
#  [' https://html5up.net/uploads/demos/massively/#'],
#  [' dono'],
#  [' .'],
#  [' kha'],
#  [' acha', ' mai phone m krra hu', ' islea', ' kuch aa ni ra h'],
#  [' ruk'],
#  [' ok'],
#  [' thik'],
#  [' kya ho gya'],
#  [' kyu'],
#  [' itna website to bnaya na tu'],
#  [' to'],
#  [' or kya krna h tko'],
#  [' ek bt bta', ' kya krna hai tko'],
#  [' ha', ' bhut sare ideas hai chtbot ke', ' internet pe'],
#  [' nahi bhai'],
#  [' ase nahi sikhate chatbot ko'],
#  [' whatsapp chat nahi', ' tu ek kam kar'],
#  [' kuch specific chizo ka chat bana',
#   ' how are you?',
#   ' or iske kya kya reply ho skte hai'],
#  [' uska dataset bana'],
#  [' acha', ' to bhi pehle dekh le kse lya krte hai iske liye'],
#  [' log?'],
#  [' thik h'],
#  [' hz', ' ha'],
#  [' isko pehle pura krte h'],
#  [' kyu'],
#  [' kya potential'],
#  [' kisme kya potential hai', ' ache se puch question'],
#  [' .'],
#  [' ha'],
#  [' tumlog ko kab mila'],
#  [' hmlog ko to nhi diye', ' minor project hi submit kia hu mai on 15'],
#  [' acha', ' to tera wd ka h kya', ' ha grp me bnana hai major ko'],
#  [' bol'],
#  [' acha', ' ruk', ' 2 min'],
#  [' bol'],
#  [' bol'],
#  [' pde???'],
#  [' acha', ' bdhiya hai'],
#  [' jab wo bola na oct me baat krte hai', ' to or kya bolega tu'],
#  [' kuch ni'],
#  [' kya ho gya', ' MediaShared'],
#  [' .'],
#  [' kab kia',
#   ' 22 apr ko aya tha ye shyd...',
#   ' abe tko ky ho gya h ajkl',
#   ' bat nhi krta h'],
#  [' ha to kya krte rehta hai', ' online ni rehta to'],
#  [' ok'],
#  [' mai bhi verzeo ka prjct par hi kte rhta hu kich kuch'],
#  [' MediaShared', ' amy chlati h kya linkedin???'],
#  [' MediaShared'],
#  [' ha pata hai'],
#  [' mai baki mita diya tha', ' fir tko bhja'],
#  [' ase hi', ' bor ho ra tha'],
#  [' .....🙂', nan],
#  [' bol'],
#  [' tere se pehle nhi khaunga'],
#  [' nhi', ' tu kha pehle', ' fir review dena'],
#  [' tbhi khaunga'],
#  [' linkdin?'],
#  [' ha dekha'],
#  [' ha dekha', ' likhne bol de', ' tu hi'],
#  [' sahi hai bhai tera',
#   ' pura web dev sikh liya',
#   ' ham html css pr hi atke hai'],
#  [' padh chuka bhai', ' smjh kuch ni aya'],
#  [' bhosdike', ' photo kon liya hai wo dekh'],
#  [' kisse?'],
#  [' bhok'],
#  [' kyo'],
#  [' ha mere daddy bhi bolre the 2-3 month pehle se', ' ni asa bhi ni'],
#  [' kuch disease hai kya'],
#  [' abe kuch loan vgera bohot hoga'],
#  [' acha',
#   ' to ghar pe kuch acha bana ke khilane bol de',
#   ' mood thik ho jyga'],
#  [' ruk be'],
#  [' bol'],
#  [' pdh lis', ' uth jynge', ' raquet le ke ana hai kya???'],
#  [' kon kon la ra raquet'],
#  [' acha mre pa$ 2 hai', ' par ek ka net tuta hai'],
#  [' ha'],
#  [' 3 log kse khelenge badminton???', ' strategy bta'],
#  [' acha thik', ' aa jaunga', ' ja so tu'],
#  [' ohho'],
#  [' shuttle hai??'],
#  [' mahi mere pas shuttle nahi hai'],
#  [' nahi be', ' mko laga post karu ki ni'],
#  [' to socha kar hi deta hu'],
#  [' kkrh tu'],
#  [' fuck'],
#  [' .', ' itna bada bada kaam krra badk', ' bsdk'],
#  [' mko utna b ni ata'],
#  [' ha ruk', ' bna ke dekhne de'],
#  [' nhi', ' wahi padh ra', ' are ni bnega shyd'],
#  [' abe ek gaana gaa ke post karu soch ra tha daddy ke lie'],
#  [' abe sun to', ' mai sandeep.sir.ke photo me comment kia hu'],
#  [' dekhne bol ra hu bsdk'],
#  [' comment me'],
#  [' mai bhi ni chlata',
#   ' par aarish bola comment krne',
#   ' to chrome.se hi sign in krke kia'],
#  [' delete kr dia ky'],
#  [' abe sun ...sir ek black and white photo daale apna',
#   ' to mai likha',
#   ' aankho me thodi nami nami si hai....',
#   ' aaj phir lamda = 380 to 700 nanometers',
#   ' ki kami si hai'],
#  [' incognito me nahi hota sst'],
#  [' ni smajh aya???'],
#  [' abe phir history me save ho jata hai'],
#  [' kya hua'],
#  [' bolega'],
#  [' nhi'],
#  [' bilha'],
#  [' nani'],
#  [' ase hi', ' tu nhi uthaya to aarish se bt kia'],
#  [' abe tu to course lia hai', ' verzeo'],
#  [' abe mai khud project pe kaam krte krye sikh gya tha',
#   ' class nhi krta tha'],
#  [' chalu kr de',
#   ' project pe',
#   ' bas search krte krte sikhna',
#   ' how to plot...',
#   ' how to eda',
#   ' how to train algorithm'],
#  [' exploratory data analysis',
#   ' ha...plotting eda k andar hi ata hai',
#   ' kyuki output kis kis variable pe depend krta hai wo check krte hai eda me'],
#  [' yes', ' ruk'],
#  [' MediaShared', ' MediaShared', ' MediaShared', ' MediaShared'],
#  [' photo bhja hu', ' kuch  padha usme se'],
#  [' kon'],
#  [' abe ha', ' mai to bhul gya puchna', ' bas opportunities ka puch lia'],
#  [' ho skt h'],
#  [' kushashwa ravi shrimali', ' apn kush sir bolte h baa', ' bs'],
#  [' bel bhesdike'],
#  [' abe'],
#  [' MediaShared'],
#  [' tere pas hai???', ' nvidia'],
#  [' to dekh apne linux me'],
#  [' .', ' .', ' help me pelease'],
#  [' abe', ' nitin tera number maang ra'],
#  [' kuch nahi'],
#  [' bas number maang ra wo tera', ' isme or kya puri baat batau'],
#  [' tu jab ye pucha na', ' tab ka de chuka hu'],
#  [' kya bolta'],
#  [' chup bsdk', ' tu to photo khichwata hai', ' mai kuch bolta hu kyay'],
#  [' boat me bhi ghumne gya tha'],
#  [' MediaShared'],
#  [' photo khichwaya ya nahi ye matter nahi karta'],
#  [' gaya tha ye matter krta hai'],
#  [' dekh le naam likha hai', ' sath me mera naam me *#* hai'],
#  [' _#_'],
#  [' #'],
#  [' bsdk', ' tu bahut kuch kar chuka hai'],
#  [' photo hi kam hai mere pas',
#   ' baaki jiski photo nahi hai',
#   ' pata nahi kya kya kia hai',
#   ' chhiii'],
#  [' soch bhi nai paa raha hu'],
#  [' sep 3', ' 2019'],
#  [' bsdk pura photo dekh ache se', ' tu hi bhja hai', ' or mai ss lia hu'],
#  [' or bhi kaccha chittha le ke ghum ra hu tera'],
#  [' smjha'],
#  [' ye mat sochna ki sirf tu hi mera rkha hai',
#   ' there is god above you',
#   ' huaaahaaa hahhahahah'],
#  [' ha', ' nitin hai wo'],
#  [' kya bolra', ' bolega bsdk', ' ignore karra tu', ' nice'],
#  [' abe wo kya bola'],
#  [' mtlb'],
#  [' kya]'],
#  [' phir'],
#  [' abe', ' uska jee main (jan) me kitna aaya tha'],
#  [' percentile', ' ?'],
#  [' abe to usko to aram se mil jyga'],
#  [' sahi hai uska', ' usko bola ki branch matter nahi karta???'],
#  [' ohhh', ' sorry bhisdike'],
#  [' abe deepanshu',
#   ' kal aajana',
#   ' aarish ke ghar',
#   ' kkrh',
#   ' kisse chat krra',
#   ' tu'],
#  [' acha'],
#  [' tere ghr me exactly kya puche'],
#  [' or mitti ka nhi puchi kuch kse kya hua'],
#  [' tu kyu ni aa pyga kal'],
#  [' ok', ' konsa h vse'],
#  [' how you type this'],
#  [' 🙂'],
#  [' kya hua'],
#  [' phone kyu kia'],
#  [' kyo', ' bhokega'],
#  [' teri gaali gayi bhofsde me'],
#  [' you deleted this message',
#   ' abe tu bol to hua kya',
#   ' bhesdike',
#   ' mera 1st year khtm'],
#  [' aarish mko amy ka photo bhja', ' puch ra hai ki kon hai'],
#  [' MediaShared',
#   ' bol deta hu gf hi hai usko',
#   ' uski',
#   ' kya hi ho jaega',
#   ' bol diya',
#   ' abe ae',
#   ' sun'],
#  [' .', ' .', ' bolega kuch', ' nahi to sahi me bol dunga'],
#  [' kya'],
#  [' abe tu pehle isko solve kar'],
#  [' kya dikkat hai bta'],
#  [' kya bawal ho gya bhai', ' .', ' .'],
#  [' kis chiz se jealous hai bhai unlog'],
#  [' paisa ???', ' propert???'],
#  [' fuck ill society people',
#   ' abe ye sab log bas bhokne ke liye hote hai',
#   ' just ignore them...'],
#  [' kyo', ' uska bhai kya kis', ' kia'],
#  [' bhai kitta bada hai or???'],
#  [' chodu log hai kya be unlog'],
#  [' ha to kya dikkat hai',
#   ' ladka to nit trichy ka hai',
#   ' or jab uski mmy ko dikkat nahi',
#   ' to wo aunty ki gaand me kyu dard ho raha'],
#  [' bol'],
#  [' ha pta hai', ' par confirmation le ra wo', ' finally'],
#  [' puch ra tha mere se',
#   ' kabhi mila hai baat kia hai???',
#   ' to mai bola ki mere frame of reference me uska existence virtual hai'],
#  [' abe wo bola ki tum tino ek hi school me the to kaise nahi mila tu aaj tak'],
#  [' tu gurantee ke sath kaise bol skta hai yahi usko gf hai',
#   ' tu khud usse baat nahi kiya hai',
#   ' or na dekha hai'],
#  [' to mko paradox lag ra tha sab'],
#  [' to mai clear kiya ki', ' gf hai bas yahi', ' itna maan le'],
#  [' pta ni'],
#  [' kyuki rat ko nhi mangaya kbhi'],
#  [' movie dek ra tha',
#   ' abe sun',
#   ' tu apna caller tune ko gaadi waala aayaa ghar se kachra nikal wala rakh'],
#  [' abe plz', ' rakh le'],
#  [' mai hi to call krta hu tko'],
#  [' ha to rakh le na be', ' mko mast lgta hai'],
#  [' abe to mai kse sununga', ' caller tune apna'],
#  [' tu rkhega to mai sununga', ' nhi be...san andreas thik hai'],
#  [' thik hai be'],
#  [' you deleted this message',
#   ' you deleted this message',
#   ' you deleted this message'],
#  [' kaise???'],
#  [' sham tak to 0 tha'],
#  [' abe ha thik hai', ' maan liya', ' lekin ase kse ho gya'],
#  [' tera exm konsa h'],
#  [' ok', ' ky hua', ' bsdk'],
#  [' hello hello bhk ra hu kab se'],
#  [' kuch bolta nahi'],
#  [' pta ni'],
#  [' cheating kia hga', ' khlna hai'],
#  [' ok'],
#  [' abe pucha hu'],
#  [' abe mko asa lg ra', ' dono ek dusre ke phone se chat krre hai'],
#  [' kis chiz ka', ' ??', ' sab to clear ho chuka na'],
#  [' nhi be',
#   ' de chuka hu sab',
#   ' you deleted this message',
#   ' acha sun',
#   ' 50 bcha hai mera',
#   ' mai de deta hu tko'],
#  [' abe...', ' bhj diya mai tko', ' tu abhi bol raha'],
#  [' check paytm'],
#  [' wo to roz jata hi hai', ' konsi nayi baat'],
#  [' abe', ' wo raste me hai'],
#  [' https://shellshock.io/#5yvy5t', ' join using laptop', ' ...', ' abe'],
#  [' .'],
#  [' kaha gaya', ' abe'],
#  [' nahi'],
#  [' dal kar dekh phir email'],
#  [' net slow hai kya tera'],
#  [' mobile me controls nahi hai', ' website se khlte hai isko'],
#  [' khol kar dekh phone me khul raha kya', ' ni khula kya abhi tk'],
#  [' aa gya hu', ' tu chalu kar', ' khlna', ' game start ho gya'],
#  [' tu or mai'],
#  [' cod jaisa hai', ' bas jo spoon hai', ' usko apne possession me rkhna hai'],
#  [' dekh na', ' yellow color ka'],
#  [' abhi spoon mere pas hai', ' mko marega to tu chin skta hai'],
#  [' kill me',
#   ' abe sniper le',
#   ' last gun',
#   ' mast hai',
#   ' dur se mar skta hai'],
#  [' abe'],
#  [' just touch kar'],
#  [' phir tere pas aajayga'],
#  [' marega mko phir le lena spoon', ' hold q'],
#  [' just walk over them'],
#  [' tu hai kaha', ' nahi dikh ra mko kahi bhi'],
#  [' kya'],
#  [' 10 min me ayga bola'],
#  [' ha', ' tu ni khel ra lya'],
#  [' kha gya', ' chl bhai', ' ho gya', ' aj ka'],
#  [' kya recording?'],
#  [' bol'],
#  [' acha sun na',
#   ' ek kam kr dega kya???',
#   ' you deleted this message',
#   ' bhut important hai',
#   ' urgent hai mko',
#   ' bolna bsdk.',
#   ' reply de'],
#  [' abe', ' mzk mt kr', ' mai mzk k mood m nhi hu'],
#  [' ksm se bhai'],
#  [' gand me danda dal...duniya hila daal', ' mar ja bsdk'],
#  [' shell shock khelega??', ' wwhi anda wala?'],
#  [' MediaShared',
#   ' abe',
#   ' bsdk',
#   ' aj skribbl khlna hai rat ko',
#   ' itne log hai',
#   ' tu bhi',
#   ' hai',
#   ' you deleted this message',
#   ' MediaShared',
#   ' .',
#   ' .'],
#  [' kya hua'],
#  [' kis chiz ka viva hai'],
#  [' abe aarish ko bhi bol na', ' agar mere se nhi bna to wo bta skta'],
#  [' acha'],
#  [' to usko pta nhi chlega kya ki kon join kia hai'],
#  [' thik hai'],
#  [' or wo sun legi to mko', ' call par'],
#  [' thik', ' kitne bje hai tera'],
#  [' ok',
#   ' pdf bhja nhi hai...mai pdha nhi hu...answer nhi bnega to bolna mt mko'],
#  [' kiska pehle ka 5'],
#  [' lodu hai tu'],
#  [' bhai aarish ko bhi add krwa le',
#   ' mko koi coloring agent nhi dikh ra',
#   ' e1 me'],
#  [' ok', ' thik'],
#  [' lawda ka start hoga'],
#  [' kya?',
#   ' abe mere pas 5.3 lakh rupees hai',
#   ' usme se kuch rkhega kya',
#   ' kuch din k liye'],
#  [' you deleted this message',
#   ' laude...',
#   ' tu maan bhi gya mere pas itna pesa hai',
#   ' lekin yahi chiz bolta ki mko ek ladki propose ki',
#   ' wo kbhi ni manega bsdk'],
#  [' filhal 6 tak hai', ' aage bhi badh skta hai'],
#  [' apna 100% chance hai'],
#  [' or bhej', ' bohot sara'],
#  [' aarish ko bhj deta hu', ' .', ' .', ' .                       .'],
#  [' aarish ko bhj dia kya',
#   ' .',
#   ' abe bsdk',
#   ' bol rahu kuch',
#   ' .                                             .'],
#  [' 🤣'],
#  [' nhi krta'],
#  [' chl na be'],
#  [' sahi me??', ' kb se chalu hai tera'],
#  [' mera feees dene ka time aa gya', ' 79000 le re hai', ' total'],
#  [' abe 99k dete hai'],
#  [' total???'],
#  [' hostel + mess + tution???'],
#  [' acha'],
#  [' category wise lete hai kya fees'],
#  [' tabhi'],
#  [' bdhiya'],
#  [' tu bhi follow krta h kya isko'],
#  [' abe ase hi likha hai', ' ki chhote college se hu', ' or successful hu'],
#  [' nhi', ' bas logo ka hype hai'],
#  [' ha', ' kyu?'],
#  [' nhi khride hai mithai'],
#  [' pta ni'],
#  [' phone hi chla ra tha'],
#  [' tinder'],
#  [' to take a look at the treasure i cannot possess'],
#  [' youtube chla ra be'],
#  [' https://youtu.be/7evftb68-pq', ' coursera...', ' and codechef'],
#  [' padhta hu or kya'],
#  [' abe islea 2 course lia hu', ' ek bore lgta hai to dusra'],
#  [' kyu', ' lauda kaat raha tha', ' bhosdike'],
#  [' bol', ' laude', ' rakhi dekh'],
#  [' nhi smj aya tko?'],
#  [' ha', ' tu likhta hai esa'],
#  [' bol'],
#  [' konsa'],
#  [' mere pas konsa card hai azure wala?'],
#  [' abe credit card leta hai', ' debit card nahi'],
#  [' acha', ' kitna price hai'],
#  [' rupay wala hai mera'],
#  [' nhi'],
#  [' 🙂'],
#  [' aloo ka pakoda????', ' saale jeere ka dana hai'],
#  [' bhosdiwale se baat', ' 🙂'],
#  [' kuch nhi'],
#  [' kal se class hai', ' to khalibaitha hu'],
#  [' nhi', ' aj soya hu bas'],
#  [' pta ni'],
#  [' abe ha'],
#  [' phir shuru krna pdega...'],
#  [' wrna aadat ho gya tha', ' football ka'],
#  [' mko bhi', ' asa lgra'],
#  [' ghar ke log the bas'],
#  [' bhilai se cousin log ni aye'],
#  [' abe',
#   ' tere me attendance hota tha',
#   ' to time kse dikhata tha excel me???',
#   ' duration a student was present'],
#  [' automatically???'],
#  [' bel bhesdike'],
#  [' ha to'],
#  [' abe web dev kr pehle',
#   ' kyuki tu acha kr leta hai',
#   ' ml ko bad me kr le',
#   ' abe besdike',
#   ' kha mar gya'],
#  [' abe agar asa hai to ml me kr le'],
#  [' krle bhai',
#   ' apne yaha to sab khud se krna pdta hai',
#   ' abe',
#   ' kal ayga kya'],
#  [' arish k ghr', ' sham ko'],
#  [' abe dekh...',
#   ' mai apna laptop le ke aunga',
#   ' or gta 5 download pe laga dunga',
#   ' phir wo bola',
#   ' hmlog khlne chl denge'],
#  [' police ground'],
#  [' ?', ' aaj ayga ki ni'],
#  [' kyo',
#   ' ho to gya laude',
#   ' 10 tarik nikal gya',
#   ' .',
#   ' bol na',
#   ' lode',
#   ' .'],
#  [' ha to ayga na',
#   ' sidha sidha bola kr',
#   ' khelne hi jynge',
#   ' eew aar chew tiya'],
#  [' tera hoga muda hua'],
#  [' ha tu aake hilaya tha na'],
#  [' usko condom bolte hai bandar ki jhaat'],
#  [' yeh bolne ke liye ki', ' aaj bahar ghumte huye ek loda pada hua dikha'],
#  [' to mai samajh gya',
#   ' tera hi hai',
#   ' islea puchne wala tha',
#   ' ki yaha kab aya tha tu?'],
#  [' lode rat ko call mt kia kar', ' mera phone charge pe tha'],
#  [' uth ke aara', ' nhi'],
#  [' opencv install krra', ' ho hi ni ra hai'],
#  [' khul gya hai sab', ' hai'],
#  [' no'],
#  [' 6 se'],
#  [' abe image processing k basics se start karne ka soch ra tha'],
#  [' abe ml me to krna pdega',
#   ' image procession vgera',
#   ' noice',
#   ' kuch criteria tha kya'],
#  [' nhi be...agar face detection banana hoga to'],
#  [' fir'],
#  [' club me join ho jyga fir tu?'],
#  [' abe...september me thoda bohot kia tha grayscaling vgera',
#   ' to lhea gotti ka nude photo use kia tha ...'],
#  [' top me thi', ' pornhub ke site me'],
#  [' abe ml ka club hai pehle se'],
#  [' abe apne yaha apply vgera nhi hot',
#   ' hota',
#   ' jo accha krta hai',
#   ' wahi head bnta hai',
#   ' baki co worker type session lete hai bas'],
#  [' abhi uska kuch aya nhi hai', ' apply krne ke lie'],
#  [' club ka??'],
#  [' ha hota hai na',
#   ' hua tha pichle sal',
#   ' ek curriculum tyyar kie the',
#   ' ki is date tak ye sab sikhaynge krke',
#   ' kuch ds/algo tha',
#   ' wahi sab'],
#  [' kaha', ' jana hai'],
#  [' ha jaa ra hu', ' abhi pichle 2-3 hafte se frustrated tha'],
#  [' ha'],
#  [' kuch krne ka man nhi krta tha',
#   ' mood fresh ke liye movie dekhne ka sochta tha',
#   ' to bhi bore lagta tha',
#   ' kuch smjh nhi ata tha'],
#  [' padhu ya movie dekhu'],
#  [' dono me man nahi lagra tha'],
#  [' kya krte rhta hai'],
#  [' onsite ky hta h be'],
#  [' kis tarah ka prjct'],
#  [' ohh', ' tu pura frontend + backend sikh liya hoga'],
#  [' abe uske liye khud se sikhna padra hai'],
#  [' or bhut time lagra sikhne me'],
#  [' kiska'],
#  [' ha'],
#  [' ek jhan live coding krra tha',
#   ' face expression wala',
#   ' to usi ke liye opencv dal ra tha',
#   ' lekin ni hora mere me',
#   ' pta ni kyu'],
#  [' abe wo stream ho chuka tha pehle me'],
#  [' ha'],
#  [' boring lgta bhai coursera'],
#  [' ok', ' kya hai rhyme ye bta pehle'],
#  [' acha'],
#  [' sun...'],
#  [' tu alag se concept nahi sikha hai na', ' web dev ke liye'],
#  [' bas project banaya hai', ' or sikh gya'],
#  [' sahi hai be',
#   ' ml me bhi try krta hu mai',
#   ' saala linear logistic regression hi batate hai sab course wale'],
#  [' status daal deta hu isko'],
#  [' ok'],
#  [' abe', ' 1 baje aarish ke ghar aa jana', ' dpohar', ' bol na lede', ' .'],
#  [' police ground',
#   ' https://discord.gg/yhtgzw',
#   ' be',
#   ' sun',
#   ' kya krra hai'],
#  [' acha...sun',
#   ' tko link me click krne to ata hai na',
#   ' ya phir maine achaar dalne ke liye bhja hai'],
#  [' acha', ' sahi hai tera'],
#  [' bhak lwde', ' mai ni padh ra pura', ' .'],
#  [' MediaShared'],
#  [' gaali likha hoga bsdk', ' akhri me'],
#  [' ruk dekne de pura',
#   ' bolna hota hai to sidha sidha bola kar',
#   ' ase dikag khrb hota hai'],
#  [' dimag*'],
#  [' lauda ka sarkar bol deta lwde ase hi', ' mai man jata'],
#  [' abe sun to'],
#  [' right le le aage se....phir fuck off'],
#  [' anti banti kar lia me pehle se. ....', ' tera effect reflect ho gya'],
#  [' MediaShared'],
#  [' beedi nhi pita mai', ' sanskar bolte hai isko bsdk', ' tu ni smjhega'],
#  [' mai jara ganga', ' 5 ko'],
#  [' nahi', ' dadaji...or daddy ke frnd k sath'],
#  [' road', ' laude mere jitna sanskari nahi milega tko'],
#  [' bohot jyada', ' or mai bhi sanskari hu'],
#  [' 🙂', ' gtfo'],
#  [' ????'],
#  [' chup be',
#   ' lgbtq chhakka nahi hota',
#   ' lesbian gay bisexual transgender hota hai'],
#  [' mkbmc', ' send me porn', ' something new'],
#  [' nahi be', ' asa kuch ni'],
#  [' tere pas rehta hai isliye manga'],
#  [' in cpp???'],
#  [' c++'],
#  [nan, nan, nan, ' acha', ' wo mern stack kya'],
#  [' ksa gya hackathon', ' abe ye aarish kuch alag gyan diya meko'],
#  [' cms kya hai?'],
#  [' ha'],
#  [' adveritsement se preshan hu'],
#  [' MediaShared', ' MediaShared', ' dekh'],
#  [' dekhna padega'],
#  [' wahi krra hu be',
#   ' abe maine apne college me club ke core member ke liye apply kiya  hai',
#   ' aiml ka club me',
#   ' uska interview lenge'],
#  [' ha'],
#  [' kab se kab tak tha tera hackathon?'],
#  [' or soya kab se kab tak??'],
#  [' bol na lode'],
#  [' abe mai 2 se 10 am sota hu roz'],
#  [' kse??'],
#  [nan, ' lucky guy'],
#  [' abe', ' ho gya interview mera', ' simple call me lia'],
#  [' abhi 2-3 log or bache hai', ' fir btaynge result'],
#  [' 10'],
#  [' hackathon pucha ...', ' courses bhi pucha'],
#  [' participate kiya hai ya nahi',
#   ' ye pucha',
#   ' phir wo course pucha konsa konsa kiya'],
#  [' bsdk...'],
#  [' log apply kiye', ' or interview le raha wk', ' wo', ' galat kya hai'],
#  [' abe wo bas experience',
#   ' presentation skills',
#   ' management skills',
#   ' vgera vgera'],
#  [' skills hai na to'],
#  [' wo bas ase hi pucha',
#   ' nahi hai to koi prblm nahi',
#   ' ase to merr pas bhi nahi hai'],
#  [' mai bola ki management experience to hai nahi',
#   ' lekin project 1 bnaya hu',
#   ' or ek in progress hai',
#   ' to current projext k bare me pucha',
#   ' to mai bola ki lip reading wala pe kam krra hu',
#   ' to bola thoda complex hai',
#   ' start kse kiye ho'],
#  [' dataset kaha se laogw', ' laoge', ' video rhega ya pictorial'],
#  [' you deleted this message',
#   ' ek ladka hai...kaggle me uska position acha hai',
#   ' to apne se compare kia',
#   ' to mai to kahi bhi competition ni dia hu ml k liye',
#   ' ...',
#   ' bol na bhosdike',
#   ' kha mar gya'],
#  [' let us c'],
#  [' tere ghr ka hai???'],
#  [' to itna kyu rota tha', ' noeteork ni hai'],
#  [' wifi lgya', ' sahi hai'],
#  [' kis tarah ka plan hai'],
#  [' to lode', ' bata na'],
#  [' mko bhi chiye kyuki'],
#  [' abe...'],
#  [' wifi ka kitna charges hai'],
#  [' ye puch ra'],
#  [' recharge ka???'],
#  [' per month?'],
#  [' company konsa hai??', ' kitna gb deta hai ek recharge me??'],
#  [' chup be', ' asa kuch ni hota'],
#  [' 40 gb 50gb rehta hoga', ' kisko pata hai hai', ' usse puch ke bata mko'],
#  [' 🙏🏻🙏🏻🙏🏻',
#   ' pata to rkhna chiye na kya samaan aya hai tere ghr uske bare me',
#   ' specially kuch technical chiz ata hai to',
#   ' you deleted this message'],
#  [' pucha rha jio wale se???', ' tha*'],
#  [' .', ' .', ' .'],
#  [' *rkhunga', ' abe', ' mai select ni hua'],
#  [' jo log jyda project bnaye unlog ka hua'],
#  [' 3 log huye select', ' abe kya kare improvement k liye'],
#  [' ayush mehar coding club me select hi gya', ' janta hoga shyd', ' ?'],
#  [' wse rank to achi hai unlog ki codeforce/chef me'],
#  [' research vgera ni be'],
#  [' ml related job mil jayegi',
#   ' jaye****',
#   ' abe ase mt jaya kr',
#   ' bhesdike....'],
#  [nan, nan, ' linkedin me post par post maare jaa rahe inlog'],
#  [' kya be', ' pura bol', ' saale wifi ka use kar', ' naya laga hai'],
#  [' acha'],
#  [' acha'],
#  [' abe to kuch ache projects to krne hote hai na'],
#  [' ha', ' krna hi hai'],
#  [' abe',
#   ' yar',
#   ' ase hi confusion ho jta mko',
#   ' saalo ko chiye kya',
#   ' yahi smjh ni ata'],
#  [' nahi asa kuch nahi hai'],
#  [' ha'],
#  [' ☹️', ' patta kat gya yahi'],
#  [' abe', ' tko ye sb pta chlta hai', ' to mere se b discuss kr lia kr na'],
#  [' wahi na be...',
#   ' kya jruri hai...ye smjh ni ata',
#   ' sesrch krna pdega mko b...'],
#  [' skill k hisab se'],
#  [' ???', ' kya puch raha', ' clear bol'],
#  [' .', ' abe mtlb google me hi likh du kya', ' job for software dev'],
#  [' *internships for software dev*', ' ase na'],
#  [' clear hai bhai', ' bas na skill ke piche jyada sochne lag gya tha'],
#  [' coding + dsa + system design', ' or phir ml/dl', ' ase'],
#  [' lamp mern vgera. to tere web dev ka hai', ' ??'],
#  [' acha'],
#  [' general???'],
#  [' 👍'],
#  [' thik', ' MediaShared'],
#  [' hao'],
#  [' hmm'],
#  [' abe', ' isme top 3 posts me kya difference hai'],
#  [' wrb dev hai na tera'],
#  [' mko laga coding walo ko bolte hai soft. dev'],
#  [' ok'],
#  [' abe or branch ka kya kare'],
#  [' ece'],
#  [' acha'],
#  [' ppo???'],
#  [' sahi h'],
#  [' kuch tie-up rehta hai kya company ke sath club walo ka?'],
#  [' to marks affect ni hota kya'],
#  [' ok'],
#  [' abe to tera nit t hai', ' ky frk pdta hga'],
#  [' kyo'],
#  [' linkedin???'],
#  [' acha', ' to jse mere college se to alhmni hi kam hai'],
#  [' kse'],
#  [' ok'],
#  [' pehle to teeno me difference ota krta hu', ' pata**', ' top 3'],
#  [' ok'],
#  [' software dev bnenge'],
#  [' acha'],
#  [' webdev or appdev hi hai kya'],
#  [' or nahi hita kya'],
#  [' ruk be mai hi dekh leta hu'],
#  [' abe or sun to',
#   ' mere yaha dsai wale log',
#   ' to asa kuch ni pdhte',
#   ' to unlog kya krenge btech k bad',
#   ' unlog ml ka hi pdhte hai'],
#  [' abe dsai branch hai mere yaha'],
#  [' past kaha se dekhu'],
#  [' hmlog k batch se start hua'],
#  [' aage??'],
#  [' .', ' to????'],
#  [' koi direct job ni dega kya', ' off-campus', ' ya campus me'],
#  [' acha'],
#  [' thik'],
#  [' dikhaya tha shyd tko syllabus'],
#  [' abe to log ache college se cse chhod kar aye hai pata tko'],
#  [' 4000 crl rank wala aya hai'],
#  [' to bhai tko college to mila na', ' branch ko chhod'],
#  [' chutiye', ' tu college acha gaya', ' waha branch matter ni krta'],
#  [' to???'],
#  [' ha wo to hai'],
#  [' abe', ' tu kitne bje uthta hai', ' or kitne ghnte sota hai?'],
#  [' .'],
#  [' general bata'],
#  [' ok'],
#  [' sounga mai', ' 15-20 min bad'],
#  [' class'],
#  [' ruk be',
#   ' 1-2 din ka time de',
#   ' soch smjh kr jawab dunga',
#   ' abey',
#   ' mai abhi bhi samajh nahi paa raha hu'],
#  [' software dev me mobile/app dev ata hai',
#   ' jo mai nahi krna chahta',
#   ' apne ko kuch programming wala laga tha',
#   ' sde log same hote hai kya'],
#  [' dekh wo konsa post hai jisme log dsalgo padhte hai',
#   ' competintion dete hai',
#   ' codechef codeforcd me'],
#  [' abe bsdk', ' mtlb'],
#  [' nahi  be'],
#  [' acha'],
#  [' sde or softwaere dev alag hote hai kya??'],
#  [' nahi  ussse clear nahi hua....wo to bas  roles ki bat kia isme',
#   ' dekh',
#   ' swe me konsa konsa domain bataya tha tu???',
#   ' bp;',
#   ' bolega'],
#  [' acha ha sorry', ' wahi', ' sde na??'],
#  [nan, nan],
#  [' abe', ' to ye sab ke liye html js css bs react sab sikhna pdega', ' .'],
#  [' bhosdika net me bhi kuch dhang se nahi likha hai'],
#  [' sde ke bare me'],
#  [' ha wo to pata hai'],
#  [' ki starting swe/sde se hota hai'],
#  [' abe', ' MediaShared', ' MediaShared'],
#  [' abe',
#   ' tu bol na',
#   ' mai bs pucha kya karu',
#   ' tere hisab se kitna sahi bol raha ye'],
#  [' senior h', ' nvidia me internship lia tha'],
#  [' lekin wo khud software engineer me intern ths nvidia me', ' tha*'],
#  [' asa to kahi ni likha hai'],
#  [' mai linkedin account dekha tha uska'],
#  [' MediaShared'],
#  [' MediaShared'],
#  [' ha...',
#   ' abe lekin thoda software dev krunga soch ra entertainment k liye',
#   ' web dev me',
#   ' full stack'],
#  [' acha'],
#  [' thik hai front end kr lenge'],
#  [' ok'],
#  [' ha', ' or bola bhi wo ki phd se jyada experiencr kam ata hai'],
#  [' MediaShared',
#   ' aaj kya kya kiya tu',
#   ' productive',
#   ' mai codechef ka dsa series start kiya',
#   ' code to kar liya',
#   ' test case bhi sahi aara',
#   ' custom input bhi sahi hai',
#   ' lekin wrong answer bsdka',
#   ' .'],
#  [' abe sun ..ab to tu koi bhi website aram se bana skta hai khud ka...'],
#  [' full stack to ata hi hai tko'],
#  [' bas project se sikha na tu'],
#  [' tutorial kiske?'],
#  [' abe', ' ek dhaansu chiz pata chla mko', ' apne institute ka'],
#  [' apna jo major project hai na...',
#   ' last year me',
#   ' usme kuch bhi bana skte hai irrespective of branch.'],
#  [' mtlb mai ek ml related software bana skta'],
#  [' mko laga tha ki kuch electronic drone banana pad jyga'],
#  [' abe kyuki sab branch related project hi banaye hai ab tak'],
#  [' kya pucha...🙂'],
#  [' ml ka pucha tere se', ' ??'],
#  [' lodu tha wo🤦🏻\u200d♂️'],
#  [' happens🙂'],
#  [' @cha', ' to backend pe kya kya kia'],
#  [' .'],
#  [' acha', ' sun'],
#  [nan],
#  [' iska backend ka code dikha'],
#  [' kitta bada hai code?'],
#  [' bas☹️☹️'],
#  [' isse bada to infix to postix likh skta hu', ' 113 line ka hai'],
#  [' abe data structure and algo me padha mahi tha kya',
#   ' convert infix expression to postfix'],
#  [' uska code', ' ha 12th me mko kuch smjh ni aya tha dsa', ' ab sahi hai'],
#  [' ha🤣', ' shyd code nhi pdhai thi'],
#  [' acha'],
#  [' hacktoberfest me lelena'],
#  [' yad se'],
#  [' hai kya bsdk', ' registration chalu ni hua', ' october me hoga'],
#  [' abe lekin project kse khoju ye smjh ni aara'],
#  [' ???', ' kya', ' .', ' ?'],
#  [' how to put this', ' MediaShared'],
#  [' you deleted this message',
#   ' you deleted this message',
#   ' abe mai ye stats ki baat karra',
#   ' readme me kse daala'],
#  [' ha to?'],
#  [' kaha milega doc??', ' lawde', ' sidha sidha bol deta', ' api hai'],
#  [' thik'],
#  [' 2 ladki ke sath hai',
#   ' ek bathroom me moot raha hai premier academy ke',
#   ' wo hai'],
#  [' or ek chodu bhagat wala photo hai', ' nahi', ' kaha dena hai???'],
#  [' apna bio wala bol raha kya??',
#   ' abe mko bhi khichwana hai ek dhang ka photo'],
#  [' acha'],
#  [' tu gay hai madarchod?', ' bol na bhosfike'],
#  [' ye kya hai smjh ni aya'],
#  [' chutiya hi bolta hai lede tu mko',
#   ' jabki mai hu nahi',
#   ' or wo tu hai',
#   ' chitiya deepamsu'],
#  [' abe mai dekha mera bhi 1* hai codechef me'],
#  [' gareeb hu...bas expect krta hu ki mko paneer hariyali tikka khila de...',
#   ' bsdk...'],
#  [' 4 tho diya tha us din'],
#  [' .', ' yahi ansr mera'],
#  [' laude..'],
#  [' kya anser du bhai',
#   ' tu apne hisb se bol de',
#   ' mko kaahe uncomfortable krra',
#   ' tu ek baat bta'],
#  [' abe ye sb ladkiyon wale matter hai', ' frnd hai ya nahi...', ' ye sab'],
#  [' ladki log jyda sochte hai',
#   ' apan tino b dost hai par explicitly bolte thodi hai'],
#  [' it is like...ayaz se puch rahe ho ki aarish ka bhai hai ki ni',
#   ' koi sense nhi bnta is type k ques ka',
#   ' 🙂🍕',
#   ' ye mri bt kyu krri hai aur???'],
#  [' thik hai na be...'],
#  [' it means ok', ' MediaShared'],
#  [' 3 din se codechef krra hu daily',
#   ' or aaj se decide kia',
#   ' class join krke chhod dunga',
#   ' baki apna kaam krumga'],
#  [' kya??'],
#  [' example'],
#  [' abe yar', ' mai apna ml development start ni kia'],
#  [' acha'],
#  [' ha wo to sikhna hi h bhai'],
#  [' .'],
#  [' nahi hua yar'],
#  [' apna bhi hai', ' lekin utna sufficient nhi'],
#  [' ja'],
#  [' ha..', ' ye bhi', ' ye bhi'],
#  [' ha cookoff diya tha', ' parso'],
#  [' codeforce yar ek bar koshish kiya tha'],
#  [' par ek bhi ni bna tha'],
#  [' last week', ' aaj khoj ra tha koi acha project', ' nahi mil ra'],
#  [' contribute krne lyak'],
#  [' nice', ' .', ' .', ' suggest me some'],
#  [' acha'],
#  [' sahi hai tera'],
#  [' alag se sikh raha ya project bna ke sikh raha'],
#  [' acha'],
#  [' bas yar kse kru open source koi guide mil jaye to badhiya ho jyga'],
#  [' ha bat krta hu abhi',
#   ' kal parso tak ayga bhai reply',
#   ' msg to kar diya hu',
#   ' lekin ek jhan se puch k kya hi mil jyga',
#   ' ek do se aur puch leta hu'],
#  [' kal call pe bataynge', ' isi time pe', ' isko status kyu dala hai'],
#  [' dal skta hai',
#   ' lekin koi specifi reason hoga na',
#   ' koi publicity ke liye bola hoga',
#   ' ya tera roommate likha hoga'],
#  [' acha'],
#  [' ha wahi padh ra hu',
#   ' abe bohot sahi hai',
#   ' maja aa gya mko',
#   ' pura padha mai',
#   ' shuru se akhri tak'],
#  [' kse???', ' follow kar diya hu spider ko'],
#  [' MediaShared', ' bel bhesdki'],
#  [' ok'],
#  [' abe mera nahi hai', ' dusre ka repo padh ra'],
#  [' mai surprisingly puch ra tha', ' ye krta kya hai vae', ' vse?'],
#  [' okee',
#   ' mera time bach jata hai tere se puch ke',
#   ' google me sab haga answer milta hai'],
#  [' MediaShared'],
#  [' link bhj', ' .'],
#  [' photo to acha hai tera',
#   ' lekin shakal utna acha ni hai...jitna photo me hai'],
#  [' apne isi photo ko github pe daal de',
#   ' apna face rkhna chiye github pry',
#   ' pe',
#   ' or tu hi dala hai kya apna website',
#   ' or koi ni dala hai',
#   ' jo dala bhi hai usme se bhi tera hi acha dikh ra hai'],
#  [' partition delete kr de', ' or bios me boot priority change kr fe'],
#  [' de*'],
#  [' abe easy hai'],
#  [' pendrive ko bootable bana ubuntu ka'],
#  [' ha wahi kar pendrive me', ' rook video bhj ra'],
#  [' https://youtu.be/9dr-b7c5mp4', ' itna kr'],
#  [' fark kya hai?', ' .'],
#  [' kse pata.'],
#  [' ha'],
#  [' mera to ho gaya tha sahi se'],
#  [' tv me kia tha mai'],
#  [' acha', ' to bhai', ' koi fark nahi aega'],
#  [' tko display resolution change krna hoga bas'],
#  [' ya fir mint krna to mint kar le agar lag ra to'],
#  [' ha to partition delete kar',
#   ' or boot priority change kar de bios me jaake',
#   ' bas itna hi krna hota hai'],
#  [' 🙂', ' boot prioriity change krna nahi smjha hoga', ' 🙂'],
#  [' MediaShared'],
#  [' tu kar liya kya???'],
#  [' review batana'],
#  [' tabhi krunga'],
#  [' ni pucha hu'],
#  [' MediaShared'],
#  [' MediaShared', " u'll get to know", ' bro', ' wait for it'],
#  [' chutiye', ' advance ka attempt 2 bar hi hota hai', ' MediaShared'],
#  [' MediaShared', ' MediaShared'],
#  [' ni failega',
#   ' islea personal bhja hu',
#   ' koi hashtag b ni dala hu',
#   ' MediaShared'],
#  [' 🙂', ' suna hai pura?'],
#  [' sun le'],
#  [' onion'],
#  [' MediaShared', ' kaggle'],
#  [' competition start krunga 2-3 din me',
#   ' abhi bas platform se comfortable ho ra'],
#  [' MediaShared', ' MediaShared'],
#  [' tere se bohot chhote hai',
#   ' bsdk tu pura website khada kar skta hai',
#   ' mai ek khud ka model b ni bana skta bina sklearn ka'],
#  [' shut the phuck up',
#   ' tu nitt me spider club ka member hai',
#   ' mko to liye bhi nahi aiml club wale'],
#  [' nahi'],
#  [' ek ladka kaggle 2x expert hai usko milega na'],
#  [' ha wo kami hai yar'],
#  [' tko pehla task kya mila tha'],
#  [' spider ka',
#   ' mtlb tko nahi ata tha webdev',
#   ' to tune sabse pehle kya kiya tha'],
#  [' acha', ' to usko tutorual dekh ke bnaya tha kya?'],
#  [' 🙂', ' 🙂'],
#  [' ase hi puchha', ' janne ke liye how did you start with webdev.'],
#  [' mko apne minor project ke liye....',
#   ' ui chiye...',
#   ' tu bnayega',
#   ' next year',
#   ' wo b free me'],
#  [' abe 3rd year me rehta hai na minor priject',
#   ' to usme kuch ai related app  kuch bnau'],
#  [' sikh le...'],
#  [' 😕'],
#  [' ha dekh lenge'],
#  [' ok'],
#  [' MediaShared', ' abe iska bday kab aata hai'],
#  [' what 3 yrs???', ' mai bola nahi pata', ' to bolta hai *no problem*'],
#  [' MediaShared',
#   ' mai puch liya tha...tera hai kya??',
#   ' to ab delete kiya wo msg'],
#  [' pta ni', ' MediaShared'],
#  [' 🖕🏻🙂', ' you deleted this message', ' MediaShared'],
#  [' bhosdika studious kon likhta hai',
#   ' ekdum geek type ka character ban gya mera...',
#   ' aradhna ka bday hai bola wo'],
#  [' f????',
#   ' flourine???',
#   ' .',
#   ' .',
#   ' press f to pay respects????',
#   ' bolna bhosdike',
#   ' ...'],
#  [' gand maraa bro gand mara',
#   ' ..',
#   ' bsdk sab element ke letter se hi yad rkhte hai...'],
#  [' MediaShared', ' nice creativity.'],
#  [' abe', ' bsdk', ' github chl ra hai tera??????????'],
#  [' check krke bta', ' acha', ' mera to problem loading page aa ra'],
#  [' sahi me???', ' internships????', ' kon diya???'],
#  [' to tu approach kiya ya spider wale log de re tko?:'],
#  [' acha'],
#  [' to usme tu jayga'],
#  [' freelance wala ka kya scene hai??????/'],
#  [' acha',
#   ' bc yaha mera dhang se data clean nahi ho pata',
#   ' 2 din se ek hi error ke piche pada hu',
#   ' or tu hai ki internship ja ra hai'],
#  [' abe to tu chal bhi dega......club wale hi bhj denge tko'],
#  [' nice',
#   ' mko utna maza ni aya lekin',
#   ' mai ek pr daal ke chhod diya',
#   ' koi dhang ka mere layak nai dikha',
#   ' manga le tsirt'],
#  [' abe ha wo pata hai'],
#  [' lekin ml ke nahi dikha kisi ka'],
#  [' deployment nhi ata mujhe'],
#  [' kaggle se ek dataset download kiya hu',
#   ' usi par ek acha model bana ke daal dunga'],
#  [' yes'],
#  [' MediaShared'],
#  [' MediaShared',
#   ' mere yaha ka ek senior se mai baat kia',
#   ' to wo bolta hai coding koi bhi kr leta hai',
#   ' keep your focus on statistics',
#   ' and keep learning'],
#  [' usko pdhunga or kya', ' vse bhi mera subject tha 2nd sem me'],
#  [' 8.2'],
#  [' lekin is bar gir jyga', ' bohot kam marks aya hai sabme'],
#  [' or is baar absolute grading hai',
#   ' bsdk tko fark bhi ni pdega',
#   ' tera college hai',
#   ' nitt',
#   ' mera hai iiitnr'],
#  [' ha wo b hai'],
#  [' to badha le'],
#  [' abe yr', ' mko bohot nuksan hua online se'],
#  [' .', ' .'],
#  [' assingments me...'],
#  [' kia tha lekin 2-3 assingment me 2 marks 6 marks aya hai', ' out of 10'],
#  [' pura mil jata hai tko???'],
#  [' mera 2/10...', ' 12/30', ' 9/10', ' 10/10', ' 6/10', ' asa hai'],
#  [' baaki absolute k vajah se mujhe ni lgta aa pyga'],
#  [' ha mko bhi', ' hmlog kitna bole inlog ko', ' lekin nahi maane'],
#  [' kyo', ' unko to khush hona chiye'],
#  [' apne yaha to inlog ko orgasm aa jata hai'],
#  [' director ko khaas kar'],
#  [' usko acha lgta bacche coding krre'],
#  [' bhok'],
#  [' kse???'],
#  [' jo acha lage kar de server me', ' bas mko permission dene ni ata'],
#  [' mai pura ownership hi transfer kr diya hu tujhe',
#   ' mtlb ab wo server tera hai',
#   ' ab jo krna hai kar',
#   ' koi acha sa naam bhi rakh'],
#  [' naam chamge kr dena server ka'],
#  [' ok'],
#  [' kr de🔥', ' naam dusra rakh yar', ' ye naam.mt rkh'],
#  [' abe tu koi acha sa naam soch k rkh', ' or change kr'],
#  [' koi faltu joke hi marega ab',
#   ' agar ha bolunga to',
#   ' MediaShared',
#   ' bolega kuch',
#   ' kya chiz me chiye?',
#   ' .',
#   ' MediaShared'],
#  [' subject?'],
#  [' mushkil hai'],
#  [' lab bhi hai mera abhi'],
#  [' chl thik hai', ' kitne ghnte ka hai', ' .'],
#  [' time???'],
#  [' adha ghanta hi help kr paunga', ' 2:30 se class hai', ' dsa'],
#  [' tera bhi itna hi bada hai?'],
#  [' nahi....tu hi bol chaah raha hai chus le mera...'],
#  [' mai ye sb ni likhta',
#   ' or vse bhi wo sde ban chuka hai...',
#   ' kuch bhi likhe kya fark pdta'],
#  [' MediaShared'],
#  [' MediaShared'],
#  [' abe',
#   ' wo kya grp hai bhai jo abhi bana',
#   ' kon kon log aa gye kaha kaha se',
#   ' discord server bhej. re',
#   ' unlog',
#   ' bhonsdike bol kuch',
#   ' .'],
#  [' yes.', ' mko acha nahi lgta gali galoch'],
#  [' bhok'],
#  [' kon kon'],
#  [' vibha to so gyi hai'],
#  [' kya'],
#  [' kiska', ' kisme'],
#  [' nice', ' tko ata hai kya cybersecurity', ' ni khelna kya'],
#  [' jo bhi hai tko ata hai kya', ' usme kuch flag vgera khojna pdta hai'],
#  [' using hacking skills', ' .'],
#  [' .'],
#  [' to tko hacking ati hai?'],
#  [' to kse kiya', ' html padh ke???'],
#  [' webpage ka'],
#  [' inshort yahi na'],
#  [' inspect jo krte hai', ' usi se na'],
#  [' tko sab ata hai ??'],
#  [' tu to bas code hi krta tha', ' backend frontend'],
#  [' ye sab kab sikh liya'],
#  [' ohhh', ' usi basic se 300 aa gya'],
#  ...]

# %%
start_list = []
end_list = []
for ind, (i, j) in enumerate(zip(conv_start.items(), conv_end.items())):
    
    try:
        start_list.append(''.join(i[1]))
#         

    except:
        start_list.append('')
    try:
        end_list.append(''.join(j[1]))
    except:
        end_list.append('')
#         print(j)
        
#     start_dict = {index: value for index, value in enumerate(my_list)}

#     print(ind, i, j)
#     break

#     try:
#         print("input: ", ''.join(i[1]), "\nresponse: ", ''.join(j[1]))
#     except:
#         print("ERROR: ","input: ", i[1], "\nresponse: ", j[1])

# %%
conv_start = {index: value for index, value in enumerate(start_list)}
conv_end = {index: value for index, value in enumerate(end_list)}

# %%
conv_start
# Out:
# {0: ' abe sun sun na laude missed voice call missed voice call',
#  1: ' abe ye mt bhja kr be ese iss grp m ldki bhi h usko awkwrd lgta hoga',
#  2: ' abe rs10 de to googlepay mei rs 5 bhi chlega abe sun ek',
#  3: ' ha to sun mai webpage bnaya khud ka mtlb files wgra sab repo mei dal dia hu or source code master repo se lia hi but wo github.io wla domain name milta hai n usme mtlb published bta to r hai but wo link kholo to bs readme.md wla file dikjaya hai mtlb uske andr jo likha hai bs wo to bta ab wo jo files mai bna ke dala hu usko use kyo nhi kr r hai ? bsdike sun 3 din hogya hai whi kr r hu smjh nhi aa r hai pura webpage bna lia hu but site mei aa nhi r hai',
#  4: ' abe ese mt bol rat rat jg ke bnaya or end mei dikh hi nhi r hai',
#  5: ' sab kr lia mai pta nhi prblm kaha hai bs readme.md ka contents dikh r hai hogya uske alwa kch nhi',
#  6: ' ha',
#  7: ' 😒madarchod fork kr le',
#  8: ' ruk public kr deta hu ab dekh abe dekha ? abe',
#  9: ' private kr dia hu abhi kam chal r hai uspe elements overflow wala prbln prblm*',
#  10: ' tere ko chiye kya ? fork kr le',
#  11: ' id ???',
#  12: ' abe wo id  mtlb wo part ko access krne ke lia css mei',
#  13: ' hoga be #tribute-link krke rhta hai css mei #tribute-link {',
#  14: ' fork kia hai kya usko?',
#  15: ' bsdike chori mt kr give me some respect fork krke use kr',
#  16: ' acha webpage wla pe mai overflow prbln se preshn hogya hi hu*',
#  17: ' usko dekh r hu 200 lins html mei 300 lines css ka framework use krne se easy rhta hai kya ? abe kkrh ? tu?',
#  18: ' grp dekh devblin.codes open in pc for better experince mobile mei bhi khol skta hai but bahut chota lg r hai missed voice call prjct pe kch kia ? aage?',
#  19: ' ok',
#  20: ' ha update kia hu',
#  21: ' hackermode khel ke hackermode',
#  22: ' ha',
#  23: ' ha task hai kahe ki 😂 abe thik se chala ? hackermode ? normal mode ?',
#  24: ' 😂jo game bnaya hu usme 20% html .....40% css.....40% js hai bahut sahi language hai',
#  25: ' ha',
#  26: ' js dom  pdh lia ?',
#  27: ' ohf yhi to main hai mere ko bhi induction strt hone se phle ye js psnd nhi tha programming lang typ hai krke',
#  28: ' ha yhi sn to hai',
#  29: ' ha 🤦🏻\u200d♂️ dynamic bnane mei kam ata hai jo tera bina life ke page rhta hai usko life dene ka kam krta hai ye',
#  30: ' bol',
#  31: ' abe 🤦🏻\u200d♂️',
#  32: ' kisme se pdh r hai ? tu ? konsa site hai yw ?',
#  33: ' dekh mai 7 din se kam kr r hu task pe to mere ko js use krne sahi dhng se ajata hai tu humre prjct pe kam krne ki kosis kr sikhte jyga tu mera mentor yhi bol r tha mtlb jb task mila tha to',
#  34: ' mann ke tere ko kisi element ko chupana hai',
#  35: ' wo element ka class mann le *game* hai to fir tu chahta hai jb tk window load na ho ya kisi button ko use krke usko visible krna hai to',
#  36: ' btn.onclick = function(){',
#  37: ' nhi isme kya ho r hai ki btn ek button ka object model hai mtlb button nam ka ek elment hai kahi pe html mei tu usko click kia to isme jo function hai wo hoga andr function ke hissb se "game" class ka display property "block" mei chnge krna hai jiske wjh se tere ko wo element dikga button click krne pe ese hota hai code chiye to apan discussion krenge 25 ke bd humre game ke logic pe kahe ki easy hai uske lia code likhna',
#  38: ' ha bol r hu game pe kam kro aram se sikhenge js apan',
#  39: ' mzk mei mt lena  apan locally scores save bhi kr pyenge apne game mei js  script language hai isly easy hai bahut',
#  40: ' thoda basic pdh le',
#  41: ' what ?',
#  42: ' abe ye uncle aunty hai kya ? abe uncle ka shirt pant mst lg r ha8 combination style',
#  43: ' ha tu hi c reh gya',
#  44: ' abhi ? mtlb ? kya hua ?',
#  45: ' abe mtlb abhi present mei admit hai kya ? to tu ja r hai ?',
#  46: ' apollo ? mere ghr',
#  47: ' ajata',
#  48: ' raste mei pdta hai',
#  49: ' ha thik ha to ajata wps ghr',
#  50: ' thik hai',
#  51: ' .... ? kb ?',
#  52: ' 🤦🏻\u200d♂️ kb ja r hai gaon ? bro ?',
#  53: ' tu thik hai ?',
#  54: ' 😯😯😯😯',
#  55: ' maine group mei mtlb github wla grp mei dal dia hai code jyda kch nhi hai ek div elment hai yellow uske andr red wala ek element hai jo move kr r hai eventlistener rkha hu uss red box mei MediaShared',
#  56: ' hai kon ye ?',
#  57: ' 😯 fok bapre kya bt hai',
#  58: ' nhi be 😂 mere se ye sb nhi hota but acha bola tu 👏🏻 or abhi kya kr rha hai ?',
#  59: ' abe thoda practice bhi kiye kr ipython shell mei bhej de😂 wo jo pdhata hai uske sth experiment wgra kr liye kr to sahi rhega bs pdhte mt ja koi fyda nhi hai fir krta hai ki nhi practice ?',
#  60: ' thik hai kr lena kya kar rha h ? hey brosdikw missed voice call abe ek bt puchna hai mere ko agr tu free hoga to msg kr dena pls',
#  61: ' oye ye kya hai mobile hath mei rkhta hai to bhi call nhi uthata hai',
#  62: ' to mai konsa muh se bolta mai i jst want attention kr r tha abe mere ko n agr kisi profs ke under mtlb mere hi collg ke uske under kam krna hai to kese approach kru prof ko ?',
#  63: ' tell tell acha agr wo prof mera mentor hai to ?',
#  64: ' koi fyda hai ?',
#  65: ' kya ? fyda ?',
#  66: ' ok or sun wo jo prof hai',
#  67: ' uska profile bahut tgda hai machine learning computer vision',
#  68: ' ke field mei or apun ko uske under kam krne ka hi hao but dikkat ye hai n ki mere ko knowledge hi nhi hai',
#  69: ' kya likhu ?',
#  70: ' to uske sth phle discuss kru ?',
#  71: ' ya fir apne ideas du ? or bt kru ki ispe kam krna hai ye wo',
#  72: ' ok',
#  73: ' ok ok ok ',
#  74: ' ok got got it',
#  75: ' ha',
#  76: ' ok to kya bt chal ri hai ? fir ? acha',
#  77: ' acha acha smjha ruk ek min ha abhi tu iot pe kr r hai n projct ek ? to wo tu prof ke under kr r hai n ?',
#  78: ' konsi 🧐 sahi rhega fir to internship bhi kr pyga 😯',
#  79: ' 🥺 😯 acha oppurtunity hai',
#  80: ' tu akela nhi hai be logo ke job gye',
#  81: ' internshio internship tk gye tu hackerrank use krta hai?',
#  82: ' mere ko pta chala ki hackerank apne yha ka startup hai',
#  83: ' agya hai bsp ? bol',
#  84: ' to tu kya chah r hai ?',
#  85: ' abe ek bt bta chal dpge doge fir aunty',
#  86: ' akele kese rhengi ?',
#  87: ' tere ghr ke ps relatives hai ?',
#  88: ' fir bhi badi bt to hai',
#  89: ' to wo dur hai be kitna tum log',
#  90: ' mangla side rhte ho too tougj mai bachpan mei mumy mai mera bhai bs rhte the to mumy ko bekar lgta tha',
#  91: ' or tu log bhi chal doge',
#  92: ' ana bhi pdega tere ko to sunday vibha ko bhi',
#  93: ' but tere ko krna pdega n',
#  94: ' i advice you to do this  can',
#  95: ' or vibha kya krti hai ? ajkal ? wo kesi hai ? abhi ?',
#  96: ' exam ? google form mei ?',
#  97: ' cheating krna possible rhta hai kya ?',
#  98: ' ha wo to hai or udhr bahar nikal rhe hai kya log ? tere ghr side ?',
#  99: ' hair ka hi pta chalega',
#  100: ' abe bahut banjar jindagi lg rhi hai abhi jb bsy rhta hu to pta nhi chlta hai idhr udhr krta hu to yad ata hai kch nhi kr skta abhi ghr bethe bethe pagal ho r hi hu mai 2 din se 1 obstacle ke logic pe kam kr r hu pura circle ka concept use kr lia mai',
#  101: ' but its tough nind nhi ata hai sote tym sochta hu sala ye krung ye krunga ye idea krta hu esa krte krte 4 bj jata hai fir late uthata hu',
#  102: ' tera class chal rha hai kya ?',
#  103: ' abe mera',
#  104: ' eg ka class hota hai',
#  105: ' or madam attendance bhi leti hai kahe ka nice 2 hrs bethna pdta hai',
#  106: ' uppr se attendance or uppr se wo bich bich mei bolti hai kcj explain krne ke bd why only i student responding what about others fir sab bhed bakri type yeah yeah krte hai or 2-3 log to sbse jyda bolte hai',
#  107: ' unki awaj chubhti hai kan mei mere',
#  108: ' abe hum uss madam ko sbse bdi c smjhte th the kahe ko sb bde wale profs jo the har mann gye online class ke lia but wo hai ki consistencely 3 classs le chuki hai bakayda jo absent rhta hai uska absent kregi or to dont give proxy i heared this voice again ka hua be bhai ?  kya hua be tere ko rply nhi de r hai',
#  109: ' u should rply 2-3 hi logo ke msg ate hai bs mujhe usme tu bhi rply nhi dega to kese chlega be',
#  110: ' zbro',
#  111: ' bol bol bol bol bol',
#  112: ' ae ungli mt dikha abe sun be',
#  113: ' ka ka r r hai ?',
#  114: ' kya krta hai be dinbhr ? too much busy ? nowadays ?',
#  115: ' nice uthata kb hai tu ? subhe',
#  116: ' thik hai',
#  117: ' we will be coming morning not tommorow nhi',
#  118: ' is it okay for uh ?',
#  119: ' abe apan algi ki algo agli subh3 ayenge bol r hu',
#  120: ' tere ko chlega ?',
#  121: ' esa puch r hu 8 bje as ps ayenge due to lockdown timmings',
#  122: ' ok abe mai arish ayenge bol re the hai* kal to tere ko chlega ! ? koi prblm ho to bol skta hai',
#  123: ' sorry bro',
#  124: ' sale sorry likha hu usme kya kya',
#  125: ' abe ane wale the n apan but meri wjh se nhi aa paye',
#  126: ' yes',
#  127: ' no bro',
#  128: ' are',
#  129: ' mai 6 bje uth gya tha nikal hi r tha fir scooty mei fss gya abhi leke gye hai bnwane ke lia',
#  130: ' ha',
#  131: ' kaha ? verzeo ?',
#  132: ' ohfo to bn gya hai ? tum log ka prjct ?',
#  133: ' oho 🙄 kya ? mere ko abhi tk smjh nhi aya hai ye',
#  134: ' oho 🤦🏻\u200d♂️ ok got iy it ye roller coaster ka physics hai mtlb math wala part',
#  135: ' haa',
#  136: ' mai tere se math m aage rha hu bsdike 😒😒😒',
#  137: ' calculus ke lia apun ne 1 month chutti mari thi school mei',
#  138: ' are ye roller coaster wala',
#  139: ' track dekh k smjh aya ki acha graph to tum log rolercoaaster bnane wale ho kya ?',
#  140: ' abe  sun infinity sign',
#  141: ' path ka equation hai kya ?',
#  142: ' wtf kaha se itni jldi sahi hai kya ye ? 😳',
#  143: ' 😳 🙄😳😳😳😳 ye link bhj to site ka sb shape bna skte hai kya isse ?',
#  144: ' bsdike pta to ho ki function hai kya',
#  145: ' abe sun ubuntu ka sapce space bdha skta hu kya ?',
#  146: ' 😂 nhi mar jaunga  ye sb krunga to',
#  147: ' ha abe mai dekha tha partition ka pta nhi kya kya tha abhi recelty mrra ubuntu ajib behave kr r tha terminal gyab desktop gyab bs app dikh r tha',
#  148: ' bs python uninstall kia fir ho r tha',
#  149: ' 🙄 mtlb?',
#  150: ' mai bhi kia tha fir mai uninstall kr dia 😂',
#  151: ' abe mere mei terminal hi nhi tja exist hi nhi kr r tha tha*',
#  152: ' abe sun to fir',
#  153: ' restrt kia tha mai to black screen mei dikha r tha ki kch delte krna hai ye wo to mai sb kia to ubuntu firse install kia tha mai syd to fir thik hogya',
#  154: ' ha abhi to thik ha8 hai* naya version chal r hai but files sb safe tha jaha tha sb whi tha',
#  155: ' kya hua ?',
#  156: ' audio on krke khlna abe kya hogya ? whts the prblm ?',
#  157: ' abe wo task ka tha be mera',
#  158: ' task2 khel k dekh abe to mai bhi nhi de pa r hu delta ke tasks ke wjh se',
#  159: ' ye bt alg hai tu bhi pdh hi r hai',
#  160: ' kya hai ye ?',
#  161: ' kiska?',
#  162: ' significan kya hai iska?',
#  163: ' ohfo phli bar suna dekha mai to',
#  164: ' esa grpah ...',
#  165: ' ha abe mtlb isse kya pta chlega apan ko ese type ke graphs se?',
#  166: ' acha pta chal gya box plot jesa hota hai bs ye probability density bhi dikhata hai',
#  167: ' esa kch likha hai',
#  168: ' ha to',
#  169: ' acha ',
#  170: ' box ploy box plot pta hai ? or denisty  plot?',
#  171: ' ha to ye inn dono ka combination hai ab smjh de mere ko ki fyda  kya hua',
#  172: ' ok ok to prediction hai ki 60-80 ke bich ho skte hai ? agr test data dalega to?',
#  173: ' ok abe sun verzeo ka kesa',
#  174: ' lg r hai tere ko ye ml wala?',
#  175: ' ha mai soch r tha ki coursera mei koi sa course kr lu ml pe uska fees nhi dia hu n abhi ml wala',
#  176: ' using python ? hai ? ha isly to tere se pucha',
#  177: ' ha ???',
#  178: ' abe but mai dekha tha wo octave mei krata hai',
#  179: ' fok mai dekha nhi',
#  180: ' 🥵 ok',
#  181: ' ha octave wala h',
#  182: ' ha or koi course dhyn mei hai tere? jisme python ho abe how to go pro in data science wala link mila kya tere ko?',
#  183: ' milga to mujhe bhi bhj dena',
#  184: ' email',
#  185: ' abe tu cmmnt kia tha n yes email id esa krke',
#  186: ' ek min',
#  187: ' MediaShared',
#  188: ' ye tere tha ki wo c ldki bhi cmnnt ki hai',
#  189: ' oops sry mere  ko wo chinese ldka tu lga',
#  190: ' ok khrid lia mai bhi gtav',
#  191: ' attitude ki dukan kis bt ka attitude hai didi ko 😯',
#  192: ' tu ka kr  hai ? rhene de tu bhi na btaya kr kch ese log ko',
#  193: ' abe bol',
#  194: ' 😯 abe kch krte hai be something interesting',
#  195: ' abe',
#  196: ' 😂abe ye 150 rupiya dega wala status sahi hai tera',
#  197: ' 😳 mai bhi kr leta hu kch idea de wo totla ka rkh lu kya ?',
#  198: ' usko wo chote height wala kon tha 25 din mei pesa double wala',
#  199: ' ha iska 😂 dekh ab 😂',
#  200: ' kya ?',
#  201: ' ab',
#  202: ' ha whi soch r hu la baba 5 crore ?',
#  203: ' 😂 https://devblin.codes abe ye dekh be pura responsive bnaya hu iss bar page ko',
#  204: ' to bna le',
#  205: ' abe to page hi to bnana hai',
#  206: ' to mai bs html css hi use kia hu',
#  207: ' no no js only html css abe mere page ke niche pdhna credit dia hu 😂 madw with html css https://html5up.net/ isme dekh le ye sb html ae kachra seth',
#  208: ' dekha isko?',
#  209: ' ha to idea dene ke lia ludo',
#  210: ' ha but bahut sara rhta hai unka code',
#  211: ' bol bol na bsdikhe',
#  212: ' kya nhi mila ? 😯dub ja ek glass pani leke',
#  213: ' iya',
#  214: ' kya hogya',
#  215: ' hai be tere ko kya chiz ?',
#  216: ' acha  koi ek template choose kr or mere ko bhj',
#  217: ' link bhjna',
#  218: ' to tere ko code chiye uska ?',
#  219: ' bsdike  wo to blogger ka template lg r hai',
#  220: ' acha sry abe simply download kr download button dikh r hoga n usse ek zip file milega usme sab hai bs apne hissb se content chnge krna pdega tere ko then you r ready to go template whi hai',
#  221: ' wtf MediaShared ho kya gya hai be tere ko dinbhr kya krta hai ?',
#  222: ' laptop?',
#  223: ' kaha h ? abe 15-20 min ka  kam hai isse page ready krna',
#  224: ' koi acha sa dekh k bna le',
#  225: ' ha abe kya kar rha h bhai bt kr mere se',
#  226: ' feeling low nowdays',
#  227: ' kch krne ka mnn nhi krta be agr krne ka sochta hu to kese krunga kch ata hai nhi',
#  228: ' wo sb vhor',
#  229: ' abe mai kch',
#  230: ' notable krna chahta hu idea ga9 hai* but pta nhi mnn krta nhi hai kyoki ata hai nhi kch mere ko',
#  231: ' uea yes ek chat bot bnana hai taki uske sth mai bt kr sku',
#  232: ' abe mera idea hai n usme n mai jo whtsapp ke chats hai usme se export krunga chat ko as a training data to fir mer chatbot usse sikhega or fir syd',
#  233: ' natural bt kr pau ha bol',
#  234: ' to',
#  235: ' bol',
#  236: ' abe nhi be mere ko',
#  237: ' whi krna hai jo mai socha hu',
#  238: ' tu log krega kya',
#  239: ' yhi chatbot wala',
#  240: ' bsdike ek prjct pending hai abhi tk',
#  241: ' kya ha team kya pta ye prjct startup bn jaye chatbot wala',
#  242: ' co-founder bn jyenge tino ha to kese krenge arish pubg khlte rhta hai',
#  243: ' grp mei aa tu soch potential hai isme mere hissb se hai ki nhi bta ?',
#  244: ' bsdike potential mtlb potential hota hai',
#  245: ' idea idea bol be bol',
#  246: ' 😂 fok mam man fok 🥵 🤦🏻\u200d♂️ kya tu jag rha hai',
#  247: ' abe ye verzeo ka major prjct mila hai usko mai kese kru mtlb kch log bol re hai ki kam bat lete hai wgra wgra',
#  248: ' 2 din phke',
#  249: ' chutuye tera ml wla h',
#  250: ' pta hai ka kr r hai be missed voice call',
#  251: ' online bulane ki ninja technique abe ka kr r hai be bhai mere se to bt kiye kr tu hi hai sahara abhu abhi',
#  252: ' ka kar r h tu?',
#  253: ' missed voice call abe',
#  254: ' abe prof ko mail kia tha mai to rply m wo bola ki pde pdgo pdho* for oct m bt krega research prjct pe',
#  255: ' partial differential eq.',
#  256: ' abe sun be wo prof ko rply kese du ? jldi bol be',
#  257: ' abe ek min tere ko bhjta hu pura tu pdh ke btana abe esa nhi ki bs oct mei bt krenge iske bare mek wo bola ki advance books wgra dekho ye wo abe sun be ja ka kar rha h ?',
#  258: ' bol bhai ka krya hai',
#  259: ' kya hua bol',
#  260: ' 😏tere se phle ka update kr chuka hu',
#  261: ' online hi jaha kaha rhta hu mai',
#  262: ' 1 bje to soke utha hu aj baki coursera or prjct kr r tha verzeo ka',
#  263: ' tu ka krta ha hai be',
#  264: ' or? MediaShared jldi grp mei aa',
#  265: ' chk krke dekh kon hai mere  ko to nhi pta kya msg aya hai ?',
#  266: ' oh ye to wo hai linkedin wali',
#  267: ' mere ko bhi ki thi',
#  268: ' kyo ?',
#  269: ' m a cbsdi bsdhike bsdike',
#  270: ' abe sun',
#  271: ' guu kha le bhosdike zeher walo kheet bhi kha le',
#  272: ' kha le na',
#  273: ' abe shriya btech',
#  274: ' bs likhi hai btech + mtech likhna chiye tha usko',
#  275: ' ha uska acc. dekhna btech 2019 - 2024',
#  276: ' sirf btech likhi hai bol r hu mai',
#  277: ' MediaShared testing backend thing',
#  278: ' bsdike *about* pdhne bola tha g andhe',
#  279: ' bsdike test kr r hu chi tu filter use krta hai b s d i k e l d k i y o wa le shok k bse pal r ha',
#  280: ' mai bsdikw k ka kr  rha yai hai gurlfrand dhundh lia gai kya ajkal itna bt krta hau',
#  281: ' abe sun ve be',
#  282: ' abe bittu ke papa ajib behave kr rhe hai marne warne ki bt kr re hai',
#  283: ' bolte hai *mera akhir tym agya hai* ghr mei sbkoo preshan krne se acha to yhi hai ki chal du',
#  284: ' 😰',
#  285: ' nhi  koi reason nhi hai ese pine ka bittu bolti hai ki koi baba bola tha ki uske papa pe koi kala jadu kr diye hai syd uss wjh se',
#  286: ' bhai wo kch month phle car lene wale the but bittu mna kr di thi pese ka koi prblm nhi lgta mujhe',
#  287: ' to kya krna chahiye ? psychatrist ke pss bhja jaye ? abe  khana bhi nhi kha re hai kch month  phle maze mei the',
#  288: ' ka hogya? abe sun bsdike kal badmintom khelenhe subhe mai jldi so jaunga aj pakka tu bhi jag jana nehru chowk ke pss ke park mei badmintom kaha bsy hai ? seen to kr be tu bahut badal gyi hai re chinmi chinki chintu hadd hai wtf u r cordssing',
#  289: ' bsdike msg pdh le pura',
#  290: ' le ana',
#  291: ' mere pss hai but colg mei to mai nhi la r arish ke pss ha9',
#  292: ' khelne lyk hai?',
#  293: ' le ana',
#  294: ' are arish ka bhai bhi to hai',
#  295: ' nhi ayega be arish ka bhai wo bola ki round mei khelnge 2 log fir 2 log or net nhi hai',
#  296: ' ha be',
#  297: ' 🤣 ek min puchne de hona to chiye hoga be ;@ ha hai wo bola tere pas cock hoga to le ana 🤣',
#  298: ' missed group voice call bsdike abhi yad aa r hai tere ko bdy uncle ka',
#  299: ' oh',
#  300: ' 👍🏽',
#  301: ' happy bdy mere trf se bhi uncle ko apna site host kr r hu',
#  302: ' taki tum log use krke dekho kya fock?',
#  303: ' usme kya bada kam db bnao or hosting se hos tkr do',
#  304: ' jldi aa MediaShared bs grewal ka laplace transformation wlaa chapter ka solution hai ki nhi tere psss ? aj submit krna hai assignment dhundh de be solution dila de',
#  305: ' ata hai tere ko laplace?',
#  306: ' kr de bhai tu bhi post father day la ka',
#  307: ' 👍🏽 u shit mot rply rplying egoist',
#  308: ' to ? mai kya kr skta hu isme',
#  309: ' kidhr?',
#  310: ' oh nhi chlata mai bhai instagram',
#  311: ' abe acc. nhi hai mere pss',
#  312: ' ha to pichle sal hi kr dia tha',
#  313: ' sst hi bhj de na lodu 🙄 wtf',
#  314: ' 🤨insta bhi incoginuto?',
#  315: ' DeletedMsg',
#  316: ' DeletedMsg bsdike',
#  317: ' bsdike',
#  318: ' ka bol boli be tu bta ka kr rhai itni rat ko kya be tera numbr coverage chrtra se bahar bta r hai',
#  319: ' kya nhi 2 bar call kia mai tu kia rha tp to* kidhr gya tha?',
#  320: ' kiska ghr hai ? bilha m?',
#  321: ' ok or call kahe kia tha ?',
#  322: ' thik hai or tera car predicition wala model use kese krte hai ? or tu log function use krte ho ? sicktlearn ? pandas mese ? or code likhte ho ? mere ko bhi sikha de thoda',
#  323: ' ha but nhi krta hu mai usko nhi hai pdhne ka isly puch r ju hu mere ko insect classify krne wala model bnana hai mtlb mai photo lu insect ka or mere ko pta chal jaye ki ye hai konsa insect ya esa kch to kese krunga ye mai?',
#  324: ' ha yhi to bta hai n bsdike ese hi sikte gai to or kch prerequisites? hai kya ? ki chalu kr du ? bol na bsdike gali gloch psnd nhi mere ko bolega',
#  325: ' acha ye to ata hai plot krke ye pta chlega n ki mera model kesa kam kr r hai ? eda ? kya hota hai?',
#  326: ' ok ok ... kya bt hui be tere senior se any imp info?',
#  327: ' thik gai',
#  328: ' startups mei intern krne ka fyda to hota hai ye mai pdha tha mere dhyn mei kch startups hai ai pe ... haptik lekin yha kese lete hai idea nhi hai',
#  329: ' ha pdh lia abe ye to sde hi krta hai',
#  330: ' abs mtlb  tu pucha kyo nhi ki cloud ke bare mei kahe pdhna hai ? mtlb janna hai',
#  331: ' oh ok..cloud isly bola hoga kahe ki ajkal sab data cloud pe rhta hai',
#  332: ' inka nam kya hai ?',
#  333: ' ae lodu ludo* kjelga?',
#  334: ' chepli kahi ki lodu kgel r gai kya ? oh ab smjh aya adha tym tera mobile hang ho jata hai isly lgta hai ki tu bsy hai😂 ae indian guy wamt abusive wrds to get pressurizrd in your ear drums? bol na ludo abhi ldki msg ki hoti to... *ha bolo mai to free hu* *sun r hu bolo*',
#  335: ' kha kya? laude bol na',
#  336: ' to google pe dekh ye ajib chiz kya hai',
#  337: ' ha mai chnge kia tha',
#  338: ' kya dekhu?',
#  339: ' randy orton kyo bn r hai wo kya hogya be call kahe kia th a? missed voice call',
#  340: ' ha to?🙄 bolega ?',
#  341: ' kya kch nhi ... bsdike puri bt to bol',
#  342: ' ha to de d de* usme  kya h',
#  343: ' koi ldki hoti to bolta kch kch😂🤣😂',
#  344: ' depends on girl',
#  345: ' ??? kb ??? bhai?',
#  346: ' acha.... mai to nhi khichaya tha ab khinch di thi bina btaye to meri kya glti h',
#  347: ' wtf ?',
#  348: ' ye kon',
#  349: ' ye kon de dia tere ko?',
#  350: ' kb ka hai ye ???',
#  351: ' bhai mai esa kam bikul nhi krta',
#  352: ' apna photo share wala apni dp tak nhi lagata mai to photo post kaha se krunga ?',
#  353: ' ave abe',
#  354: ' ye kb ka hai??? ye btayega ?',
#  355: ' ???',
#  356: ' acha ? 🙄🙄🙄',
#  357: ' 😂 acha tere ko jalane ke lia',
#  358: ' bhja rha hounga',
#  359: ' wo bt alg hai',
#  360: ' 70677 nitin hai kya ?',
#  361: ' backdhoi kr r hai',
#  362: ' kya nice laude tu 1 din bd rply krta hai',
#  363: ' kch nhi bs ldki bnne ki kosis kr r tha',
#  364: ' abe',
#  365: ' bol r hu usko mai ki trichy ajana tu bhi',
#  366: ' wo bol r hai ki nit kyga jyga* btaya usko mai ki apun depression mei rha',
#  367: ' 90 se uppr',
#  368: ' haaa',
#  369: ' ha bhai trichy mil jyga usko',
#  370: ' usko bs mai itna bola ki baki tu bhi usko bol de apne trf se bsdike linkedin mei msg mt kia kr profession jgh hai wo unprofessional kam mt kia kr bsdike ganda admi hai tu isly esa kam krta hai',
#  371: ' tu bsdike missed voice call kya be call kyo ki thi?',
#  372: ' kisi se nhi mentor se bt krr  tha',
#  373: ' doubt',
#  374: ' kch nhi mumy ko lga bhinga hu barish mei to mai bola nahi bhinga hu or kch nahi',
#  375: ' nahi',
#  376: ' •_°     assignment likhna hai',
#  377: ' math',
#  378: ' symbols abe abe arish ka ststus dekh 🙂',
#  379: ' 🖕🏻🖕🏿 missed group voice call',
#  380: ' kya ? kya hua?',
#  381: ' bsdike saram kr le thoda',
#  382: ' bho s dike',
#  383: ' kaha ? ja rhi hai? bol na laudu laudi tu laudi hai laudi MediaShared bol na bsdike ignore bsdike ab tu msg krna fir mai rply dunga',
#  384: ' missed voice call',
#  385: ' nhi pta tujhe kch',
#  386: ' kya ?',
#  387: ' bahut prblm hai bro',
#  388: ' bittu ke colony mei',
#  389: ' bsdiwali auntiyo ka conspiracy chal r hai bsdike ye ab chor mera to dimag',
#  390: ' abe uske papa abhi thik nhi hai thode or office ka kch bt tha to ek bsdiwali aunty pure colony ko jama krke bawal kr di ak aj bittu ki mumy ko suna ke bina wjh',
#  391: ' jealous aunty asshole aunty got no chi bcoz bittus dad transfered his husband',
#  392: ' to janjgir',
#  393: ' to bakchodi kr rhi thi ki kahe lagaye ? kyo lagaye ? bhai kyo kahe kya hota hai sbka tranfer hota hai duty mei but wo aunty ko duty office or personal matter ke bich differnce nhi smjh aya to jst like an illiterate person she came barking with household media',
#  394: ' ha whi be... but bitti uske bhai ke bare mei ulta sidha bt kr re the alg se wo log bittu ke ghr ane se phle',
#  395: ' kch nhi....wo aunty log ki ye sikhayat thi ki uska bhai bhondu hai',
#  396: ' 💁🏻\u200d♂️ 12th mei hau',
#  397: ' or ye log bittu ke line mei nhi rhte hai piche rhte hai or bittu ko koi frnd btai ki wo log bittu ke bare mei bhi ulta sishda bt kr re the ki koi ldka ata hai maestro mei blabla',
#  398: ' wo hi jane abe',
#  399: ' ye tk to* arish ko pta hai n?',
#  400: ' nhi bolna tha tere kk ko',
#  401: ' acha 🙄 sahi hai or ka to mnn lia wo?',
#  402: ' 😂 point to hai',
#  403: ' 😂 bapre',
#  404: ' abe whi hai bs tu paradox chalne de',
#  405: ' 🤨 abe doninos kb tk deliver krta hai ? rat ko?',
#  406: ' tere kk kese nhi pta ye sb ke bare mei 🤨',
#  407: ' abe tu ka krte rhta hai itne rat ko? der rat ko?',
#  408: ' kyo? 🙄 bsdike log kachra wala smjhenge mere ko',
#  409: ' kya m ?',
#  410: ' bhag be to usse kya hoga ?',
#  411: ' abe krishna wala thik hai logo ko shanti milti hai wo sunk to tu rkh le',
#  412: ' to laude ringtone rkh le',
#  413: ' bhga be mai nhi krunga change ese',
#  414: ' missed voice call',
#  415: ' MediaShared',
#  416: ' 🙂',
#  417: ' devblin codechef search kr le',
#  418: ' ye to apun ko nhi pta',
#  419: ' chems',
#  420: ' abe khlna',
#  421: ' hai ki nhi aj ?',
#  422: ' wtf is arish where*',
#  423: ' 24/25 chemistry ct 😎 abe to khelena hai ki nhi lodu',
#  424: ' na bhai open book tha google ki help lia',
#  425: ' call kr usko mere mei balance nhi hai abe kia ki nhi be ? bol na auntt au kya ghanti mai baju kya sot mai lagu kya 🙂',
#  426: ' to ky bola wo?',
#  427: ' ha whi kr re hai bsdike uske ghr mei hainwo wo 2 bje se .. missed voice call bsdike tu mere ko rs 100 dene wala tha n',
#  428: ' grp pdh*',
#  429: ' nhi arish ko de de....usko fir mere ko usko 50 dena hoga',
#  430: ' chor mai bhj deta hu usko',
#  431: ' paytm nji hai mere  lss ayega to bta dunga nhi aya  hai abj9 missed group voice call he is going to meet his gf missed voice call',
#  432: ' bsy hai abhi wo call pe shriya bhi bsy hai lockdown kbse hai?',
#  433: ' 🤦🏻\u200d♂️ ldki ke chkkr mei hum nhi khel pa rhe hai🤦🏻\u200d♂️ usko puch aa pyega ki nhi 🤦🏻\u200d♂️',
#  434: ' bol',
#  435: ' ba khol r hu',
#  436: ' email adress dlana pdta hai kya?',
#  437: ' puch to r hai or load nhi ho r hai tym le r hai',
#  438: ' yhi ho r hai kbse MediaShared',
#  439: ' ho skta hai mobole mei kya prblm hai ?',
#  440: ' ok',
#  441: ' yhi dikha r hai kbse khul gya isme.kia hu jlin join abe aja bsdike',
#  442: ' ok abe ae ruk na bhai mai naya hu ake mar dia bs or ko  kon hai? agame mei?',
#  443: ' bolega ? or kya krte hai isne ?',
#  444: ' konsa ? spooon?',
#  445: ' ok ryk abhi mrna mt dekhne de sb',
#  446: ' mere pss kese ayegam kese chinunga ?',
#  447: ' okkm abe tu leke kese bhag r hai? spoon ? abolega tu pkd ke kese bhag r hai ?',
#  448: ' hold kese krte hai?',
#  449: ' ok',
#  450: ' or bomb kese fekte hai?',
#  451: ' om chize kese uthate hai? bomb pde rhta hai to?',
#  452: ' ok hindi mei bol skta hai',
#  453: ' bsdike',
#  454: ' arish ko bula grp mei bol fri shriya bhi ajyegi',
#  455: ' ok mere ko acha wo isi game meinayeya?',
#  456: ' aa r hu ruk customize kr r hu chal aa ab',
#  457: ' abe sun tu mere ppt ke lia recording kr dega kya ?',
#  458: ' ppt bta dunga script tu kr lena record parts mei krna hai jya nhi juda missed group voice call abe sun',
#  459: ' MediaShared',
#  460: ' chal gudnight maza aya apke sth',
#  461: ' maa kasam kha ke bol to manunga',
#  462: ' ...',
#  463: ' MediaShared',
#  464: ' DeletedMsg DeletedMsg DeletedMsg DeletedMsg DeletedMsg DeletedMsg DeletedMsg missed group voice call MediaShared MediaShared',
#  465: ' abe sun missed voice call',
#  466: ' aj mera viva hai or tu help krega mai pdf bhj r hu',
#  467: ' lab ka chemistry ka madam ms teams mei legi',
#  468: ' abe lab manual mei sb mil jyga bs tu dhyn se sunna madam jo ques. kregi',
#  469: ' ha',
#  470: ' abe nhi tu whtsaop call mei rhna mai speaker pe kr deunga',
#  471: ' ha',
#  472: ' tu mute rkhna bs tu sunna usko',
#  473: ' 11 bje',
#  474: ' wtf phle ke 5 hi se puchegi pdhne ki zarurt nhi hai tu search krke ansr bta pyega',
#  475: ' pdf ka abe fok send hi nhi hua tha mere ko lga bhj dia hu',
#  476: ' aa r hau MediaShared mai tere ko whtsapp pe bolega jese e1  coloringagent mtlb experiment 1 mei coloring agent bta agr bs wrd bolu to ya sentence to uska ansr de dena e2 indicator e3 mtlb experiment 3 itna smjh jana bs tu baki pdf search se try krna dhundne ka hojyga',
#  477: ' abe example de r tha',
#  478: ' hoga strt to msg krunga',
#  479: ' ye kya ludu lussun hau',
#  480: ' nhi bhai',
#  481: ' 🙄 nhi abe lockdown kb khtm hoyega ?',
#  482: ' abe mere yha virtual sem hoga 80% chances hai',
#  483: ' abe krta hai dinbhr ? MediaShared',
#  484: ' nhi hai dhundh ke thodi bhjta hu garib ki madad krne ja r tha ye to lga educational ',
#  485: ' kya ?',
#  486: ' 🤦🏻\u200d♂️ nhi abe ye kya hai sale tu bhi to',
#  487: ' ignote krta hai 🙂',
#  488: ' mai bhi kr r 🙂 lauda ka',
#  489: ' endsem hogya mera ab mai bhi 2nd year mei hu',
#  490: ' ye sb nhi pta',
#  491: ' noics bahut jyda hai',
#  492: ' mai 18',
#  493: ' or iss bar mess ka na dena pde syd',
#  494: ' total 45000-50000 hai syd',
#  495: ' pta nhi ache se 50k se kam hai ha tution nhi lgta mere ko',
#  496: ' 62k hai tuotion ha',
#  497: ' or jinka family income 1 lakh se kam hai unka bhi kam hota hai tuition mei',
#  498: ' bwahhaha MediaShared',
#  499: ' nhi wo conneciom mei se koi like kia tha to dikh r hai',
#  500: ' 🙂 yhi to puch r hu koi mtlb hai iss bat ka ?',
#  501: ' ok or tu ka karte rhta hai ajka ajkal tu rakshabandhan manayega kya ? kal?',
#  502: ' mithai bhjwa dena fir',
#  503: ' kahe ? son papadi khyega kya?',
#  504: ' oh abhi ka kr r hai?',
#  505: ' ka chalata hai? linkedin ? tinder ? instagrama fb?',
#  506: ' kahe ?',
#  507: ' oh  enlish mei bola',
#  508: ' mt kiye kr ye sb achi bt nhi hai or kch ? nhi krta ?',
#  509: ' oho ye kese krta hai ? ye sb dekht hai ?',
#  510: ' abe mtlb whi pdh kese leta hai? bore nhi lgta ? ki wtf pdh r hu',
#  511: ' 🙂 mai neuroscience pe ek course lia hu or computational biology 🙂',
#  512: ' abe ek bt bta',
#  513: ' kya hai rakhi mei?',
#  514: ' bo no abs bd abe lode nodejs ml enthisiast 🙂',
#  515: ' nhi 🙂 tu abe sun tera card',
#  516: ' dega kya',
#  517: ' azure use krna hai merr ko',
#  518: ' abe visa/mastercard hai ???',
#  519: ' nhi dono chlta hai',
#  520: ' rs 2 katega bs',
#  521: ' abe yr ... shit tere pss azure hai kya ?',
#  522: ' abe dekh na try kr ek bar abe',
#  523: ' chus chus mera loda jese aloo ka pakoda',
#  524: ' abe ka kr r hai?',
#  525: ' abe boleha',
#  526: ' abe dinbhe ka krta hai',
#  527: ' aj kch tufani kia ki nhi ?',
#  528: ' mt hila bhai itna or lockdown kb khtm hoga ? jldi bnd kra bhai futbol khlna hai',
#  529: ' fir adat khtm',
#  530: ' kya ha ?',
#  531: ' kya chiz ?',
#  532: ' abe body...flexible rhta hai n ghr mei pde pde rust lg gya hai lgta hai',
#  533: ' baki log to baki kya sale tu bhi rakhi mna r tha itne sare logo ke sth dar nhi lga ?',
#  534: ' social distancing ki abcd',
#  535: ' ok got it',
#  536: ' time joined time left jitne bar join left kreg sb dikheyga',
#  537: ' ha abe',
#  538: ' abe mera yha r&d club ka inductiin strt hone wala hai',
#  539: ' to usme webdev aur ml dono hai to mai konsa kru ? dono kru ki ml kru ki webdev ?',
#  540: ' abw ye to chal hi r hai delta ka spider rd club hai n or wo log ieee mei paper wgra  publish bhi krte hai to mai soch r tha ki ml mei kru to ye sb jyda kr paunga webdev mei bs best practices sikhna reh gya hai mtlb 2 profile mei apply kr skta hu mai to mai dono mei apply kru ki koi ek smjh ni aa r hai',
#  541: ' ha mujhe bhi yhi lg r hai ki ye krna chiye',
#  542: ' kaha ?',
#  543: ' kya ke lia ?',
#  544: ' kaha ?',
#  545: ' acha',
#  546: ' nhi sayd',
#  547: ' abe to mai khelne aunga bol r tha',
#  548: ' or tu laudamod 🙂',
#  549: ' tera hai muda hu hua* 🙂',
#  550: ' nhi tu circular tube mei dal dia tha lamination hogya tera ludu ka 😂',
#  551: ' circular tube* 🙂 aj tk circular tube ko condom smjhta rha tu🙂 you are MediaShared ae bsdike tu call kia tha ? 6 bje ? kahe ?',
#  552: ' ok',
#  553: ' got it DeletedMsg a e sun abe',
#  554: ' so r tha kaya?',
#  555: ' to fir',
#  556: ' mt kr...fir abe wo chor merr ko ye bta bahar ka sthithi kesa hai abhi? bhid bhad ? jan ko khtra ?',
#  557: ' police checking ?',
#  558: ' kbse ?',
#  559: ' achnk opencv! ? changing path ? to cv ?',
#  560: ' abe mera nam shortlist hogya delta ke lia ....',
#  561: ' ha wo to uske andr  hai n....to cv hi krega kya ? ha.....task ke basis pr last task bahut kam log kiye',
#  562: ' or abhi onsite hoga or hackathon',
#  563: ' onsite mei daily 4 din tk ...6-7 hrs mei ek topic ke uppr bnana hoga last mei main product iss basis pe hoga swagat club mei',
#  564: ' tu bhi bna r hai face detection ? abe pornstar ke nam pta krne wala bna le...bahut fyda hoga kbhi kbhi bahut jyda janne ki iccha hoti hai ki ye pornstar hai kon aba ha',
#  565: ' ye suna suna lg r hai..achi h kya ?',
#  566: ' or tere wo s&t ka kia tu apply ? tb jake kch months mei tu apne yha ke jo bhi student se reltes kam dekhta ho department/arra',
#  567: ' to tu apply kr r hai ki nhi?',
#  568: ' abe head nhi memebrr ? ki bt kr r mai',
#  569: ' induction to hota hai n ?',
#  570: ' ha',
#  571: ' ok....to tu ja r hai ml ke sth ?',
#  572: ' bsdike uss disha mei ja r hai kya puch r hu',
#  573: ' ok ja fir ml wale club ka dekh lena apna...nhi to tu bhi kr skta hai ye kam hafte ?',
#  574: ' kahe ?',
#  575: ' abe bsy rkhne ke lia kch hai nhi',
#  576: ' tere yha',
#  577: ' abhi mere yha spider spider ka to form bhi agya mai to yhi krte rhta hu mentor bhi mere ko',
#  578: ' congo kr r tha to usse puch lia ki koi mini project de do krne ke lia to wo topic dega bola hai esi timepss bnane ke lia onsite se phle',
#  579: ' abe bola to....daily ...4din 6-7hrs project',
#  580: ' webdev ka hi',
#  581: ' tu bhi chota mota project kiye kr ha',
#  582: ' devops nhi....webdev bs soch r hh devops ke loa apply kru',
#  583: ' abe tutorial dekha kr.... fir kya kiye kr ki wo jo bhi chiz bnata hai',
#  584: ' tutorial mei tu uskl modify krna apne hissb se ese krke',
#  585: ' sikh lega abe ml ka',
#  586: ' abe live coding mt dekhe kr aage piche krne mei prblm jata hai',
#  587: ' acha.. tere yha..coursera ka mila hai n ?',
#  588: ' usme rhyme ka rhta hai',
#  589: ' hands-on prjct wo try kr ek bar',
#  590: ' abe jese deeplearning.ai ka course dikhega tere ko vesi hands-on project ka ek section hai',
#  591: ' dikhnana chiye chk kr lena',
#  592: ' kya ?',
#  593: ' kiska ?',
#  594: ' ha',
#  595: ' abe mtlb esa nhi hai ki mai nhi pdha hu...mai *for the sake of learning webdev* nhi pdha.....mai *for the sake of making the project possible* isly pdhta gya process mei or mere ko pta bho nhi chala ki mai kch pdh bhi r hu ab jese tu bolega ki mai pdh leta hu thoda js css wgra',
#  596: ' abe mtlb tu ek ex-googler hai uska video dekhna wo bhi yhi bola ki mai kbhi koi language isly nhi sikha ki mere ko ye ana chiye wo bs ek prjct sochta tha ki ye bnaunga or uss prjct ke hissb se language dhundhta tha or bnate bnate sikh jata tha try kr prjct dekh le koi jo bna r ho  fir tu uss prjct  ko apne hissb se modify krne ki kosis krna...to tu sikh hi jyga at the ens end*',
#  597: ' wtf',
#  598: ' mai 4 bje aunga khlne location send me',
#  599: ' onsites chal r hai',
#  600: ' abe abhi nhi kr skta join discord pe online rhna pdta hai or call wgra krte hai udhr se',
#  601: ' kya? -__________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________ ...
#  602: ' oh okay pdh lia hai tu chadarmod',
#  603: ' ha to kya ? readmore to ese bhi dikhata hai back krke wps ane pe',
#  604: ' oh you dont know me kid gali wali chor dia mai dena',
#  605: ' .',
#  606: ' yhi aim hota hai',
#  607: ' ....',
#  608: ' suri i am bsy bzy jo bolega whi hoga',
#  609: ' .. ..',
#  610: ' to bhai neutral hogya mai tantra mantra kr dia isme hi no reflection',
#  611: ' MediaShared',
#  612: ' MediaShared ram teri....ganga melli hogyi tere pap dhote dhote 👍',
#  613: ' apne pap dho lena corona hai corona 5  akele?',
#  614: ' flight? train?',
#  615: ' tere laude sanskari hai?',
#  616: ' i doubt',
#  617: ' lkbht lgbt',
#  618: ' l a u d e k a b a l h a i t u c h a k k a',
#  619: ' mkbhd',
#  620: ' fir depression mei ja r hai kya ?',
#  621: ' frustration?',
#  622: ' bsdike nhi hai abhi mern pdh r tha stack* hackthon bhi hogya mera delta ka',
#  623: ' chances kam lg le re hai mere vese kyoki webdev mei bahut competition hai cpp kya h?',
#  624: ' ane webdev ka  h mongodb',
#  625: ' ha',
#  626: ' sahi tha cms bnana tha 8hrs mei mtlb or options thr but mai cms bnaya',
#  627: ' wix jnta hai? wix.com',
#  628: ' ? bs whi bnana tha',
#  629: ' jisse users apna webpage bna ske kya ?mm ?? bolega bsdike',
#  630: ' wtf ye sb kya h? porn  access ?',
#  631: ' bsdike kam kr le kch',
#  632: ' to tyari kr le',
#  633: ' mai april ke bd kal dhang se soya hu hackathon khtm hua fir abhi spider ka bhi krna hai',
#  634: ' ye to 9am to 5pm mai pura process ka bt kr r hu induction process',
#  635: ' 🙂',
#  636: ' 9 se 10am pm*',
#  637: ' lucky guy',
#  638: ' kyoki mere ko sone ka tym nhi milta do{search ',
#  639: ' kahe ka lucky',
#  640: ' select hogya?',
#  641: ' total kitne the ?',
#  642: ' ho jana chiye bsdike kya puche m ???',
#  643: ' mtlb  ???',
#  644: ' acha ye kya direct interview kaha se pta chlega',
#  645: ' kch ata jata hai nhi',
#  646: ' task ?',
#  647: ' mai hota to tere yha select nhi hota kabhi kyoki ye sb nhi hai mere pss or mere type log honge tere yha',
#  648: ' jo deserve krte honge but experince wgra nhi hone se',
#  649: ' to kya kya bola hai tu?',
#  650: ' oh my gad',
#  651: ' fir ? kya bole tere ko kya lg r hai? hojyga ?',
#  652: ' abe frk nhi pdta utna kaggle se google mei bhi ml engineers hai mere yha bhi hai wo sv kaggle nhi krte',
#  653: ' backdhoi mt kr sbka alg path hota hai MediaShared',
#  654: ' yes🙂',
#  655: ' bsdike aj lga gai wifie',
#  656: ' MediaShared',
#  657: ' ye to pta nhi puch ke btaunga',
#  658: ' kya !',
#  659: ' tu konsa plan pucha ? charge wala?',
#  660: ' ya total?',
#  661: ' total 5000',
#  662: ' lga installation',
#  663: ' sb mila ke ye syd 1000',
#  664: ' download speed max 90 ha syd',
#  665: ' unlimited hai',
#  666: ' ye sure nhi hu 🙂 isly bola mujhe nhi pta',
#  667: ' puch ke btaunga ka pitashri se wo hi lgwaye hai kyoki i doubt konsa plan hai 🙂 pitashri mera to hogya bhai sb fast lg r hai ab',
#  668: ' idhr jiofiber nhi aa  r hai nhi to wo hi lagwata',
#  669: ' ha wo bola nhi lg skta mere area mej',
#  670: ' ye bt bhi hai aage se dhyn rkhna iss bat ka',
#  671: ' kese ? kitne log hue? select ?',
#  672: ' oh acha ui ke wjh se patta kat gya mera 😭',
#  673: ' kya ! m ???',
#  674: ' wo developer hai n',
#  675: ' abe tere ko kya krna hai ? mtlb research mei jyega ? ki software?',
#  676: ' dev?',
#  677: ' kyoki dekh tere ko agr ml mei jana hai to ',
#  678: ' 3. khud se research wgra 4. professor ke under ya jese bhi 🙂 tere ko software dev',
#  679: ' bhi ana chiye kyoki or mai medium wgra mei dekha hu future ml ka',
#  680: ' ki software developer le lenge ml engineers ki jgh kyoki inko koi bhi chiz sikhne mei prblm nhi jata jese webdev se appdev mei ja skte hai ml mei bhi jate hai ese hi log',
#  681: ' tere ko safe side mei rhna hai to software development  krna pdega ml ke sth',
#  682: ' ruk ek min MediaShared google mei internship ke lia tere ko minimum qualification chiye kisme dekh le prefered dekh le mostly kya hai prefered mej tu ml positions ke lia bhi internship dhundega jese nvidia mei to wha bhi jyda kch chiye ml/dl internships ke lia phle internship krega n???',
#  683: ' microsoft dekh le sbka internship amazon ka ml wgra mei internship dekhega to only for phds ms exception btech walo ke lia agr wo conferences mei sahi se publications wgra kiye ho',
#  684: ' hyperverge inc. hai ek startup uska deeplearning ka internship ka dekh le agr tu badi companies soch r hai to forget it yha tere ko sirf software developer',
#  685: ' bnke jana pdega startups or bta di rubrik haptik ye jo startups hai khas kr ye',
#  686: ' inko iitian chiye interns ke roop mei yha mera mentor kia hai',
#  687: ' ha bhai hyperverge inc. ka dekh le ek bar wo achi startup hau hai* https://hyperverge.co/careers',
#  688: ' bsdike research krta hu mere skillset ke hissb se ab mere ko kya pta ki tere ko idea nhi hai',
#  689: ' ye dekh le isme ai roles mei deep learning internship hai',
#  690: ' python chiye',
#  691: ' ....',
#  692: ' phle internship* tu aim kr google ke lia ese krke tere ko nvidia  ya startup mei aram se mil jyega mai abhi mern sikh r hu lamp ata hai thoda bahut fir dsa kr lunga',
#  693: ' ha kr le bs tere ko clear rhe ki tere ko kya krna hai',
#  694: ' b.tech ke bd direct ml engineer ki job expect mt krna thoda hard hai....',
#  695: ' abe mere ko dsa ka need tb smjh aya jb mai develop kr r tha apps ese mei mere lia hard tha isly mai phle tech stack sikha koi sa jese lamp ab mern sikh r hu dsa is jst need main hai webdev baju mei dsa',
#  696: ' ha....',
#  697: ' mtlb tu dekh le konsa sahi hai tere kia ml hai to sahi se kr le but general ana chiue tere ko bhi',
#  698: ' tu search kr how to get job as ml engineer as undergrad fir tere ko smjh ayega ki kya krna hai internship dhundhna phle agr satisfied  na lge to job ka dhundhna',
#  699: ' ha ja kr search tujhe kya smjh aya',
#  700: ' ha smjh gya n tu?',
#  701: ' ha fir tu meri bt se confuse hota usse acha tu khud dekh lia sacchai',
#  702: ' ab bol kya krna hai ?',
#  703: ' vese to mujhe bhi utna nhi pta  same hi hote hai syd developer jese mai hounga abhi kisi club mei jaunga to software developer',
#  704: ' but engineer nhi hounga ha wo software mei ata hai webdev ho ya appdev',
#  705: ' mtlb humre yha jitne clubs hai wha sb software devs hai software  engineer koi nhi likhta apne  profile mei',
#  706: ' ha usme tera system administarator webdev',
#  707: ' appdev kya branch?',
#  708: ' oo bhai mai ice wala hu mere branch se ek bhiya ko uber mei sde ka role mila hai wo delta mei developer the ek civil wali didi',
#  709: ' ko microsoft mei internship + ppo mila',
#  710: ' wo bhi delta mei developer thi ppo - pre-placement offer',
#  711: ' mtlb delta  sbko mil jata hai job developers ka',
#  712: ' nahi re bhai sb talented ppl hai hardworking sahi wrd hai interested pol ppl* ek bhiya gsoc kiye wo os bnaye the khud ka dekhega usko to lgega ye to chutiya hai joki mere ko bhi lga tha dekh k delta wale khas kr delta ke kam ke lia cts skip kr dete hau classs chor dete hai',
#  713: ' bola to sbko job mil jata hai esa koi ni hai jo jobless ho',
#  714: ' 7 cgpa wale hai kai log',
#  715: ' nhi... ye jo tu soch r hai sbkko on campus milta hoga job to glt hai sb offcampus dhundhte hai',
#  716: ' jo simple log hai abe kyoki logo se to offer mil jate hai ya fir syd cgpa kam rhta',
#  717: ' delta alumni google ibm sb jgh hai abhi jese iss sal microsfot  to abhi jo club mei hai unke lia fyda hai kyoki ye log ko pta hai ki delta mei kese log hote hai',
#  718: ' or tu to bhai ece wala hai mil jyga ese bhi',
#  719: ' mehnat krega to hojyga',
#  720: ' vese tu kya role pe kam krega ab? abhi?',
#  721: ' mujhe bhi bta dena top 2 ka',
#  722: ' https://shecancode.io/blog/software-developer-or-engineer-whats-the-difference#:~:text=in%20the%20end%2c%20software%20engineering mil gya',
#  723: ' ha ab dekh le kya kya domain hai softwaredev mei webdev vast hai appdev hard hai thoda.....with library its easy without library its too hard',
#  724: ' webdev krega to html most important',
#  725: ' ye ache se kr lega',
#  726: ' system administrator ek role hai mere yha pta nhi jyda iske bare mei devops = webdev + sysads',
#  727: ' ha dekh le',
#  728: ' wo tu past placements ke hissb se dekh ki kya krte hai......',
#  729: ' kyoki',
#  730: ' ha pta hai',
#  731: ' oh to ab tu placements ka wait kr ....................... research agr research krenge abhi to',
#  732: ' aage?? kya?',
#  733: ' to highers ke lia hi jyenge or kaha jyenge ya to university mei kisi prof ke under internship krenge',
#  734: ' ye to tere collg ke seniors se puch wo log jyda jante honge',
#  735: ' kyoki new branch hai',
#  736: " though dsai doesn't make sense data science alg hai ai se ds mei to data ke rang roop ko pdhte hai ai mei to data use krke human-like software/machine bnate hai to ese dekhe to tere yha dsai walo ka syllabus bahut bda hona chiye",
#  737: ' ha risky hai wo branch as btech for* kyoki ai mei job wo bhi undergrad',
#  738: ' its close to impossible',
#  739: ' ha......pta hai mai bhi bhopal ka cse chora hu',
#  740: ' but u see the difference abhi syd mai bhopal mei cse leta to jo abhi kr pa r hu nhi kr pata same is for dsai',
#  741: ' ha.......iiitr tu soch ab iiitr+dsai (new)',
#  742: ' sbke sb cs ke placement mei bethenge ya highers jyenge ya research bhai kyoki koi ai ke lia undergrad ko nhi lega......itne bde bde collg se sirf sde/swe ke roles ke offer ate hai iitb ...............',
#  743: ' tu kbhi suna hai ml enginer from iitb got offer ka milta hai branch matter nhi krta......ab mme wala sde tha ms kia cs mei ab ml engineer hai fb mei cs wale bhi management mei ja re hai ab mere yha hi kai log cs wale hai but developers nahi hai sbka alg alg chal r hai koi designer hai koi consultanting club mei hai',
#  744: ' abe fix nhi hai esa kch ab class chalu hogya hai to class ke tym se 1.hr phle uthna pdta hai🙂 or abhi spider ka chal r hai',
#  745: ' ye bhi fix nhi hai jb tk nind na khule tb tk sota hu',
#  746: ' abe nhi hai esa mai bs rat ko sota hu ab abhi sounga to 9.30 bje uthunga kyoki 10.30 ko class hai ya jyda kam hota hai to 3 bje sota hh 12 bje uthta hu ya 1 bje abhi spider ka chal r hai to fir whi hoga syd but ab easy lg r hai sb task',
#  747: ' kyoki bahut practixe hogya hai mera delta ke wjh se😒 kyo tu kitne bje sota haim ?',
#  748: ' kya kr r hai! ? tu ?',
#  749: ' 🙂 bsdike i meant tu kya development suru krega  ?',
#  750: ' kya???',
#  751: ' software development engineer swe - software engineer software developer kya programming ?',
#  752: ' competitioj ? chutiye🙂',
#  753: ' tu abhi bhi cc/cf ko soch r h uss way mei ? 🤣',
#  754: ' bhai tu developer hai to bhi tere ko dsa chiye not necessarily this delta mei ese log bhi hai jo competitive programmin nahi krte',
#  755: ' but dsa ka gyan hai tu sirf dsa krne ke kia dsa krna chahega to fir its tough',
#  756: ' swe* sde* ye log architecture dekhte hai pura use krke ye to bhja tha tere ko tu chahe ese ja  ',
#  757: ' mai software developer ka btaya tha',
#  758: ' webdev',
#  759: ' as per my knowledege baki tu dhundh le arish bhi software dev mei lga hai opensource contributions krke',
#  760: ' webdev ....yes',
#  761: ' kiske lia?',
#  762: ' tere ko ml krna hai to tu kr skta hai.... but ye hai dont expect ml jobs as undergrad highers krke expect kr skta hai bahut chances hai ms',
#  763: ' krke',
#  764: ' software developer domains youtube mei search kr https://youtu.be/_9zs6q4996g https://youtu.be/ogy_uk6frge',
#  765: ' tere ko jo thik lge kr bhai',
#  766: ' deep learning internship -> hyperverg inc. (startuo) ha kon ye ? senior hai kya ?',
#  767: ' ml ? acha wo to kr tu ml ka esa hai to',
#  768: ' kch description likha hai? ki kya kiye ? nvidia mei?',
#  769: ' acha tu bta....startups ya big companies ?',
#  770: ' abe mtlb likhte hai n ki kya kiye hai wha pe short desc. resume mei dekha ?',
#  771: ' ok indirectly wo dl pe kam kiye ...mtlb framework pe skills wala dikha zara',
#  772: ' bhai tu confuse mt ho jyda....tere ko jo sahi lg r hai kar ke ab le* ok tu bhi ml pe hi focus kr ab hojyga tera bhi chinta mt kr',
#  773: ' mt kr ..... entertainment ke lia bhi oo bhai sab frontend thik hai backend muskil hai',
#  774: ' php nodejs iske lia tere ko express',
#  775: ' or javascript chiye phle to ye ye to easy hai',
#  776: ' ml kr le abhi hai ek phle se referal ke roop mei kam ajyga ye isko pakad le ab tu',
#  777: ' ha..project se relted doubt wgra isse hi pucha kr to usko fir tera smjh ane lgega ki kesa hai tu field mei to bd mei help ajyga',
#  778: ' mai....mern kia mtlb fullstack task hai or java dekh r tha',
#  779: ' ha',
#  780: ' ha',
#  781: ' stackoverflow + documentations + tutorials ye krna tha to ye krna pda',
#  782: ' abe jese for example ek paint tool bnaya hu bnaya tha onsite mei to usme kch kch pta nhi tha to stackoverflow + kch tutorial kch naya functions pta chala random mostly traversary',
#  783: ' kya ?',
#  784: ' to isme nayi bt kya h ? 🙂',
#  785: ' ha to bna lena usme kya hai',
#  786: ' nhi hota esa ajkal wo to bs ehsan kr dk do* ki ek project bna do wala condition hai ab tere yha nerds honge koi wo log to whi bnayenge jo branch se relted hai',
#  787: ' mere yha ek hai nerd 9.7 cgpa ml ka mere se puch r tha task🙂 acha...',
#  788: ' abe wo task dia tha jo tun kog',
#  789: ' ha...or mai bta bhi r tha 😂',
#  790: ' ha mai usko bola ki web kch puchta to bta deta ab ye kya ml ka mai khud ni kr r hu',
#  791: ' ruk tujhe classs ke bd use krne ke lia dunga abe botfather hota hai usme new bot ka nam wgra dete hai fir backend code khud likhana pda',
#  792: ' *devblin_bot* nam se hai groups mei msgs wgra bhej skta hai or groups jisme wo member hai uski lists de skta hai',
#  793: ' commands ke basis pe tujhe rply bhejega wo /help se commands ke list ate hai /show  se group list',
#  794: ' /send to group_name msg',
#  795: ' kya ?',
#  796: ' ha abhi private hai tu khud bhi use kr skta hai usko apne bot ke lia be jo commands maine de rkhe hai unme se hi use kr skta hai',
#  797: ' abe tu utna bada bhi mt smjh 40-50 line ka hoga',
#  798: ' kyo? kya hua?',
#  799: ' kya h ye . ?',
#  800: ' nahi',
#  801: ' kb ? pdhai? wo madam ?',
#  802: ' abe speech wala bhi bnaya mai https://devblin.github.io/voice/',
#  803: ' isme box move krta hai speech se left right up',
#  804: ' down start',
#  805: ' commands hai ha mai hu',
#  806: ' ready* uske wo seminar wgra kr r hu crud ka kia',
#  807: ' ja',
#  808: ' ha bol kch nho be',
#  809: ' repo bna apne username ke nam se',
#  810: ' ye ek project hai',
#  811: ' to uska documentation dekh',
#  812: ' ha to api ka documentation hai gitbub mej',
#  813: ' abe tere psss mera koi photo hai ? dhang kaa?',
#  814: ' ...',
#  815: ' website ke lia 🙂',
#  816: ' nahi ....spoder spider*',
#  817: " ki pradyumna kya h apki life me bittu's ques. 😂",
#  818: " pradyumna apke liye jaha bolte ho aa jata h but ap usko bs use krte ho bittu's ques. 😂 abe iska ansr de de bhai mai to bol dia jnti ho ni mere ko to jo smjhana hai smjh lo to ye smjh ri hai wo 😂",
#  819: ' ansr de iska jlsi',
#  820: ' ok bhai anser de sbke',
#  821: ' jo wo puchi hai usko frwrd krna hau',
#  822: ' pradyumna apka friend h ki ni??',
#  823: ' bhai jo jo puch r hu ansr de sbke',
#  824: ' ???',
#  825: ' kya laude m ? abe ansr de jldi sar kha ri hai mera wo ab',
#  826: ' ha m ?',
#  827: ' 🙄',
#  828: ' yhi tk',
#  829: ' abe kch ni puch ri thi pradyumna kya hai apka ye wo to mai bola khud ko pta hona chiye ye to bekar sa ques. yai hai* to mai bola hi nahi directly',
#  830: ' kya thik hai ?',
#  831: ' jya be kya kya krta hai dinbhr ajkal ?',
#  832: ' koi development wala sikh le arish faced prblm',
#  833: ' mujhe puch r tha apna ml model',
#  834: ' deploy krna hai to kese kru?',
#  835: ' mai usko bola ki django/flask sikhna pdega tujhe  agr tu webapp bnana chahta hai apne model ke lia to agr ab mai club mei hu to ek bhiya hai jo github pe top contributor the wo bole ki ml wgra sb overrated hogya hai',
#  836: ' jyda per mt lagao ek chiz ache se kr lo but agr tere ko arish jesa krna hai ki model ke lia app wgra bnana to tujhe kam se kam app/web sikhna pdega',
#  837: ' or codechef mt kia kr kya ?',
#  838: ' dsa mei kaha tk pahcuh gya ?',
#  839: ' mera dsa chal r hai iss sem aj to ct tha google helped',
#  840: ' to codechef mei kya ? compete ?',
#  841: ' practice ?',
#  842: ' abe long challenge mt kia kr tym waste hai cookoff or lunchtime sahi hai',
#  843: ' or baki codeforces kia kr',
#  844: ' or opensource kr r hai ?',
#  845: ' MediaShared',
#  846: ' MediaShared',
#  847: ' maine 2 compete kiye hai abhi tk codeforces pe 2-3 hi bnta hai ek mei to bs 1 bna',
#  848: ' mai to spider walo se puchunga MediaShared',
#  849: ' bahut sahi log hai',
#  850: ' MediaShared agle week se project denge abhi bole sikho project ke hissb se mern to sikh hi r hu sath mei or kch extra phli bar sun r hu wo sb MediaShared',
#  851: ' ha tutorial dekh r hu usme koi prjct bna r hai but mai wo prject nhi bna r hu mai reddit clone bna r hu',
#  852: ' mtlb framework smjhne ke lia',
#  853: ' tere yha to honge ? abe tere wo nvidia wale to honge opensource wake wale* github dekh ke smjh lia kr',
#  854: ' https://goodfirstissues.com/',
#  855: ' kyo nahi dal skta ! ? 🙂',
#  856: ' spider ka hai',
#  857: ' acha hai...dekh le tere layk chiz hai',
#  858: ' tali baja fir usme',
#  859: ' MediaShared',
#  860: ' ha but sb nhi kr skte hai restricted hai markdown hi use kr',
#  861: ' ha p tag center align use kr skta hai kam lrega krega*',
#  862: ' ha to kahe puch r bhaklandi ke kia hua hai use to MediaShared',
#  863: ' google kia kr na laude center krne ke lia or kya content ko',
#  864: ' MediaShared DeletedMsg DeletedMsg DeletedMsg DeletedMsg DeletedMsg MediaShared',
#  865: ' mera photu lg gua gya MediaShared website mei MediaShared',
#  866: ' https://spider.nitt.edu MediaShared',
#  867: ' MediaShared',
#  868: ' mai new bna r hu abhi parallex effect k sth 2-3 log bs seniors mei bs webdev head ka hau syd MediaShared nahi bhai mai ye wala phot htwa dunga jldi hi ajib feel ho r hai ab abe ubuntu ko uninstall kese kru? ?',
#  869: ' mere ko',
#  870: ' space bdhana hai ubuntu ka',
#  871: ' bta ?',
#  872: ' 🙂 nahi smjh aya last bar jo tu kia tha ? whi?',
#  873: ' ok',
#  874: ' mint kr r hu be mai install ab ye uninstall ka hai ?',
#  875: ' external monitor connect krne mei prblm jata hai ubuntu mei mint mei thik hai ye sb ye video mei hai ?',
#  876: ' ek frnd krta hai use',
#  877: ' dual montior',
#  878: ' mera dusra monitor ka resolution jitna hai usse kam support krta hai ubuntu mei',
#  879: ' windows mei thik chlta hai',
#  880: ' kiska ?',
#  881: ' 🙂 maine 10 videos dekh loye ye sahi krne ke loa lia*',
#  882: ' halka hai thoda',
#  883: ' 🙂 ok smjh gua',
#  884: ' MediaShared',
#  885: ' ok sir abe mint fast hai be ubuntu se tu bhi try kr mint MediaShared',
#  886: ' kr  r hu',
#  887: ' stats/seniors ki bt',
#  888: ' se bol r tha ki fast hai ubuntu se abe nitin ka kya chal r hai? kidhar ja r hai wo?',
#  889: ' MediaShared 10 min lagay tu ye msg pdhne mei? or fur 3 min rply dene m',
#  890: ' abe ye utha hai ki ni? sok soke yad dila de usko call rkek',
#  891: ' 🙂 iit  mei jyga lg rh advanve nikal lia hoga wo',
#  892: ' oh',
#  893: ' abe ae bsdike maryega kya ? ye sb mt kr fel jyga sticker idhr udhr',
#  894: ' ni aya snjh',
#  895: ' nahi earphone nako',
#  896: ' sun lia bhai ye kya pyaz ? kya ? wtf pyaz ?',
#  897: ' ka krta hai ajkal? class ke alwa ?',
#  898: ' oh bade log',
#  899: ' oh big people',
#  900: ' bade log...pur ungli kyo krta h khud ko 😂 ?',
#  901: ' *kaggle* bade log krte hai mere jese chote log nahi',
#  902: ' abe c hai bhai tere club wale',
#  903: ' or tu nhi c hai laude tere ko bola tha mai poroject kar induction krna nahi ata sahi se bhai unko',
#  904: ' sbko equal sun meri bt sbkk equal chance milna chiye jese 2 month ke lia task wgra dena taki usme sikhe khud se ab sbko nhi pta hota',
#  905: ' ml ai ke bare mei mere ko nhi pta tha webdev ke bare mei to ab tere yha type induction hota tb to mere lag jate',
#  906: ' kisme ?',
#  907: ' tapping wala game number tapping',
#  908: ' nahi mila hi nhi tutorial uss game ka dom manipluation krna tha',
#  909: ' kya ? kyo puch r hai ye sb ?',
#  910: ' oh wro',
#  911: ' ok kb ? jyda kch  hi dominoos le jana ye hai konsa ??? project ?',
#  912: ' agr reactnative sikh lunga iss sal to mobileapp bna dunga nahi to webapp hi bna paunga',
#  913: ' zarurat ke hissb se sikhta hu mai bsdike tere projct ke lia kahe sikhunga',
#  914: ' ha kyoki react  sikh lia hu to native easy pdega frontend* bolte hai usko or tere ko phle apne model ke lia api bnana pdega backend*',
#  915: ' django/flask sikhna pdega tere ko iskw lua*',
#  916: ' MediaShared',
#  917: ' mujje kese pta hoga tu fb chalata hai tere ko pta hoga 3 yrs ?',
#  918: ' usi ka hoga kya pta abe wo usme dekh le jo schl se menu card mila tha students ka usme sbka dob to likha hi hai',
#  919: ' 🙂 uska nhi hai to hai kiska ?',
#  920: ' MediaShared',
#  921: ' chutuya kehna chah rhe the likh nahi paye',
#  922: ' a cha MediaShared MediaShared',
#  923: ' gm bro gm yhi ganda dimag yhi dikhega phle',
#  924: ' MediaShared MediaShared',
#  925: ' MediaShared',
#  926: ' ha',
#  927: ' chal r hai',
#  928: ' haa...wo club ko or ek freelance wala',
#  929: ' are nhi spider ko approach kiye hai to senior log meet krenge ki krna hai ya nahi cloud based hai koi',
#  930: ' ye alg hai...',
#  931: ' club',
#  932: ' usme cuvette tech krke koi company hai wo projectw dilayegi nitt...iitkgp... or koi 2 tha yad nhi unke lia hai abhi filhal',
#  933: ' abhi gya nhi hu',
#  934: ' club wala to bhai club pe depend krega kyoki project chal r hai filhal MediaShared MediaShared',
#  935: ' opensource contribution hi maza hai tere ko aya ni',
#  936: ' ml ke projects dhundh r tha ?',
#  937: ' ml mei mostly documentation...bug wale hi honge ya deployment se relted',
#  938: ' sikh le leta hacktober mei dinbhr kya krta hai tu ? class ke alwa',
#  939: ' or m ??? bs ? oh kaggle...',
#  940: ' MediaShared',
#  941: ' MediaShared',
#  942: ' MediaShared MediaShared sahi hai tera tp statistics MediaShared',
#  943: ' tera cgpa kitna h ! ? MediaShared',
#  944: ' mera to ab kya hi bolu course',
#  945: ' dsa  mera phle se gira hua hai',
#  946: ' frk pdta hai...placements mei sort krte hai bina skills dekhe 7.5 amazon ka tha eyd syd*',
#  947: ' mera to use bhi kam',
#  948: ' microsfot ka bhi 8 hai syd ha whi  krunga ct mei to 90% aa re hai MediaShared endsem online hua tb to mai hi top krunya MediaShared',
#  949: ' kese m ?',
#  950: ' km kese aye ? google se ansr nhi mile ?',
#  951: ' assignments nhi kia ?',
#  952: ' itna tatti bhi kyo bnaya ? MediaShared mai to dusro ke assignments ke sth ched chad krke submit kr deta hu mai assignments khud se krta hi nahi ho hu*',
#  953: ' MediaShared 4.5/5 9/10 8.5/10 MediaShared ese aa re hai ajkal mai ek grp bnaya hu north walo ka mere dept. mei 2yr walo ka usme sab kr dete hai help MediaShared sbke ache ate hau endsem mei sbka 8+ aya mera chor ke MediaShared',
#  954: ' tera to ayega hi 8 se upor upor kese bhi krke',
#  955: ' mera to spider wale senior bol re the ki cgpa thoda bdha lo...8 ke uppr kr lo ... to dhyn dunga endsem mei thoda humara to relative hi hai endsem bhi relative tha absolute rkhne ka logic smjh nj aya tum log ke yha se',
#  956: ' MediaShared mere dept. mei software dev krne wale bacho ka grades janbhuj ke gira dete hai',
#  957: ' jo iss bar ki hod hai wo phle se yhi krwa ri hai... kyoki core pe dhyn de krke unko chiye ki sb core pe dhyn de',
#  958: ' kin log ko?',
#  959: ' bdhiya hai',
#  960: ' yha to apne clubs ko funding milta hai lakh ke uppr....itna support krte hai abhi trichy police ke lia...app bna re hai apan to ye sb projects admin late hai apan ko dete hai logo ko jo project krna ho mtlb club wale wo pesa le skte hai club se abe jaldi group deky dekh* abe',
#  961: ' mujhe bhi owner bna tdap server mei kch',
#  962: ' krna hai mujhe kya pta bs merr ko server settinga krna hai',
#  963: ' bsdike iske lia hi vhiye permission settinga dekh na server settings mei',
#  964: ' thik hai',
#  965: ' mai 3 no ko admin setting krne ka kosis krunga',
#  966: ' or roles wgra bta dena add kr dunga tiwari ko hilarious-boi ka role de dunga',
#  967: ' ok bra bta tu bhi change kr skta hai ab tu weird-admin gai hai* sab powers hai bs 3 log tk rkhna hai tu mai arish honge bs weird-admin',
#  968: ' abe help krega kya ?',
#  969: ' aj ct hai to ansrs dhundne hai tere ko',
#  970: ' circuit theory',
#  971: ' kyo ?',
#  972: ' MediaShared chor de lab 2 bje hai ct mera',
#  973: ' 1',
#  974: ' 2 bje',
#  975: ' MediaShared bade log',
#  976: ' nahi tera hai bta r hu MediaShared',
#  977: ' MediaShared tu bhi machine learning enthusiast hai kya ? MediaShared',
#  978: ' MediaShared ha ye bt bhi hai ab kya hi bol skte hai',
#  979: ' MediaShared',
#  980: ' MediaShared',
#  981: ' kyo kya hua ? syd vit wale hai usme gali galoch krte hai kya ? MediaShared',
#  982: ' abe amoungus',
#  983: ' khelega? abhi',
#  984: ' tu arish mei riwari bpr',
#  985: ' cancel... bsdike',
#  986: ' 354/2761 rank',
#  987: ' ctf',
#  988: ' web exploitation ruk ja',
#  989: ' haa nahi',
#  990: ' ha',
#  991: ' hq',
#  992: ' nahi',
#  993: ' webdev ata hai ... webexploitation smjh ata hai',
#  994: ' ki vurnabilities kya kya ho skti hai ek website mei cookies..session wgra sab',
#  995: ' sql injection 🙄',
#  996: ' abe wo nhi redirects...dekhna pdta hai server mei kch bug hota hai usko dhundhte hai',
#  997: ' thoda bahut',
#  998: ' ha',
#  999: ' ha to bhai maine basic vurnabilities smjh rkhi hai n',
#  ...}

# %% [markdown]
# creating dict such that, conv_end's index is the index on the conv_start, till which the reply has been made.

# %%
conv_dicts = pd.DataFrame({'col_1':conv_start,'col_2':conv_end})#asdf
# conv_dicts = pd.DataFrame(pairs, columns=['col_1', 'col_2'])

# %%
conv_dicts
# Out:
#                                                   col_1  \
# 0      abe sun sun na laude missed voice call missed...
# 1      abe ye mt bhja kr be ese iss grp m ldki bhi h...
# 2      abe rs10 de to googlepay mei rs 5 bhi chlega ...
# 3      ha to sun mai webpage bnaya khud ka mtlb file...
# 4      abe ese mt bol rat rat jg ke bnaya or end mei...
# ...                                                 ...
# 7829                                             ticket
# 7830                                            + id bs
# 7831                     boarding pss jb board krte hai
# 7832                        👍 controller mt bhulna null
# 7833                               live location shared
#
#                                                   col_2
# 0                                                   bol
# 1                                           acha thik h
# 2                                                   bol
# 3               pata nahi me kbhi github.io use nhi kia
# 4                                 google me search kia?
# ...                                                 ...
# 7829                            mai toh yehi dikhata hu
# 7830                           ticket alag hoya hai kya
# 7831   boarding pass hi dikhata hu mai to entry mein...
# 7832   rkh liya hu MediaShared location: https://map...
# 7833   live location shared MediaShared MediaShared ...
#
# [7834 rows x 2 columns]

# %%
def join_as(x):
    try:
        if(len(x)!=1):
            return ''.join(x)
        else:
            return str(x[0])
    except:
        return 'nan'
# conv_dicts.dropna(subset=['col_1','col_2'],inplace=True)
conv_dicts['response_text'] = conv_dicts['col_2'].apply(join_as)
conv_dicts['input_text'] = conv_dicts['col_1'].apply(join_as)

# %%
conv_dicts.head()
# Out:
#                                                col_1  \
# 0   abe sun sun na laude missed voice call missed...
# 1   abe ye mt bhja kr be ese iss grp m ldki bhi h...
# 2   abe rs10 de to googlepay mei rs 5 bhi chlega ...
# 3   ha to sun mai webpage bnaya khud ka mtlb file...
# 4   abe ese mt bol rat rat jg ke bnaya or end mei...
#
#                                       col_2  \
# 0                                       bol
# 1                               acha thik h
# 2                                       bol
# 3   pata nahi me kbhi github.io use nhi kia
# 4                     google me search kia?
#
#                               response_text  \
# 0                                       bol
# 1                               acha thik h
# 2                                       bol
# 3   pata nahi me kbhi github.io use nhi kia
# 4                     google me search kia?
#
#                                           input_text
# 0   abe sun sun na laude missed voice call missed...
# 1   abe ye mt bhja kr be ese iss grp m ldki bhi h...
# 2   abe rs10 de to googlepay mei rs 5 bhi chlega ...
# 3   ha to sun mai webpage bnaya khud ka mtlb file...
# 4   abe ese mt bol rat rat jg ke bnaya or end mei...

# %%
conversation_data = conv_dicts[['input_text','response_text']]

# %%
conversation_data.to_csv(os.path.join(data_path,'conversation_data.csv'),index=False)

# %%
import pandas as pd
import re

def remove_hyperlinks(text):
    # Remove any URLs from the text using regex
    return re.sub(r'http\S+|www\S+|https\S+', '', text, flags=re.MULTILINE)

def clean_whatsapp_data(csv_file):
    # Read the CSV file
    df = pd.read_csv(csv_file)
    df.dropna(inplace=True)
    df = df.rename(columns={'input_text':'question','response_text':'response'})
    df['question'] = df['question'].apply(lambda x:x.replace('"',''))
    df['response'] = df['response'].apply(lambda x:x.replace('"',''))

    # Assuming you have a 'Message' column in your CSV file
    # Remove hyperlinks from the 'Message' column
    df['question'] = df['question'].apply(remove_hyperlinks)
    df['response'] = df['response'].apply(remove_hyperlinks)

    # Filter out rows containing media content
    # Update the pattern if you have a different format
    media_pattern = r'<Media omitted>$|<Media omitted>$|image omitted$|video omitted$|GIF omitted$|sticker omitted$|audio omitted$|document omitted$'
    df = df[~df['question'].str.contains(media_pattern)]
    df = df[~df['response'].str.contains(media_pattern)]

    # Write the cleaned data to a new CSV file
#     df.to_csv(output_file, index=False)
    return df

# Usage example
input_csv = os.path.join(data_path,'conversation_data.csv')
# output_csv = 'cleaned_whatsapp_data.csv'
cleaned_df = clean_whatsapp_data(input_csv)

# %%
cleaned_df
# Out:
#                                                question  \
# 0      abe sun sun na laude missed voice call missed...
# 1      abe ye mt bhja kr be ese iss grp m ldki bhi h...
# 2      abe rs10 de to googlepay mei rs 5 bhi chlega ...
# 3      ha to sun mai webpage bnaya khud ka mtlb file...
# 4      abe ese mt bol rat rat jg ke bnaya or end mei...
# ...                                                 ...
# 7829                                             ticket
# 7830                                            + id bs
# 7831                     boarding pss jb board krte hai
# 7832                        👍 controller mt bhulna null
# 7833                               live location shared
#
#                                                response
# 0                                                   bol
# 1                                           acha thik h
# 2                                                   bol
# 3               pata nahi me kbhi github.io use nhi kia
# 4                                 google me search kia?
# ...                                                 ...
# 7829                            mai toh yehi dikhata hu
# 7830                           ticket alag hoya hai kya
# 7831   boarding pass hi dikhata hu mai to entry mein...
# 7832      rkh liya hu MediaShared location:  location:
# 7833   live location shared MediaShared MediaShared ...
#
# [7708 rows x 2 columns]

# %%
cleaned_df['text_field'] = 'deepanshu:'+cleaned_df['question']+'. pradyumna: '+cleaned_df['response']

# %%
cleaned_df[['text_field']].to_csv(os.path.join(data_path,'text_fields.csv'),index=False)
